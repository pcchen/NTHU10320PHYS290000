# %% [markdown]
# # Homework 4

# %% [markdown]
# ## Problem 1
#
# 1. Implement the `Point` class.
# 2. Implement the `Rectangle` class.
# 3. Write a function called `distance_between_points` that takes two Points as arguments and returns the distance between them.
# 4. Write a function named `move_rectangle` that takes a Rectangle and two numbers named `dx` and `dy`. It should change the location of the rectangle by adding `dx` to the `x` coordinate of corner and adding `dy` to the `y` coordinate of corner.
# 5. Write a function named `move_rectangle_new` that is similar to the `move_rectangle` but it creates and returns a new Rectangle instead of modifying the old one.
# 6. Write some codes to demonstrate the usage of functions above.

# %%
# Problem 1

# 1
class Point(object):
    """Represents a point in 2-D space."""
blank = Point()
blank.x=1
blank.y=2
print '(%g,%g)' %(blank.x,blank.y)

# 2
class Rectangle(object):
    """Represents a rectangle. 

    attributes: width, height, corner.
    """
box = Rectangle()
box.width = 100.0
box.height = 200.0
box.corner = Point()
box.corner.x=1
box.corner.y=2
print '(%g,%g,%g,%g)' %(box.width,box.height,box.corner.x,box.corner.y)

# 3
import math
point1=Point()
point2=Point()
def distance_between_points(p1,p2):
    distance = math.sqrt((p1.x-p2.x)**2 + (p1.y-p2.y)**2)
    print 'The distance between','(%g,%g)'%(p1.x,p1.y),'and','(%g,%g)'%(p2.x,p2.y),'is',distance 
    distance=1
    return distance
point1.x=1
point1.y=2
point2.x=5
point2.y=6
distance_between_points(point1,point2)

# 4
import math
def move_rectangle(r,adx,ady):
    r.corner.x=r.corner.x+adx
    r.corner.y=r.corner.y+ady
    return r
rec=Rectangle()
rec.width=10
rec.height=5
rec.corner=Point()
rec.corner.x=1
rec.corner.y=2
dx=2
dy=3
move_rectangle(rec,dx,dy)
print 'The new rectangle corner is','(%g,%g)'%(rec.corner.x,rec.corner.y)

# 5
import math
class Rectangle(object):
    """Represents a rectangle. 

    attributes: width, height, corner.
    """
def move_rectangle_new(r,adx,ady):
    recn.width=r.width
    recn.height=r.height
    recn.corner=Point()
    recn.corner.x=r.corner.x+adx
    recn.corner.y=r.corner.y+ady
    return recn
rec=Rectangle()
recn=Rectangle()
rec.width=10
rec.height=5
rec.corner=Point()
rec.corner.x=1
rec.corner.y=2
dx=3
dy=5
move_rectangle_new(rec,dx,dy)
print 'The new rectangle corner is','(%g,%g)'%(recn.corner.x,recn.corner.y)

#6
print '=====Here is number 6====='
originbook=Rectangle()
originbook.width=20
originbook.height=30
originbook.corner=Point()
originbook.corner.x=12
originbook.corner.y=20
bookmovedx=1
bookmovedy=1
move_rectangle_new(originbook,bookmovedx,bookmovedy)
distance_between_points(originbook.corner,recn.corner)
print 'The book move',distance

# %% [markdown]
# ## Problem 2
#
# 1. Implement the `Time` class.
# 2. Write a function called `print_time` that takes a Time object and prints it in the form `hour:minute:second`.
#   **Hint**: the format sequence '%.2d' prints an integer using at least two digits, including a leading zero if necessary.
# 3. Write a boolean function called `is_after` that takes two Time objects, `t1` and `t2`, and returns `True` if `t1` follows `t2` chronologically and `False` otherwise. **Challenge**: don’t use an `if` statement.
# 4. Write a function called `increment_modifier` that adds a given number of seconds to a Time object. It should modify the original time object. It should not contain any loops.
# 5. Write a function called `increment_pure` that adds a given number of seconds to a Time object. It should create and return a new Time object.
# 6. Write a function called `mul_time` that takes a Time object and a number and returns a new Time object that contains the product of the original Time and the number.
# 7. Use `mul_time` to write a function that takes a Time object that represents the finishing time in a race, and a number that represents the distance, and returns a Time object that represents the average pace (time per mile).
# 8. Write some codes to demonstrate the usage of functions above.

# %%
# Problem 2

# 1
class Time(object):
    """Represents the time of day.
    attributes: hour, minute, second
    """
time = Time()
time.hour =  3
time.minute = 56
time.second = 20

# 2
class Time(object):
    """Represents the time of day.
    attributes: hour, minute, second
    """
def print_time(t):
    print '%.2d:%.2d:%.2d'%(t.hour,t.minute,t.second)
    
time = Time()
time.hour =  3
time.minute = 56
time.second = 20
print_time(time)

# 3
def is_after(t1,t2):
    d=t2.hour*3600+t2.minute*60+t2.second-t1.hour*3600+t1.minute*60+t1.second
    print d>0
time1 = Time()
time2=Time()
time1.hour =  3
time1.minute = 56
time1.second = 20
time2.hour =  10
time2.minute = 50
time2.second = 25
is_after(time1,time2)

# 4
def increment_modifier(t,dt):
    t.second=t.second+dt
    if t.second==60:
        t.second=0
        t.minute=t.minute+1
    if t.second>60:
        t.minute=t.minute+t.second/60
        t.second=t.second%60
        if t.minute>=60:
            t.hour=t.hour+t.minute/60
            t.minute=t.minute%60
    return t
time = Time()
time.hour =  15
time.minute = 56
time.second = 20
dt=300
increment_modifier(time,dt)
print '%.2d:%.2d:%.2d'%(time.hour,time.minute,time.second)
# 5
class Time(object):
    """Represents the time of day.
    attributes: hour, minute, second
    """
def increment_pure(t,dt):
    newtime.hour=t.hour
    newtime.minute=t.minute
    newtime.second=t.second+dt
    if newtime.second==60:
        newtime.second=0
        newtime.minute=newtime.minute+1
    if newtime.second>60:
        newtime.minute=newtime.minute+newtime.second/60
        newtime.second=newtime.second%60
        if newtime.minute>=60:
            newtime.hour=newtime.hour+newtime.minute/60
            newtime.minute=newtime.minute%60
    return newtime
time = Time()
newtime=Time()
time.hour =  15
time.minute = 56
time.second = 20
dt=240
increment_pure(time,dt)
print '%.2d:%.2d:%.2d'%(newtime.hour,newtime.minute,newtime.second)
# 6
class Time(object):
    """Represents the time of day.
    attributes: hour, minute, second
    """
class NewTimeObject(object):
    """Represents the time of day.
    attributes: hour, minute, second, distance
    """
def mul_Time(time,number):
    newtimeob.hour=time.hour
    newtimeob.minute=time.minute
    newtimeob.second=time.second
    newtimeob.distance=number
    return newtimeob
time=Time()
newtimeob=NewTimeObject()
time.hour =  15
time.minute = 56
time.second = 20
number=10
mul_Time(time,number)
print 'The newtime object is:','%.2d:%.2d:%.2d:%.2d'%(newtimeob.hour,newtimeob.minute,newtimeob.second,newtimeob.distance)
# 7
class NewTimeObject(object):
    """Represents the time of day.
    attributes: hour, minute, second, distance
    """
def mul_Time(time,distance):
    timepace.hour=time.hour/distance
    timepace.minute=time.minute/distance
    timepace.second=time.second/distance
    timepace.distance=distance
    return timepace
time=Time()
timepace=NewTimeObject()
time.hour =  15
time.minute = 56
time.second = 20
number=10
mul_Time(time,number)
print 'The timepace object is:','%.2d:%.2d:%.2d:%.2d'%(timepace.hour,timepace.minute,timepace.second,timepace.distance)
# 8
# Out:
#  03:56:20
# True
# 16:01:20
# 16:00:20
# The newtime object is: 15:56:20:10
# The timepace object is: 01:05:02:10

# %% [markdown]
# ## Problem 3
#
# 1. Write a class definition for a Date object that has attributes `day`, `month` and `year`.
# 2. Write a function called `increment_date` that takes a Date object, `date` and an integer, `n`, and returns a new Date object that represents the day `n` days after date.
# 3. **Challenge**: does your function deal with leap years correctly? See http://en.wikipedia.org/wiki/Leap_year.

# %%
# Problem 3

#1
class Date(object):
    """Represents the date of day.
    attributes: day, month, year
    """
#2
class Date(object):
    """Represents the date of day.
    attributes: day, month, year
    """
class newDate(object):
    """Represents the date of day.
    attributes: day, month, year, dday
    """
def increment_date(newdateob,date,n):
    newdateob.day=date.day+n
    newdateob.month=date.month
    newdateob.year=date.year
    newdateob.dday=n
    if newdateob.day==30:
        newdateob.day=0
        newdateob.month=newdateob.month+1
    if newdateob.day>30:
        newdateob.month=newdateob.month+newdateob.day/30
        newdateob.day=newdateob.day%30
        if newdateob.month>=12:
            newdateob.year=newdateob.year+newdateob.month/12
            newdateob.month=newdateob.month%12
    return newdateob
newdateob=newDate()
date=Date()
date.day=10
date.month=9
date.year=2015
n=30
increment_date(newdateob,date,n)
print 'The new Date object is:','%.2d:%.2d:%.2d:%.2d'%(newdateob.day,newdateob.month,newdateob.year,newdateob.dday)

#3
# Out:
# The new Date object is: 10:10:2015:30

# %% [markdown]
# ## Problem 4
#
# The `datetime` module provides date and time objects that are similar to the Date and Time objects in this chapter, but they provide a rich set of methods and operators. Read the documentation at http://docs.python.org/2/library/datetime.html.
#
# 1. Use the `datetime` module to write a program that gets the current date and prints the day of the week.
# 2. Write a program that takes a birthday as input and prints the user’s age and the number of days, hours, minutes and seconds until their next birthday.
# 3. For two people born on different days, there is a day when one is twice as old as the other. That’s their Double Day. Write a program that takes two birthdays and computes their Double Day.
# 4. For a little more challenge, write the more general version that computes the day when one person is `n` times older than the other.

# %%
# Problem 4

#1
#2
#3
#4

# %% [markdown]
# ## Problem 5
#
# Implement the `Point` class and the `Rectangle` class, with following methods.
#
# 1. Write an `init` method for the Point class that takes `x` and `y` as optional parameters and assigns them to the corresponding attributes.
# 2. Write a `str` method for the Point class.
# 3. Write an `add` method for Points that works with either a Point object or a tuple:
#   * If the second operand is a Point, the method should return a new Point whose `x` coordinate is the sum of the `x` coordinates of the operands, and likewise for the `y` coordinates.
#   * If the second operand is a tuple, the method should add the first element of the tuple to the `x` coordinate and the second element to the `y` coordinate, and return a new Point with the result.
# 4. Write some codes to demonstrate the usage of methods above.

# %%
# Problem 5

#1
#2
#3
#4
