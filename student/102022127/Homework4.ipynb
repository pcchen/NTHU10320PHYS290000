# %% [markdown]
# # Homework 4

# %% [markdown]
# ## Problem 1
#
# 1. Implement the `Point` class.
# 2. Implement the `Rectangle` class.
# 3. Write a function called `distance_between_points` that takes two Points as arguments and returns the distance between them.
# 4. Write a function named `move_rectangle` that takes a Rectangle and two numbers named `dx` and `dy`. It should change the location of the rectangle by adding `dx` to the `x` coordinate of corner and adding `dy` to the `y` coordinate of corner.
# 5. Write a function named `move_rectangle_new` that is similar to the `move_rectangle` but it creates and returns a new Rectangle instead of modifying the old one.
# 6. Write some codes to demonstrate the usage of functions above.

# %%
# Problem 1
import math
import copy

# 1
print'problem1 #1'
class Point(object):
    """Represents a point (x,y) in 2-D space."""
point1 = Point()
point2 = Point()
point1.x = 3
point1.y = 4
point2.x = 6
point2.y = 8
print Point

# 2
print'\nproblem1 #2'
class Rectangle(object):
    """Represents a rectangle.
    attributes: width, height, corner."""
box = Rectangle()
box.width = 20.0
box.height = 30.0
box.corner = Point()
box.corner.x = 0.0
box.corner.y = 0.0
print Rectangle
    
# 3
print'\nproblem1 #3'
point1.x = 3
point1.y = 4
point2.x = 6
point2.y = 8

def print_point(p):
    return '(%g, %g)' % (p.x, p.y)

def distance_between_points(a, b):
    d = math.sqrt((a.x - b.x)**2 + (a.y - b.y)**2) 
    return d
    
print 'point1', print_point(point1)
print 'point2', print_point(point2)
print 'distance',distance_between_points(point2, point1)


# 4
print'\nproblem1 #4'
def move_rectangle(rect, dx, dy):
    rect.corner.x = rect.corner.x + dx
    rect.corner.y = rect.corner.y + dy
    return '(%g, %g)' % (rect.corner.x, rect.corner.y)

print 'before box.corner', '(%g, %g)' % (box.corner.x, box.corner.y)
print 'move',move_rectangle(box, 1, 2)
print 'after move box.corner', '(%g, %g)' % (box.corner.x, box.corner.y)


# 5
print'\nproblem1 #5'
class Rectangle2(object):
    """Represents a rectangle.
    attributes: width, height, corner."""
new = Rectangle2()
new.width = box.width
new.height = box.height
new.corner = Point()
new.corner.x = box.corner.x
new.corner.y = box.corner.y
print Rectangle2

Rectangle2 = copy.copy(Rectangle)

def move_rectangle_new(rect, dx, dy):
    new.corner.x = rect.corner.x + dx
    new.corner.y = rect.corner.y + dy
    return '(%g, %g)' % (new.corner.x, new.corner.y)

print 'move', move_rectangle_new(box, 1, 2)
print 'new reactangle2 corner', '(%g, %g)' % (new.corner.x, new.corner.y)


# 6
print'\nproblem1 #6'
class Point(object):
    """Represents a point (x,y) in 2-D space."""
point1 = Point()
point2 = Point()

class Rectangle(object):
    """Represents a rectangle.
    attributes: width, height, corner."""
box = Rectangle()
box.width = 20.0
box.height = 30.0
box.corner = Point()
box.corner.x = 0.0
box.corner.y = 0.0

class Rectangle2(object):
    """Represents a rectangle.
    attributes: width, height, corner."""
new = Rectangle2()
new.width = box.width
new.height = box.height
new.corner = Point()
new.corner.x = box.corner.x
new.corner.y = box.corner.y
Rectangle2 = copy.copy(Rectangle)

def distance_between_points(a, b):
    d = math.sqrt((a.x - b.x)**2 + (a.y - b.y)**2) 
    return d

def move_rectangle(rect, dx, dy):
    rect.corner.x = rect.corner.x + dx
    rect.corner.y = rect.corner.y + dy
    return '(%g, %g)' % (rect.corner.x, rect.corner.y)

def move_rectangle_new(rect, dx, dy):
    new.corner.x = rect.corner.x + dx
    new.corner.y = rect.corner.y + dy
    return '(%g, %g)' % (new.corner.x, new.corner.y)

point1.x = float (raw_input('point1.x = '))
point1.y = float (raw_input('point1.y = '))
point2.x = float (raw_input('point2.x = '))
point2.y = float (raw_input('point2.y = '))
print 'distance',distance_between_points(point2, point1)

print 'before box.corner', '(%g, %g)' % (box.corner.x, box.corner.y)
dx = float (raw_input('move_dx = '))
dy = float (raw_input('move_dy = '))
print 'move',move_rectangle(box, dx, dy)
print 'after move box.corner', '(%g, %g)' % (box.corner.x, box.corner.y)
print 'move', move_rectangle_new(box, dx, dy)
print 'new reactangle2 corner', '(%g, %g)' % (new.corner.x, new.corner.y)
# Out:
#  problem1 #1
# <class '__main__.Point'>
#
# problem1 #2
# <class '__main__.Rectangle'>
#
# problem1 #3
# point1 (3, 4)
# point2 (6, 8)
# distance 5.0
#
# problem1 #4
# before box.corner (0, 0)
# move (1, 2)
# after move box.corner (1, 2)
#
# problem1 #5
# <class '__main__.Rectangle2'>
# move (2, 4)
# new reactangle2 corner (2, 4)
#
# problem1 #6
# point1.x = 7
# point1.y = 8
# point2.x = 4
# point2.y = 6
# distance 3.60555127546
# before box.corner (0, 0)
# move_dx = 4
# move_dy = 6
# move (4, 6)
# after move box.corner (4, 6)
# move (8, 12)
# new reactangle2 corner (8, 12)

# %% [markdown]
# ## Problem 2
#
# 1. Implement the `Time` class.
# 2. Write a function called `print_time` that takes a Time object and prints it in the form `hour:minute:second`.
#   **Hint**: the format sequence '%.2d' prints an integer using at least two digits, including a leading zero if necessary.
# 3. Write a boolean function called `is_after` that takes two Time objects, `t1` and `t2`, and returns `True` if `t1` follows `t2` chronologically and `False` otherwise. **Challenge**: don’t use an `if` statement.
# 4. Write a function called `increment_modifier` that adds a given number of seconds to a Time object. It should modify the original time object. It should not contain any loops.
# 5. Write a function called `increment_pure` that adds a given number of seconds to a Time object. It should create and return a new Time object.
# 6. Write a function called `mul_time` that takes a Time object and a number and returns a new Time object that contains the product of the original Time and the number.
# 7. Use `mul_time` to write a function that takes a Time object that represents the finishing time in a race, and a number that represents the distance, and returns a Time object that represents the average pace (time per mile).
# 8. Write some codes to demonstrate the usage of functions above.

# %%
# Problem 2

# 1
print'problem2 #1'
class Time(object):
    """Represents the time of day.
    attributes: hour, minute, second"""
    def __init__(self, hour=0, minute=0, second=0):
        self.hour = hour
        self.minute = minute
        self.second = second
print Time
        
# 2
print'\nproblem2 #2'
def print_time(time):
    print '%.2d:%.2d:%.2d' % (time.hour, time.minute, time.second)
time = Time() 
time.hour = 16
time.minute = 51
time.second = 30
print_time(time)

# 3
print '\nproblem2 #3'
t1 = Time()
t2 = Time()
def is_after(t1, t2):
    total_t1=t1.hour*3600+t1.minute*60+t1.second
    total_t2=t2.hour*3600+t2.minute*60+t2.second
    return total_t1>total_t2

t1.hour = float (raw_input('t1.hour = '))
t1.minute = float (raw_input('t1.minute = '))
t1.second = float (raw_input('t1.second = '))
print '%.2d:%.2d:%.2d' % (t1.hour, t1.minute, t1.second)
t2.hour = float (raw_input('t2.hour = '))
t2.minute = float (raw_input('t2.minute = '))
t2.second = float (raw_input('t2.second = '))
print '%.2d:%.2d:%.2d' % (t2.hour, t2.minute, t2.second)
print is_after(t1, t2)

# 4
print '\nproblem2 #4'
time.hour = 10
time.minute = 50
time.second = 11
def increment_modifier(time, seconds):
    print ("Original time : %.2d:%.2d:%.2d"
          % (time.hour, time.minute, time.second))
    time.second += seconds
    if time.second >= 60:
        quotient, remainder = divmod(time.second, 60)
        time.minute += quotient
        time.second = remainder
    if time.minute >= 60:
        quotient, remainder = divmod(time.minute, 60)
        time.hour += quotient
        time.minute = remainder
    if time.hour >= 24:
        time.hour -= 24
    print "Plus %g seconds" % (seconds)
    print ("New time : %.2d:%.2d:%.2d" % (time.hour, time.minute, time.second))

increment_modifier(time, 300)
        
# 5 method1
print '\nproblem2 #5'
class Time2(object):
    """Represents the time of day.
    attributes: hour, minute, second"""
new = Time2()
def increment_pure(t,sec):
    new.hour = time.hour
    new.minute = time.minute
    new.second = time.second+sec
    while new.second >= 60:
        new.second = new.second-60
        new.minute = new.minute+1
    while new.minute >= 60:
        new.minute = new.minute-60
        new.hour = new.hour+1
    while new.hour >= 24:
        new.hour = new.hour - 24
    return new

# 5 method2
def increment_pure(time, seconds):
    new_time = copy.copy(time)
    return increment_modifier(new_time, seconds)
    
# 6
print '\nproblem2 #6'
def time_to_int(time):
    minutes = time.hour * 60 + time.minute
    seconds = minutes * 60 + time.second
    return seconds
def int_to_time(seconds):
    time = Time()
    time.minute, time.second = divmod(seconds, 60)
    time.hour, time.minute = divmod(time.minute, 60)
    return print_time(time)

def mul_time(time , factor):
    new_time = copy.deepcopy(time)
    second = time_to_int(new_time)*factor
    return int_to_time(second)


# 7
print '\nproblem2 #7'
time = Time()
new = Time2()
def speed(time , distance):
    second = time_to_int(time)
    sp = second/distance
    return int_to_time(sp)

# 8
print '\nproblem2 #8'
time.hour = 10
time.minute = 10
time.second = 10
t1.hour=10
t1.minute=11
t1.second=10
t2.hour=10
t2.minute=59
t2.second=10

print_time(time)
print_time(t1)
print_time(t2)
print is_after(t1, t2)
increment_modifier(time, 300)
print_time(time)
increment_pure(time, 300)
print_time(time)
print time_to_int(time)
int_to_time(time_to_int(time))
mul_time(time , 2)
print 'time per miles:',speed(time , 10)
# Out:
#  problem2 #1
# <class '__main__.Time'>
#
# problem2 #2
# 16:51:30
#
# problem2 #3
# t1.hour = 1
# t1.minute = 2
# t1.second = 3
# 01:02:03
# t2.hour = 4
# t2.minute = 5
# t2.second = 6
# 04:05:06
# False
#
# problem2 #4
# Original time : 10:50:11
# Plus 300 seconds
# New time : 10:55:11
#
# problem2 #5
#
# problem2 #6
#
# problem2 #7
#
# problem2 #8
# 10:10:10
# 10:11:10
# 10:59:10
# False
# Original time : 10:10:10
# Plus 300 seconds
# New time : 10:15:10
# 10:15:10
# Original time : 10:15:10
# Plus 300 seconds
# New time : 10:20:10
# 10:15:10
# 36910
# 10:15:10
# 20:30:20
# time per miles: 01:01:31
# None

# %% [markdown]
# ## Problem 3
#
# 1. Write a class definition for a Date object that has attributes `day`, `month` and `year`.
# 2. Write a function called `increment_date` that takes a Date object, `date` and an integer, `n`, and returns a new Date object that represents the day `n` days after date.
# 3. **Challenge**: does your function deal with leap years correctly? See http://en.wikipedia.org/wiki/Leap_year.

# %%
# Problem 3

#1
class Date(object):
    """ Represent the date
    attributes: year, month, day.
    """
    def __init__(self, year=0, moon=0, day=0):
        self.year = year
        self.moon = moon
        self.day = day
print Time    

#2 & #3
date = Date()
date2 = Date()
def leapyear(year):
    if year%4 == 0:
        if year%100 == 0:
            if year%400 == 0:
                return True
            return False
        return True
    return False

def day_year(year):
    if leapyear(year):
        return 366
    return 365

def month_list(year):
    if leapyear(year):
        return [31,29,31,30,31,30,31,31,30,31,30,31]
    return [31,28,31,30,31,30,31,31,30,31,30,31]

def date_to_int(day):
    year_to_day = 0
    month_to_day = 0
    for year in range(1,date.year):
        year_to_day += day_year(year)

    month_day = month_list(date.year)
    for month in range(1,day.month):
        month_to_day += month_day[month - 1] 
    return month_to_day + year_to_day + date.day - 1

def print_date(date):
    print "西元{}年/{}月/{}日".format(date.year,date.month,date.day)    

def int_to_date(day):
    date2 = copy.deepcopy(date)
    date2.year = 1
    remain_day = 365
    month_day = month_list(date2.year)
    while day >= remain_day:
        date2.year += 1
        day -= remain_day
        remain_day = day_year(date2.year)
    
    date2.month = 1
    remain_day = 31    
    while day >= remain_day:
        date2.month += 1
        day -= remain_day
        remain_day = month_day[date2.month-1]
    
    date2.day = day+1
    return print_date(date2)
import copy
def increment_date(date,n):
    new_date = copy.deepcopy(date)
    return int_to_date(date_to_int(new_date)+n)

# Example
date.year = 2015 
date.month = 5
date.day = 13
n = 3
print_date(date)
increment_date(date,n)
print_date(date)
# Out:
# <class '__main__.Time'>
# 西元2015年/5月/13日
# 西元2015年/5月/16日
# 西元2015年/5月/13日

# %% [markdown]
# ## Problem 4
#
# The `datetime` module provides date and time objects that are similar to the Date and Time objects in this chapter, but they provide a rich set of methods and operators. Read the documentation at http://docs.python.org/2/library/datetime.html.
#
# 1. Use the `datetime` module to write a program that gets the current date and prints the day of the week.
# 2. Write a program that takes a birthday as input and prints the user’s age and the number of days, hours, minutes and seconds until their next birthday.
# 3. For two people born on different days, there is a day when one is twice as old as the other. That’s their Double Day. Write a program that takes two birthdays and computes their Double Day.
# 4. For a little more challenge, write the more general version that computes the day when one person is `n` times older than the other.

# %%
# Problem 4
#1
import datetime
rules = {0: "Monday",
         1: "Tuesday",
         2: "Wednesday",
         3: "Thursday",
         4: "Friday",
         5: "Saturday",
         6: "Sunday"}

# 2
class Time(object):
    now = datetime.datetime.now()

    def __init__(self, year=1, month=1, day=1, hour=0, minute=0, second=0):
        self.date = datetime.datetime(year, month, day, hour, minute, second)

today = Time().now
birthday = Time(1983, 3, 31).date

def day_of_week():
    return "1) Today is %s" % rules[today.weekday()]

def birthday_stats(birthday):
    age = today.year - birthday.year
    if (birthday.month == today.month) and (birthday.day <= today.day):
        pass
    elif birthday.month < today.month:
        pass
    else:
        age -= 1
    birthday_ = Time(today.year, birthday.month, birthday.day).date
    till_birthday = str(birthday_ - today).split()
    if len(till_birthday) > 1:
        days = int(till_birthday[0])
        time = till_birthday[2].split(":")
    else:
        days = 365
        time = till_birthday[0].split(":")
    hours = time[0]
    mins = time[1]
    secs = time[2][:2]

    if (days < 0) and (days != 365):
        days = 365 + days
    elif (days == 365):
        days = 0
    else:
        days = abs(days)

    print ("2) You are %s years old; %sd:%sh:%sm:%ss until your next birthday."
    % (age, days, hours, mins, secs))

print day_of_week()
birthday_stats(birthday)

# 3
from datetime import date as date
from datetime import datetime as datetime

def double_day(b1,b2):
    """
        Takes two birthdays as date objects
        and returns a date for their Double Day.
    """
    # Given birthdays b1 and b2, we seek a d such that (d-b1) = 2*(d-b2) => d = 2*b2 - b1. To make sure we don't get a nonsensical answer where d is negative, if 2*b2 - b1 < 0 , return 2*b1 - b2 instead.
    today = date.today()
    b1_age = (today-b1)
    b2_age = (today-b2)
    if b2 > b1:
        d = today - (2*b2_age - b1_age)
    else:
        d = today - (2*b1_age - b2_age)
    return d

b1 = date(1951,7,14)
b2 = date(1989,9,5)
print("Double day for %s and %s: %s" %(b1,b2,double_day(b1,b2)))


# 4
def n_day(b1,b2,n):
    """
        Takes two birthdays as date objects
        and integer n and returns a date for their n-day.
    """
    # Given birthdays b1 and b2, we seek a d such that (d-b1) = n*(d-b2) => d = n*b2 - b1. To make sure we don't get a nonsensical answer where d is negative,if n*b2 - b1 < 0 , return n*b1 - b2 instead.
    today = date.today()
    b1_age = (today-b1)
    b2_age = (today-b2)
    if b2 > b1:
        d = today - (n*b2_age - b1_age)
    else:
        d = today - (n*b1_age - b2_age)
    return d

b1 = date(1949,8,8)
b2 = date(1989,9,5)
print("n=3 day for %s and %s: %s" %(b1,b2,n_day(b1,b2,3)))
# Out:
# 1) Today is Tuesday
# 2) You are 32 years old; 315d:5h:16m:48s until your next birthday.
# Double day for 1951-07-14 and 1989-09-05: 2027-10-29
# n=3 day for 1949-08-08 and 1989-09-05: 2004-01-21

# %% [markdown]
# ## Problem 5
#
# Implement the `Point` class and the `Rectangle` class, with following methods.
#
# 1. Write an `init` method for the Point class that takes `x` and `y` as optional parameters and assigns them to the corresponding attributes.
# 2. Write a `str` method for the Point class.
# 3. Write an `add` method for Points that works with either a Point object or a tuple:
#   * If the second operand is a Point, the method should return a new Point whose `x` coordinate is the sum of the `x` coordinates of the operands, and likewise for the `y` coordinates.
#   * If the second operand is a tuple, the method should add the first element of the tuple to the `x` coordinate and the second element to the `y` coordinate, and return a new Point with the result.
# 4. Write some codes to demonstrate the usage of methods above.

# %%
# Problem 5

#1
print 'problem 5 #1'
class Point(object):
    """Represents a point in 2-D space."""    
    def __init__(self, x=0, y=0):
        self.x = x
        self.y = y
        
    def print_point(point):
        print '(%.d,%.d)' % (point.x, point.y) 

point = Point(2, 3)
point.print_point()

#2
print '\nproblem 5 #2'
class Point(object):
    """Represents a point in 2-D space."""
    def __init__(self, x=0, y=0):
        self.x = x
        self.y = y      

    def __str__(self):
        return '(%.d,%.d)' % (self.x, self.y)
   
point = Point(10, 10)
print point

#3
print '\nproblem 5 #3'       
class Point(object):
    """Represents a point in 2-D space."""
    def __init__(self, x=0, y=0):
        self.x = x
        self.y = y
    
    def __add__(self, other):
        point_ = Point()
        if isinstance(other, Point):
            point_.x += self.x + other.x
            point_.y += self.y + other.y
            return point_
        elif type(other) == tuple:
            point_.x += self.x + other[0]
            point_.y += self.y + other[1]
        return point_

    def __radd__(self, other):
        return self.__add__(other)

    def __str__(self):
        return "(%s, %s)" % (self.x, self.y)

point1 = Point(1, 1)
point2 = (2, 2)
point3 = point1 + point2
point4 = point2 + point1
print point3
print point4


#4
print '\nproblem 5 #4'
class Point(object):
    """Represents a point in 2-D space."""    
    def __init__(self, x=0, y=0):
        self.x = x
        self.y = y
        
    def print_point(point):
        print '(%.d,%.d)' % (point.x, point.y) 
    
    def __str__(self):
        return '(%.d,%.d)' % (self.x, self.y)
    
    def __add__(self, other):
        point_ = Point()
        if isinstance(other, Point):
            point_.x += self.x + other.x
            point_.y += self.y + other.y
            return point_
        elif type(other) == tuple:
            point_.x += self.x + other[0]
            point_.y += self.y + other[1]
        return point_

    def __radd__(self, other):
        return self.__add__(other)

point = Point(20, 20)
point.print_point()  
print point
point1 = Point(1, 1)
point2 = (2, 2)
point3 = point1 + point2
point4 = point2 + point1
print point3
print point4
# Out:
# problem 5 #1
# (2,3)
#
# problem 5 #2
# (10,10)
#
# problem 5 #3
# (3, 3)
# (3, 3)
#
# problem 5 #4
# (20,20)
# (20,20)
# (3,3)
# (3,3)
