# %% [markdown]
# # Homework 4

# %% [markdown]
# ## Problem 1
#
# 1. Implement the `Point` class.
# 2. Implement the `Rectangle` class.
# 3. Write a function called `distance_between_points` that takes two Points as arguments and returns the distance between them.
# 4. Write a function named `move_rectangle` that takes a Rectangle and two numbers named `dx` and `dy`. It should change the location of the rectangle by adding `dx` to the `x` coordinate of corner and adding `dy` to the `y` coordinate of corner.
# 5. Write a function named `move_rectangle_new` that is similar to the `move_rectangle` but it creates and returns a new Rectangle instead of modifying the old one.
# 6. Write some codes to demonstrate the usage of functions above.

# %%
# Problem 1

# 1
class Point(object):
    """Represents a point in 2-D space."""
# 2
class Rectangle(object):
    """Represents a rectangle. 

    attributes: width, height, corner.
    """
# 3
import math
def distance_between_points(x,y):
    return math.sqrt(x**2+y**2)
print distance_between_points(3,4)
# 4
box = Rectangle()
box.width = 100.0
box.height = 200.0
box.corner = Point()
box.corner.x = 0.0
box.corner.y = 0.0
def move_rectangle(dx,dy):
    box.corner.x = box.corner.x+dx
    box.corner.y = box.corner.y+dy
    return(box.corner.x,box.corner.y)
print move_rectangle(6.0,6.0)    
    
#5
import copy
def move_rectangle_new(dx2,dy2) :
    box2 = copy.copy(box)
    box2.corner.x = box2.corner.x+dx2
    box2.corner.y = box2.corner.y+dy2
    return(box2.corner.x,box2.corner.y)
move_rectangle_new(6,7)

#6
import math
def distance_between_points(x,y):
    return math.sqrt(x**2+y**2)

box = Rectangle()
box.width = 100.0
box.height = 200.0
box.corner = Point()
box.corner.x = 0.0
box.corner.y = 0.0
def move_rectangle(dx,dy):
    box.corner.x = box.corner.x+dx
    box.corner.y = box.corner.y+dy
    return(box.corner.x,box.corner.y)

import copy
def move_rectangle_new(dx2,dy2) :
    box2 = copy.copy(box)
    box2.corner.x = box2.corner.x+dx2
    box2.corner.y = box2.corner.y+dy2
    return(box2.corner.x,box2.corner.y)
print move_rectangle_new(6,7)

def f(x,y,dx,dy,dx2,dy2):
    print distance_between_points(x,y)
    print move_rectangle(dx,dy)
    return move_rectangle_new(dx2,dy2)

print f(3,4,5,6,7,8)
# Out:
# 5.0
# (6.0, 6.0)
# (6.0, 7.0)
# 5.0
# (11.0, 13.0)
# (18.0, 21.0)

# %% [markdown]
# ## Problem 2
#
# 1. Implement the `Time` class.
# 2. Write a function called `print_time` that takes a Time object and prints it in the form `hour:minute:second`.
#   **Hint**: the format sequence '%.2d' prints an integer using at least two digits, including a leading zero if necessary.
# 3. Write a boolean function called `is_after` that takes two Time objects, `t1` and `t2`, and returns `True` if `t1` follows `t2` chronologically and `False` otherwise. **Challenge**: don’t use an `if` statement.
# 4. Write a function called `increment_modifier` that adds a given number of seconds to a Time object. It should modify the original time object. It should not contain any loops.
# 5. Write a function called `increment_pure` that adds a given number of seconds to a Time object. It should create and return a new Time object.
# 6. Write a function called `mul_time` that takes a Time object and a number and returns a new Time object that contains the product of the original Time and the number.
# 7. Use `mul_time` to write a function that takes a Time object that represents the finishing time in a race, and a number that represents the distance, and returns a Time object that represents the average pace (time per mile).
# 8. Write some codes to demonstrate the usage of functions above.

# %%
# Problem 2

# 1
class Time(object):
    """Represents the time of day.
    attributes: hour, minute, second
    """
# 2
def print_time(time):
    print '%.2d:%.2d:%.2d' % (time.hour, time.minute, time.second)

time = Time()
time.hour = 10
time.minute = 25
time.second = 31   
print_time(time)
# 3
def print_time(time):
    print '%.2d:%.2d:%.2d' % (time.hour, time.minute, time.second)

time1 = Time()
time1.hour = 10
time1.minute = 25
time1.second = 31   
time2 = Time()
time2.hour = 9
time2.minute = 27
time2.second = 31  

def is_after(t1,t2):
    while time1.hour!=time2.hour:
        return time1.hour>time2.hour
    while time1.minute!=time2.minute:
        return time1.minute>time2.minute
    while time1.second!=time2.second:
         return time1.second>time2.second
    return false

print is_after(time1,time2)

# 4
def increment_modifier(t1,s):
    second=t1.hour*3600+t1.minute*60+t1.second
    second=second+s
    time.hour=second/3600
    time.minute=(second%3600)/60
    time.second=second-(time.hour*3600)-(time.minute*60)
    print '%.2d:%.2d:%.2d' % (time.hour, time.minute, time.second)

increment_modifier(time,11)
# 5
def increment_pure(t1,s):
    second=t1.hour*3600+t1.minute*60+t1.second
    second=second+s
    t=Time()
    t.hour=second/3600
    t.minute=(second%3600)/60
    t.second=second-(t.hour*3600)-(t.minute*60)
    return print_time(t)

increment_pure(time,3)

# 6
def mul_time(t1,s):
    second=t1.hour*3600+t1.minute*60+t1.second
    t2=Time()
    t2.second=second+s
    t2.hour=t2.second/3600
    t2.minute=(t2.second%3600)/60
    t2.second=t2.second-(t2.hour*3600)-(t2.minute*60)
    print 'original time:''%.2d:%.2d:%.2d' % (t1.hour, t1.minute, t1.second)
    print 'product time:''%.2d:%.2d:%.2d' % (t2.hour, t2.minute, t2.second)
    

time1 = Time()
time1.hour = 10
time1.minute = 25
time1.second = 31
mul_time(time1,45)
# 7
    
# 8
# Out:
# 10:25:31
# True
# 10:25:42
# 10:25:45
# original time:10:25:31
# product time:10:26:16

# %% [markdown]
# ## Problem 3
#
# 1. Write a class definition for a Date object that has attributes `day`, `month` and `year`.
# 2. Write a function called `increment_date` that takes a Date object, `date` and an integer, `n`, and returns a new Date object that represents the day `n` days after date.
# 3. **Challenge**: does your function deal with leap years correctly? See http://en.wikipedia.org/wiki/Leap_year.

# %%
class Date(object):
    """attribute day,month and year"""
def increment_date(day1,d):
    day1=Date()
    x=day1.day
    y=day2.month
    z=day3.year
    if y=

# %%
# Problem 3

#1
class Date(object):
    """attribute day,month and year"""

#2
def increment_date(day1,d):
    day1.day=day1.day+d    
    if day1.day>=31 and day1.month==4 or 6 or 9 or 11:
        day1.month=day1.month+1  
        day1.day=day1.day-31
        print '(month,day,year)='+'(%.2d,%.2d,%.2d)' % (day1.month, day1.day, day1.year)
    elif day1.day>=32 and day1.month==1 or 3 or 5 or 7 or 8 or 10 :
        day1.month=day1.month+1  
        day1.day=day1.day-31
        print '(month,day,year)='+'(%.2d,%.2d,%.2d)' % (day1.month, day1.day, day1.year)
    elif day1.day>=29 and day1.month==2:
        day1.day=day1.day-28
        day1.month=3
        print '(month,day,year)='+'(%.2d,%.2d,%.2d)' % (day1.month, day1.day, day1.year)
    elif day1.month>=32 and day1.month==12:
        day1.year=day1.year+1  
        day1.day=day1.day-31
        print '(month,day,year)='+'(%.2d,%.2d,%.2d)' % (day1.month, day1.day, day1.year)
    
day1=Date()
day1.day=30
day1.month=3
day1.year=1994

increment_date(day1,1)

def increment_date(day1,d):
    day1=Date()
    if day1.month==1:
        day=day1.day
    elif day1.month==2:
        day=31+day1.day
    elif day1.month==3:
        day=59+day1.day
    elif day1.month==4:
        day=90+day1.day
    elif day1.month==5:
        day=120+day1.day
    elif day1.month==6:
        day=151+day1.day
    elif day1.month==7:
        day=181+day1.day
    elif day1.month==8:
        day=212+day1.day
    elif day1.month==9:
        day=243+day1.day
    elif day1.month==10:
        day=273+day1.day
    elif day1.month==11:
        day=304+day1.day
    elif day1.month==12:
        day=334+day1.day
    day=day+d
    day.year=day.year+day/365
    if day.month<=31:
        day1.month=1 
    elif 59>=day.month>31:
        day1.month=2
    elif 90>=day.month>59:
        day1.month=3
    elif 120>=day.month>90:
        day.month=4
    elif 151>=day.month>120:
        day.month=5
    elif 181>=day.month>151:
        day.month=6
    elif 212>=day.month>181:
        day.month=7
    return (day.day,day.month,day.year)
day1=Date()
day1.day=20
day1.month=3
day1.year=1994
print increment_date(day1,1)


#3
# Out:
# (month,day,year)=(04,00,1994)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-140-8749b242f7ee> in <module>()
#      79 day1.month=3
#      80 day1.year=1994
# ---> 81 print increment_date(day1,1)
#      82
#      83
#
# <ipython-input-140-8749b242f7ee> in increment_date(day1, d)
#      34 def increment_date(day1,d):
#      35     day1=Date()
# ---> 36     if day1.month==1:
#      37         day=day1.day
#      38     elif day1.month==2:
#
# AttributeError: 'Date' object has no attribute 'month'

# %% [markdown]
# ## Problem 4
#
# The `datetime` module provides date and time objects that are similar to the Date and Time objects in this chapter, but they provide a rich set of methods and operators. Read the documentation at http://docs.python.org/2/library/datetime.html.
#
# 1. Use the `datetime` module to write a program that gets the current date and prints the day of the week.
# 2. Write a program that takes a birthday as input and prints the user’s age and the number of days, hours, minutes and seconds until their next birthday.
# 3. For two people born on different days, there is a day when one is twice as old as the other. That’s their Double Day. Write a program that takes two birthdays and computes their Double Day.
# 4. For a little more challenge, write the more general version that computes the day when one person is `n` times older than the other.

# %%
# Problem 4
#1
class Datetime(object):
    """Attributes: year, month, day, hour, minute, second, microsecond, and tzinfo."""
#2

#3
#4

# %% [markdown]
# ## Problem 5
#
# Implement the `Point` class and the `Rectangle` class, with following methods.
#
# 1. Write an `init` method for the Point class that takes `x` and `y` as optional parameters and assigns them to the corresponding attributes.
# 2. Write a `str` method for the Point class.
# 3. Write an `add` method for Points that works with either a Point object or a tuple:
#   * If the second operand is a Point, the method should return a new Point whose `x` coordinate is the sum of the `x` coordinates of the operands, and likewise for the `y` coordinates.
#   * If the second operand is a tuple, the method should add the first element of the tuple to the `x` coordinate and the second element to the `y` coordinate, and return a new Point with the result.
# 4. Write some codes to demonstrate the usage of methods above.

# %%
# Problem 5

#1
class Rectangle(object):
    """Represents a rectangle. 

    attributes: width, height, corner.
    """
    
    def __init__(self, width=0, height=0, corner.x=0,corner.y=0):
        self.width = width
        self.height = height
        self.corner.x = corner.x
        self.corner.y = corner.y
    
   
    def print_rectangle(self):
        print (self.width, self.height,  self.corner.x, self.corner.y)    
        
    def rectangle_to_int(self):
        minutes = self.hour * 60 + self.minute
        seconds = minutes * 60 + self.second
        return seconds
    
    def increment(self, seconds):
        seconds += self.time_to_int()
        return int_to_time(seconds)

    def is_after(self, other):
        return self.time_to_int() > other.time_to_int()
#2
#3
#4
