# %% [markdown]
# # Homework 4

# %% [markdown]
# ## Problem 1
#
# 1. Implement the `Point` class.
# 2. Implement the `Rectangle` class.
# 3. Write a function called `distance_between_points` that takes two Points as arguments and returns the distance between them.
# 4. Write a function named `move_rectangle` that takes a Rectangle and two numbers named `dx` and `dy`. It should change the location of the rectangle by adding `dx` to the `x` coordinate of corner and adding `dy` to the `y` coordinate of corner.
# 5. Write a function named `move_rectangle_new` that is similar to the `move_rectangle` but it creates and returns a new Rectangle instead of modifying the old one.
# 6. Write some codes to demonstrate the usage of functions above.

# %%
# Problem 1
#8在#1~#7
# 1
class Point(object):
     """Represents a point in 2-D space.""" 
blank=Point() 
blank.x=1
blank.y=2

    
# 2
class Rectangle(object):
    """Represents a rectangle. 
    attributes: width, height, corner.
    """
rect= Rectangle()
rect.width=10
rect.height=20
rect.corner=Point()
rect.corner.x=0.
rect.corner.y=0.


# 3
import math
def distance_between_points():
    dis=Point()
    dis.x=blank.x1-blank.x2
    dis.y=blank.y1-blank.y2
    dis=math.sqrt((dis.x)*(dis.x)+(dis.y)*(dis.y))
    print dis
    
blank.x1=4.
blank.y1=5.
blank.x2=1.
blank.y2=1.  
        
distance_between_points()

# 4
def move_rectangle(dx,dy):
 
    r= Rectangle()
    r.corner=Point()
    r.width=10
    r.height=20
    r.corner.x=2.
    r.corner.y=3.
    r.width=rect.width
    r.height=rect.height
    r.corner.x+=dx
    r.corner.y+=dy
    print 'r.corner=','(',r.corner.x,',',r.corner.y,')'
    print  'r.width=',r.width
    print  'r.height=',r.height
   
move_rectangle(1,2)

# 5
def move_rectangle_new (dx,dy):
    r2=Rectangle()
    r2.corner=Point()
    rect= Rectangle()
    rect.corner=Point()
    rect.width=10
    rect.height=20
    rect.corner.x=2.
    rect.corner.y=3.
    r2.width=rect.width
    r2.height=rect.height
    r2.corner.x=rect.corner.x+dx
    r2.corner.y=rect.corner.y+dy
    print 'r2.corner=','(',r2.corner.x,',',r2.corner.y,')'
    print  'r2.width=',r2.width
    print  'r2.height=',r2.height
   
move_rectangle_new (10,20)
# Out:
# 5.0
# r.corner= ( 3.0 , 5.0 )
# r.width= 10
# r.height= 20
# r2.corner= ( 12.0 , 23.0 )
# r2.width= 10
# r2.height= 20

# %% [markdown]
# ## Problem 2
#
# 1. Implement the `Time` class.
# 2. Write a function called `print_time` that takes a Time object and prints it in the form `hour:minute:second`.
#   **Hint**: the format sequence '%.2d' prints an integer using at least two digits, including a leading zero if necessary.
# 3. Write a boolean function called `is_after` that takes two Time objects, `t1` and `t2`, and returns `True` if `t1` follows `t2` chronologically and `False` otherwise. **Challenge**: don’t use an `if` statement.
# 4. Write a function called `increment_modifier` that adds a given number of seconds to a Time object. It should modify the original time object. It should not contain any loops.
# 5. Write a function called `increment_pure` that adds a given number of seconds to a Time object. It should create and return a new Time object.
# 6. Write a function called `mul_time` that takes a Time object and a number and returns a new Time object that contains the product of the original Time and the number.
# 7. Use `mul_time` to write a function that takes a Time object that represents the finishing time in a race, and a number that represents the distance, and returns a Time object that represents the average pace (time per mile).
# 8. Write some codes to demonstrate the usage of functions above.

# %%
# Problem 2
#8在#1~#7
# 1

class Time(object):
    """Represents the time of day.
    attributes: hour, minute, second
    """
time=Time()    

# 2
def print_time(time):
    print '%.2d:%.2d:%.2d' % (time.hour, time.minute, time.second)

time=Time()
time.hour=23
time.minute=59
time.second=59
print_time(time)

# 3
def is_after():
    t1=Time()
    t1.hour=1
    t1.minute=23
    t1.second=45
    t2=Time()
    t2.hour=2
    t2.minute=34
    t2.second=56
    return t1<t2
print is_after()

# 4
def increment_modifier(s):
    t1=Time()
    t1.hour=1
    t1.minute=59
    t1.second=45
    t1.hour=(t1.hour+(t1.minute+(t1.second+s)/60)/60)%24
    t1.minute=(t1.minute+(t1.second+s)/60)%60
    t1.second=(t1.second+s)%60
    print_time(t1)

increment_modifier(20)

# 5
def increment_pure(s):
    t1=Time()
    t1.hour=1
    t1.minute=59
    t1.second=45
    t2=Time()
    t2.hour=(t1.hour+(t1.minute+(t1.second+s)/60)/60)%24
    t2.minute=(t1.minute+(t1.second+s)/60)%60
    t2.second=(t1.second+s)%60
    print 't1=',
    print_time(t1)
    print 't2=',
    print_time(t2)

increment_pure(80)

# 6
def mul_time(m):
    t1=Time()
    t1.hour=12
    t1.minute=59
    t1.second=45
    t1.hour=(t1.hour*m+(t1.minute*m+(t1.second*m)/60)/60)%24
    t1.minute=(t1.minute*m+(t1.second*m)/60)%60
    t1.second=(t1.second*m)%60
    print_time(t1)
    
mul_time(2)

# 7
def average_pace(x):
    m=1./x
    t1=Time()
    t1.hour=12
    t1.minute=59
    t1.second=45
    t1.hour=(t1.second*m+(t1.minute*m+(t1.hour*m)/24)/60)%60
    t1.minute=(t1.minute*m+(t1.hour*m)/24)%60
    t1.hour=t1.hour*m
    print 'average pace(time/mile) =',
    print_time(t1)
    
average_pace(2)
# 8
# Out:
# 23:59:59
# True
# 02:00:05
# t1= 01:59:45
# t2= 02:01:05
# 01:59:30
# average pace(time/mile) = 11:29:45

# %% [markdown]
# ## Problem 3
#
# 1. Write a class definition for a Date object that has attributes `day`, `month` and `year`.
# 2. Write a function called `increment_date` that takes a Date object, `date` and an integer, `n`, and returns a new Date object that represents the day `n` days after date.
# 3. **Challenge**: does your function deal with leap years correctly? See http://en.wikipedia.org/wiki/Leap_year.

# %%
# Problem 3

#1
class Date(object):
    """Represents the date.
    attributes: day, month, year
    """
date=Date()    
#2
def increment_date(n):
    d1=Date()
    d1.year=2014
    d1.month=12
    d1.day=31
    d2=Date()
    d2.day=(d1.day+n)%31
    d2.month=(d1.month+(d1.day+n)/31)%12
    d2.year=(d1.year+(d1.month+(d1.day+n)/30)/12)


    if d1.month==1 or 2:
         d2.day=d2.day
    if d1.month==3 or 4:
         d2.day-=3
    if d1.month==5 or 6:
         d2.day-=4
    if d1.month==7 or 8 or 9:
         d2.day-=5           
    if d1.month==10 or 11:
         d2.day-=6            
    if d1.month==12:
         d2.day-=7
    if d2.month==1 or 2:
         d2.day=d2.day
    if d2.month==3 or 4:
         d2.day+=3
    if d2.month==5 or 6:
         d2.day+=4
    if d2.month==7 or 8 or 9:
         d2.day+=5            
    if d2.month==10 or 11:
         d2.day+=6            
    if d2.month==12:
         d2.day+=7
    d2.day+=(d2.year-d1.year)*7
    d3=Date()
    d3.year=d2.year
    d3.month=d2.month
    d3.day=d2.day
    if d3.month==1 and d3.day==0:
        d3.year-=1
        d3.month=12
        d3.day=31
    if d3.month== 2 or 4 or 6 or 8 or 9 or 11 and d3.day==0:
        d3.month-=1
        d3.day==31
    if d3.month==4 or 6 or 9 or 11 and d3.day==31:
        d3.month+=1
        d3.day==1
    if d3.month==2 and d3.day>28:
        d3.month==3
        d3.day-=28
        
    print d1.year,'/',d1.month,'/',d1.day
    print d3.year,'/',d3.month,'/',d3.day  
       


increment_date(321)


#3
# Out:
# 2014 / 12 / 31
# 2015 / 11 / 11

# %% [markdown]
# ## Problem 4
#
# The `datetime` module provides date and time objects that are similar to the Date and Time objects in this chapter, but they provide a rich set of methods and operators. Read the documentation at http://docs.python.org/2/library/datetime.html.
#
# 1. Use the `datetime` module to write a program that gets the current date and prints the day of the week.
# 2. Write a program that takes a birthday as input and prints the user’s age and the number of days, hours, minutes and seconds until their next birthday.
# 3. For two people born on different days, there is a day when one is twice as old as the other. That’s their Double Day. Write a program that takes two birthdays and computes their Double Day.
# 4. For a little more challenge, write the more general version that computes the day when one person is `n` times older than the other.

# %%
# Problem 4

#1
import time
from datetime import date
today = date.today()
print today,date.isoweekday(today)

#2

    
a=2002
b=2
c=2
birthday=date(a,b,c)
age=abs(today.year-birthday.year)
print 'age=',age
my_birthday = date(today.year,b,c)
if my_birthday < today:
     my_birthday = my_birthday.replace(year=today.year + 1)
my_birthday

time_to_birthday = abs(my_birthday - today)
print 'time_to_birthday=',time_to_birthday

#3
birthday1=date(1999,9,9)
birthday2=date(2002,2,2)
print 'Double Day=',birthday2+(birthday2-birthday1)
     


#4
n=3
print birthday2+abs(birthday2-birthday1)/(n-1)
# Out:
# 2015-05-19 2
# age= 13
# time_to_birthday= 259 days, 0:00:00
# Double Day= 2004-06-28
# 2003-04-16

# %% [markdown]
# ## Problem 5
#
# Implement the `Point` class and the `Rectangle` class, with following methods.
#
# 1. Write an `init` method for the Point class that takes `x` and `y` as optional parameters and assigns them to the corresponding attributes.
# 2. Write a `str` method for the Point class.
# 3. Write an `add` method for Points that works with either a Point object or a tuple:
#   * If the second operand is a Point, the method should return a new Point whose `x` coordinate is the sum of the `x` coordinates of the operands, and likewise for the `y` coordinates.
#   * If the second operand is a tuple, the method should add the first element of the tuple to the `x` coordinate and the second element to the `y` coordinate, and return a new Point with the result.
# 4. Write some codes to demonstrate the usage of methods above.

# %%
# Problem 5

#1
class Point(object):
    def __init__(self, x=0, y=0):
        self.x = x
        self.y = y

    def print_point(self):
        print "x =", self.x, ",",
        print "y =", self.y

point = Point(1,2)
point.print_point()

#2
class Point(object):
    def __init__(self, x=0, y=0):
        self.x = x
        self.y = y

    def __str__(self):
        return '(%d, %d)' % (self.x, self.y)

point = Point(3,4)
print point
#3
class Point(object):
    def __init__(self, x=0, y=0):
        self.x = x
        self.y = y

    def __str__(self):
        return '(%d, %d)' % (self.x, self.y)

    def __add__(self, other):
        x = self.x + other.x
        y = self.y + other.y
        return Point(x, y)

point1 = Point(1, 2)
point2 = Point(3, 4)

print point1 + point2
#4
# Out:
# x = 1 , y = 2
# (3, 4)
# (4, 6)
