# %% [markdown]
# # Homework 6

# %% [markdown]
# ## Problem 1
#
# Use **ivisual** module to plot the projectile motion with following equations of motion:
#
# $$
# \begin{eqnarray*}
#   m\ddot{x} &=& 0, \\
#   m\ddot{y} &=& -mg, \\
#   m\ddot{z} &=& 0,
# \end{eqnarray*}
# $$
# and initial conditions
#
# $$
#   \vec{r}(0) = (0, 0, 0), \\
#   \vec{v}(0) = (v_{x0}, v_{y0}, 0),
# $$
# You can assign $v_{x0}$ and $v_{y0}$ in the code or ask user to input it.
#
# You should
# * Use a box to represent the ground.
# * Use three arrows to represent the three axes.
# * Use a sphere to represent the ball of the projectile motion.
# * Leave a trail.
# * Stop the simulation when the ball hit the ground.
#
# You should use to ways to calculate the trajectory of the motion.
# 1. Use exact solution: $x(t)=x(0)+v_x t$, etc.
# 2. Use numerical solution:
#  * $v(t+dt) = v(t) + a * dt$.
#  * $x(t+dt) = x(t) + v(t) * dt$.
#
# You should use a small enough $dt$ to ensure the numerical solution is accurate enough.

# %%
# Problem 1
from ivisual import *

scene = canvas()

scene.width = 800
scene.height = 600

scene.autoscale = 0
scene.range = (10,10,30)
scene.center = (0,0,0)

ball = sphere(pos=(0,0,0), radius=0.5, color=color.blue)
ground = box(pos = (0, 0, 0), size = (30, 0.2, 20), color = color.green)
x_axis = arrow(pos = (0, 0, 0), axis = (10, 0, 0), shaftwidth=0.1)
y_axis = arrow(pos = (0, 0, 0), axis = (0, 10, 0), shaftwidth=0.1)
z_axis = arrow(pos = (0, 0, 0), axis = (0, 0, 10), shaftwidth=0.1)
ball.velocity = vector(9,10,0)
vscale = 0.2
varr = arrow(pos=ball.pos, axis=vscale*ball.velocity, color=color.yellow)

ball.trail = curve(color=ball.color)
deltat = 0.01
g = -9.8
ball.velocity.y += g*deltat
t = 0

while t < 10:
    rate(50)
    if ball.pos.y < ground.pos.y:
        break
        
    ball.pos = ball.pos + ball.velocity*deltat
    ball.trail.append(pos=ball.pos)
    ball.velocity.y += g*deltat
    varr.pos = ball.pos
    varr.axis = vscale*ball.velocity
    t = t + deltat

# %% [markdown]
# ## Problem 2
#
# Now introduce the air resistence so the equations of motion become:
#
# $$
# \begin{eqnarray*}
#   m\ddot{x} &=& -km\dot{x}, \\
#   m\ddot{y} &=& -km\dot{y}-mg, \\
#   m\ddot{z} &=& 0,
# \end{eqnarray*}
# $$
# and initial conditions
#
# $$
#   \vec{r}(0) = (0, 0, 0), \\
#   \vec{v}(0) = (v_{x0}, v_{y0}, 0),
# $$
# You can assign $v_{x0}$ and $v_{y0}$ in the code or ask user to input it.
#
# You should
# * Use a box to represent the ground.
# * Use three arrows to represent the three axes.
# * Use a sphere to represent the ball of the projectile motion.
# * Leave a trail.
# * Stop the simulation when the ball hit the ground.
#
#
# You should use to ways to calculate the trajectory of the motion.
# 1. Use exact solution: (Check for example Marion's book).
# 2. Use numerical solution:
#  * $v(t+dt) = v(t) + a * dt$.
#  * $x(t+dt) = x(t) + v(t) * dt$.
#
# You should use a small enough $dt$ to ensure the numerical solution is accurate enough.

# %%
# Problem 2
rom ivisual import *

scene = canvas(title = "Three Dimensions Motion")

scene.width = 800
scene.height = 600

scene.autoscale = 0
scene.range = (10,10,30)
scene.center = (0,0,0)

wall_ground = box(pos = (0, -1, 0), size = (30, 0.2, 20), color = color.blue)
xaxis = arrow(pos = (0, 0, 0), axis = (10, 0, 0), shaftwidth=0.1)
yaxis = arrow(pos = (0, 0, 0), axis = (0, 10, 0), shaftwidth=0.1)
zaxis = arrow(pos = (0, 0, 0), axis = (0, 0, 10), shaftwidth=0.1)
ball = sphere(pos = (0, 0, 0), radius=0.3, color = color.green)

ball.trail = curve(color=ball.color)
ball.velocity = vector(10, 10, 0)
vscale = 0.1
k=5

deltat = 0.005
t=0
while t < 100:
    rate(50)
    if ball.pos.y <=-1:
        break
    ball.velocity.y += -9.8*deltat-k*ball.velocity.y*deltat
    ball.velocity.x += -k*ball.velocity.y*deltat
    ball.pos = ball.pos + ball.velocity*deltat
    ball.trail.append(pos=ball.pos)
    t = t + deltat

# %% [markdown]
# ## Problem 3
#
# Use **ivisual** module to plot the trajectory of a coupled spring-mass system that has two masses, three springs, two walls.
#
# Something like Wall-spring1-mass1-spring2-mass2-spring3-Wall.
#
# You should
# * Use a box to represent the ground.
# * Use two boxes to represent the walls.
# * Use two **cubic** boxes to represent the two masses.
# * Use helix to represent the two srpings.

# %%
# Problem 3
scene = canvas()

scene.width = 800
scene.height = 600

scene.autoscale = 0
scene.range = (10,10,30)
scene.center = (0,0,0)
relaxedlength1 = vector(10,0,0)
relaxedlength2 = vector(10,0,0)
relaxedlength3 = vector(10,0,0)
wall1 = box(pos = (-10.6, 0, 0), size = (0.2, 3, 3), color = color.blue)
wall2 = box(pos = (10.6, 0, 0), size = (0.2, 3, 3), color = color.blue)
ground = box(pos = (0, -1.5, 0), size = (21.2, 0.2, 3), color = color.blue)
spring1 = helix(pos = (-10.4, 0, 0), axis=relaxedlength1, coils = 10, radius = 0.5, color = color.black)
box1 = box(pos = (-3.9, 0, 0), size = (2, 2, 2), color = color.red)
spring2 = helix(pos = (-2.4, 0, 0), axis=relaxedlength2, coils = 10, radius = 0.5, color = color.black)
box2 = box(pos = (4.1, 0, 0), size = (2, 2, 2), color = color.yellow)
spring3 = helix(pos = (5.6, 0, 0), axis=relaxedlength3, coils = 10, radius = 0.5, color = color.black)


g=9.8 
spring1.constant = 1.5
spring2.constant = 1.5
spring3.constant = 1.5
box1.mass = 25 
box2.mass = 25 

box1.pos=vector(0.35,0,0)
spring1.displacement=box1.pos
spring1.axis=relaxedlength1+spring1.displacement
box2.pos=vector(0.7,0,0)
spring2.displacement=box2.pos
spring2.axis=relaxedlength2+spring2.displacement

box1.velocity = vector(0,0,0)
box1.acceleration = vector(0,0,0)
box1.force = vector(0,0,0)
box2.velocity = vector(0,0,0)
box2.acceleration = vector(0,0,0)
box2.force = vector(0,0,0)


def ani():
    dt = .01    
    seconds = 0 
    steps=5000 

    while seconds < dt*steps:
        rate(100)
        seconds = seconds + dt

        SpringForce1 = -spring1.constant * spring1.displacement
        SpringForce2 = -spring2.constant * spring2.displacement
        SpringForce3 = -spring3.constant * spring3.displacement

    
        box1.force = SpringForce1
        box2.force = SpringForce2

        
        box1.velocity += dt*box1.force/box1.mass 
        box1.pos += box1.velocity*dt
        box2.velocity += dt*box2.force/box1.mass 
        box2.pos += box2.velocity*dt

        spring1.displacement=box1.pos
        spring2.displacement=box2.pos

        spring1.axis = relaxedlength1 + spring1.displacement
        spring2.axis = relaxedlength2 + spring2.displacement
        spring3.axis = relaxedlength3 + spring3.displacement

# %% [markdown]
# # Problem 4
#
# Use **ivisual** module to plot the trajectories of 20 particles in a rectangle box.
#
# * The rectangle box has the dimension $L_x$, $L_y$, $L_z$.
# * Use boxes to represent the walls. Keep one wall **invisible**.
# * The 20 particles should have **random** initial velocity.
# * The 20 particles should leave a trail.
# * Make each particle has random RGB color.

# %%
# Problem 4
from ivisual import *
import random

scene = canvas(title = "Free Particle Motion")

scene.width=800
scene.height=600

scene.autoscale = 0
scene.range = (10,10,10)
scene.center = (0,0,0)

wallR = box(pos=(+5,0,0), size=(0.3,10,10), color=color.green)
wallL = box(pos=(-5,0,0), size=(0.3,10,10), color=color.green)
wallU = box(pos=(0,+5,0), size=(10,0.3,10), color=color.blue)
wallD = box(pos=(0,-5,0), size=(10,0.3,10), color=color.blue)
wallB = box(pos=(0,0,-5), size=(10,10,0.3), color=color.red)

ball=[] 
for i in range(20):
    ball.append(sphere(pos=(random.uniform(-5,5),random.uniform(-5,5),random.uniform(-5,5)),radius=0.3,color=(random.random(),random.random(),random.random())))
    ball[len(ball)-1].velocity=vector(random.uniform(-30,30),random.uniform(-30,30),random.uniform(-30,30))
    ball[len(ball)-1].trail=curve(color=ball[len(ball)-1].color)

dt=0.005
t=0

while t<10:
    rate(50)
    for i in range(len(ball)):
        if ball[i].pos.x>wallR.pos.x:
            ball[i].velocity.x=-ball[i].velocity.x
        if ball[i].pos.x<wallL.pos.x:
            ball[i].velocity.x=-ball[i].velocity.x
        if ball[i].pos.y>wallU.pos.y:
            ball[i].velocity.y=-ball[i].velocity.y
        if ball[i].pos.y<wallD.pos.y:
            ball[i].velocity.y=-ball[i].velocity.y   
        if ball[i].pos.z<wallB.pos.z:
            ball[i].velocity.z=-ball[i].velocity.z
        if ball[i].pos.z > 6: 
            ball[i].velocity.z=-ball[i].velocity.z
            
        ball[i].pos=ball[i].pos+ball[i].velocity*dt
        ball[i].trail.append(pos=ball[i].pos)
        
    t=t+dt
