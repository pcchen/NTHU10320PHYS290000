# %% [markdown]
# # Homework 6

# %% [markdown]
# ## Problem 1
#
# Use **ivisual** module to plot the projectile motion with following equations of motion:
#
# $$
# \begin{eqnarray*}
#   m\ddot{x} &=& 0, \\
#   m\ddot{y} &=& -mg, \\
#   m\ddot{z} &=& 0,
# \end{eqnarray*}
# $$
# and initial conditions
#
# $$
#   \vec{r}(0) = (0, 0, 0), \\
#   \vec{v}(0) = (v_{x0}, v_{y0}, 0),
# $$
# You can assign $v_{x0}$ and $v_{y0}$ in the code or ask user to input it.
#
# You should
# * Use a box to represent the ground.
# * Use three arrows to represent the three axes.
# * Use a sphere to represent the ball of the projectile motion.
# * Leave a trail.
# * Stop the simulation when the ball hit the ground.
#
# You should use to ways to calculate the trajectory of the motion.
# 1. Use exact solution: $x(t)=x(0)+v_x t$, etc.
# 2. Use numerical solution:
#  * $v(t+dt) = v(t) + a * dt$.
#  * $x(t+dt) = x(t) + v(t) * dt$.
#
# You should use a small enough $dt$ to ensure the numerical solution is accurate enough.

# %%
from ivisual import *

# %%
scene = canvas(title = "Problem 1")

scene.width = 600
scene.height = 500

scene.autoscale = 0
scene.range = (15,15,20)
scene.center = (0,0,0)

ground = box(pos = (0, -10, 0), size = (10, 10, 10), color = color.red)
x_axis = arrow(pos = (0, 0, 0), axis = (10, 0, 0), shaftwidth=0.2)
y_axis = arrow(pos = (0, 0, 0), axis = (0, 10, 0), shaftwidth=0.2)
z_axis = arrow(pos = (0, 0, 0), axis = (0, 0, 10), shaftwidth=0.2)
ball = sphere(pos = (0, 0, 0), radius=0.5, color = color.blue)

ball.trail = curve(color=ball.color)
ball.velocity = vector(3, 0.1, 0)
vscale = 0.1
deltat = 0.01
t=0
g = -9.8
ball.velocity.y += g*deltat

while t < 50:
    rate(50)
    if ball.pos.y -5 < ground.pos.y:
        break
        
    ball.pos = ball.pos + ball.velocity*deltat
    ball.trail.append(pos=ball.pos)
    ball.velocity.y += g*deltat
    t = t + deltat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8f79b60e2a8f> in <module>()
#       1
# ----> 2 scene = canvas(title = "Problem 1")
#       3
#       4 scene.width = 600
#       5 scene.height = 500
#
# NameError: name 'canvas' is not defined

# %% [markdown]
# ## Problem 2
#
# Now introduce the air resistence so the equations of motion become:
#
# $$
# \begin{eqnarray*}
#   m\ddot{x} &=& -km\dot{x}, \\
#   m\ddot{y} &=& -km\dot{y}-mg, \\
#   m\ddot{z} &=& 0,
# \end{eqnarray*}
# $$
# and initial conditions
#
# $$
#   \vec{r}(0) = (0, 0, 0), \\
#   \vec{v}(0) = (v_{x0}, v_{y0}, 0),
# $$
# You can assign $v_{x0}$ and $v_{y0}$ in the code or ask user to input it.
#
# You should
# * Use a box to represent the ground.
# * Use three arrows to represent the three axes.
# * Use a sphere to represent the ball of the projectile motion.
# * Leave a trail.
# * Stop the simulation when the ball hit the ground.
#
#
# You should use to ways to calculate the trajectory of the motion.
# 1. Use exact solution: (Check for example Marion's book).
# 2. Use numerical solution:
#  * $v(t+dt) = v(t) + a * dt$.
#  * $x(t+dt) = x(t) + v(t) * dt$.
#
# You should use a small enough $dt$ to ensure the numerical solution is accurate enough.

# %%
scene = canvas(title = "Problem 2")

scene.width = 600
scene.height = 500

scene.autoscale = 0
scene.range = (15,15,20)
scene.center = (0,0,0)

ground = box(pos = (0, -20, 0), size = (20, 20, 20), color = color.red)
x_axis = arrow(pos = (0, 0, 0), axis = (10, 0, 0), shaftwidth=0.2)
y_axis = arrow(pos = (0, 0, 0), axis = (0, 10, 0), shaftwidth=0.2)
z_axis = arrow(pos = (0, 0, 0), axis = (0, 0, 10), shaftwidth=0.2)
ball = sphere(pos = (0, 0, 0), radius=0.5, color = color.blue)

ball.trail = curve(color=ball.color)
ball.velocity = vector(5, 0.1, 0)
vscale = 0.1
deltat = 0.005
t=0
g = -9.8
k = -1
ax = k*ball.velocity.x
ay = k*ball.velocity.y + g
ball.velocity.x += ax*deltat
ball.velocity.y += ay*deltat

while t < 50:
    rate(50)
    if ball.pos.y -10 < ground.pos.y:
        break
        
    ball.pos = ball.pos + ball.velocity*deltat
    ball.trail.append(pos=ball.pos)
    ball.velocity.y += g*deltat
    t = t + deltat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7f58413c53b6> in <module>()
# ----> 1 scene = canvas(title = "Problem 2")
#       2
#       3 scene.width = 600
#       4 scene.height = 500
#       5
#
# NameError: name 'canvas' is not defined

# %% [markdown]
# ## Problem 3
#
# Use **ivisual** module to plot the trajectory of a coupled spring-mass system that has two masses, three springs, two walls.
#
# Something like Wall-spring1-mass1-spring2-mass2-spring3-Wall.
#
# You should
# * Use a box to represent the ground.
# * Use two boxes to represent the walls.
# * Use two **cubic** boxes to represent the two masses.
# * Use helix to represent the two srpings.

# %%
scene = canvas(title = "Problem 3")

scene.width = 900
scene.height = 700
scene.autoscale = 0
scene.range = (600,300,300)
scene.center = (0,0,0)

ground = box(pos=(0,-5,0), axis=(1,0,0), length=420, height=10, width=100)

left_wall = box(pos=(-205,50,0),length=10,width=100,height=100)

left_wall = box(pos=(205,50,0),length=10,width=100,height=100)

left_box = box(pos=(-75,25,0), length=50,width=50,height=50,color=color.blue)

right_box = box(pos=(75,25,0), length=50,width=50,height=50,color=color.blue)

left_spring = helix(pos=(-200,25,0),axis=(1,0,0),radius=15,coils=5,length=100,thickness=1.5,color=color.red)

mid_spring = helix(pos=(-50,25,0),axis=(1,0,0),radius=15,coils=5,length=100,thickness=1.5,color=color.red)

right_spring = helix(pos=(200,25,0),axis=(-1,0,0),radius=15,coils=5,length=100,thickness=1.5,color=color.red)

left_box_velocity=0
mid_box_velocity=0
right_box_velocity=0

k=3                            
t=0                            
v1=100                          
v2=-100                         
dt=0.05                       
r=1/dt                        

while t<10:
    rate(r)
    t+=dt
    
    left_box.pos.x=left_box.pos.x+v1*dt
    right_box.pos.x=right_box.pos.x+v2*dt
    
    ldl=left_box.pos.x+75
    mdl=right_box.pos.x-left_box.pos.x-150
    rdl=75-right_box.pos.x
    
    left_spring.length=100+ldl
    mid_spring.length=100+mdl
    mid_spring.pos.x=-50+ldl
    mid_spring.pos=mid_spring.pos
    right_spring.length=100+rdl
    
    
    v1=v1-ldl*dt*k+mdl*dt*k
    v2=v2-mdl*dt*k+rdl*dt*k
    
    
    
    left_box.pos=left_box.pos
    right_box.pos=right_box.pos

# %% [markdown]
# # Problem 4
#
# Use **ivisual** module to plot the trajectories of 20 particles in a rectangle box.
#
# * The rectangle box has the dimension $L_x$, $L_y$, $L_z$.
# * Use boxes to represent the walls. Keep one wall **invisible**.
# * The 20 particles should have **random** initial velocity.
# * The 20 particles should leave a trail.
# * Make each particle has random RGB color.

# %%
# Problem 4
