# %% [markdown]
# # Homework 4

# %% [markdown]
# ## Problem 1
#
# 1. Implement the `Point` class.
# 2. Implement the `Rectangle` class.
# 3. Write a function called `distance_between_points` that takes two Points as arguments and returns the distance between them.
# 4. Write a function named `move_rectangle` that takes a Rectangle and two numbers named `dx` and `dy`. It should change the location of the rectangle by adding `dx` to the `x` coordinate of corner and adding `dy` to the `y` coordinate of corner.
# 5. Write a function named `move_rectangle_new` that is similar to the `move_rectangle` but it creates and returns a new Rectangle instead of modifying the old one.
# 6. Write some codes to demonstrate the usage of functions above.

# %%
# Problem 1

# 1
class Point(object):
        """attributes:x and y"""
        
#2
class rectangle(object):
        """attributes:width,height and couner"""

# 3
import math  
def distance_between_points(p1,p2):
    x= p1.x - p2.x
    y= p1.y - p2.y
    distance = math.sqrt(x**2+y**2)
    return distance
a=Point()
b=Point()
a.x= 4
a.y= 5
b.x= 7
b.y= 9
print 'distance=',distance_between_points(a,b)

# 4
def move_rectangle(rect,dx,dy):
    rect.couner.x = rect.couner.x + dx
    rect.couner.y = rect.couner.y + dy

box = rectangle()
box.couner = Point()
box.couner.x = 0
box.couner.y = 0
move_rectangle(box,5,5)
print box.couner.x,box.couner.y

# 5
import copy
def move_rect_new(rect,dx,dy):
    box1=copy.copy(rect)
    move_rectangle(box1,dx,dy)
    return box1
print box
print move_rect_new(box,5,10) #the location of memories is not the same
# Out:
# distance= 5.0
# 5 5
# <__main__.rectangle object at 0x0000000003D061D0>
# <__main__.rectangle object at 0x0000000003CDCC50>

# %% [markdown]
# ## Problem 2
#
# 1. Implement the `Time` class.
# 2. Write a function called `print_time` that takes a Time object and prints it in the form `hour:minute:second`.
#   **Hint**: the format sequence '%.2d' prints an integer using at least two digits, including a leading zero if necessary.
# 3. Write a boolean function called `is_after` that takes two Time objects, `t1` and `t2`, and returns `True` if `t1` follows `t2` chronologically and `False` otherwise. **Challenge**: don’t use an `if` statement.
# 4. Write a function called `increment_modifier` that adds a given number of seconds to a Time object. It should modify the original time object. It should not contain any loops.
# 5. Write a function called `increment_pure` that adds a given number of seconds to a Time object. It should create and return a new Time object.
# 6. Write a function called `mul_time` that takes a Time object and a number and returns a new Time object that contains the product of the original Time and the number.
# 7. Use `mul_time` to write a function that takes a Time object that represents the finishing time in a race, and a number that represents the distance, and returns a Time object that represents the average pace (time per mile).
# 8. Write some codes to demonstrate the usage of functions above.

# %%
# Problem 2
from time import *
# 1
class time(object):
    """attributes: hour, minute, second"""
    
# 2
print 'no.2'
def t_to_s(t):                    #convert hour:minute:second   --> pure second
    return (t.hour*3600 + t.minute*60 + t.second)  
def s_to_t(s):                   #convert pure second   -->   hour:minute:second   
    t = time()
    hour,remain = divmod(s,3600)
    if hour > 24:
        hour = 0 + (hour-24)
    minute,second = divmod(remain,60)
    t.hour,t.minute,t.second = (hour,minute,second)
    return t
def print_time(time):
    print '%.2d : %.2d : %.2d' % (time.hour,time.minute,time.second) 

t = time()
t.hour = 5
t.minute = 30
t.second = 30
print_time(t)

# 3
print 'no.3'
def is_after(t1,t2):
    if (t1.hour*3600+t1.minute*60+t1.second)>(t2.hour*3600+t2.minute*60+t2.second):
        return False
    else:
        return True

tn=time()
tn.hour=5
tn.minute=30
tn.second=45
print is_after(t,tn)

# 4
print 'no.4'
def increment_modifier(t1,n):
    s = t1.hour*3600 + t1.minute*60 + t1.second
    total = s*n
    t1.hour = total / 3600
    t1.minute = (total%3600) / 60
    t1.second = total % 60
    print_time(t1)
    
increment_modifier(t,2)

# 5
print 'no.5'
def increment_pure(t1,n):
    s=t1.hour*3600+t1.minute*60+t1.second
    total=s*n
    x=time()
    x.hour=total/3600
    x.minute=(total%3600)/60
    x.second=total%60
    print_time(x)
    
increment_pure(t,2)

# 6
print 'no.6'
def mul_time(t1,n):
    s=t1.hour*3600+t1.minute*60+t1.second
    x=time()
    total=s*n
    x.hour=total/3600
    x.minute=(total%3600)/60
    x.second=total%60
    print 'oritinal time=',
    print_time(t1)
    print 'n=',n
    print 'product time=',
    print_time(x)
mul_time(t,2)

# 7
print 'no.7'
def mul_time(t,n):
    t_s = t_to_s(t)
    t_s = t_s * n  
    t_new = s_to_t(t_s)
    print_time(t_new)

t1 = time()
t1.hour = 11
t1.minute =23
t1.second = 05
mul_time(t1, 2)

# 8
print 'no.8'
def average_pace(time,distance):           #distance should be input with mile
    t_s = t_to_s(time)
    pace = t_s/distance
    time_pace = s_to_t(pace)
    print_time(time_pace)

average_pace(t1,200)
# Out:
# no.2
# 05 : 30 : 30
# no.3
# True
# no.4
# 11 : 01 : 00
# no.5
# 22 : 02 : 00
# no.6
# oritinal time= 11 : 01 : 00
# n= 2
# product time= 22 : 02 : 00
# no.7
# 22 : 46 : 10
# no.8
# 00 : 03 : 24

# %% [markdown]
# ## Problem 3
#
# 1. Write a class definition for a Date object that has attributes `day`, `month` and `year`.
# 2. Write a function called `increment_date` that takes a Date object, `date` and an integer, `n`, and returns a new Date object that represents the day `n` days after date.
# 3. **Challenge**: does your function deal with leap years correctly? See http://en.wikipedia.org/wiki/Leap_year.

# %%
import copy

class Date(object):
    """attributes: month, day, year"""

month_rules = {1: 31,
         2: 28,
         3: 31,
         4: 30,
         5: 31,
         6: 30,
         7: 31,
         8: 31,
         9: 30,
         10: 31,
         11: 30,
         12: 31}

names = {1: "January",
         2: "Feburary",
         3: "March",
         4: "April",
         5: "May",
         6: "June",
         7: "July",
         8: "August",
         9: "September",
         10: "October",
         11: "November",
         12: "December"}




date = Date()
date.month = 10
date.day = 30
date.year = 2012


def increment_date(date, inc):
    date_ = copy.deepcopy(date)
    while True:

        # adjust feb for leap year
        month_rules[2] = 28
        if (date_.year % 4 == 0 and date_.year % 100 != 0):
            month_rules[2] = 29
        elif (date_.year % 400 == 0):
            month_rules[2] = 29
        elif date_.month != 2:
            pass

        days_left = month_rules[date_.month] - date_.day

        # set date_.day based on value of days_left and inc
        if inc <= days_left:
            date_.day += inc
            break
        elif inc == 0:
            date_.day = month_rules[date_.month]
            break
        elif inc < 0:
            date_.day = month_rules[date_.month] + inc
            break
        else:
            inc -= month_rules[date_.month]
            date_.month += 1

        # increment year if month counter pushes past 12
        if date_.month > 12:
            date_.year += 1
            date_.month = 1

    # final adjustment of date if previous year was a leap year
    if ((date_.year - 1) % 4 == 0 and date_.year % 100 != 0) and date_.month != 2:
        date_.day -= 1
    elif (date_.year % 400 == 0) and date_.month != 2:
        date_.day -= 1

    #final ui element
#    print "Ending: %s %s, %s" % (names[date_.month], date_.day, date_.year)
    return date_

newDate = increment_date(date, 365)

print date, "%s %s, %s" % (names[date.month], date.day, date.year)
print newDate, "%s %s, %s" % (names[newDate.month], newDate.day, newDate.year)
# Out:
# <__main__.Date object at 0x0000000003D04550> October 30, 2012
# <__main__.Date object at 0x0000000003BEF978> October 29, 2013

# %% [markdown]
# ## Problem 4
#
# The `datetime` module provides date and time objects that are similar to the Date and Time objects in this chapter, but they provide a rich set of methods and operators. Read the documentation at http://docs.python.org/2/library/datetime.html.
#
# 1. Use the `datetime` module to write a program that gets the current date and prints the day of the week.
# 2. Write a program that takes a birthday as input and prints the user’s age and the number of days, hours, minutes and seconds until their next birthday.
# 3. For two people born on different days, there is a day when one is twice as old as the other. That’s their Double Day. Write a program that takes two birthdays and computes their Double Day.
# 4. For a little more challenge, write the more general version that computes the day when one person is `n` times older than the other.

# %%
import datetime

rules = {0: "Monday",1: "Tuesday", 2: "Wednesday",3: "Thursday",4: "Friday",5: "Saturday",6: "Sunday"}

class Time(object):
    now = datetime.datetime.now()

    def __init__(self, year=1, month=1, day=1, hour=0, minute=0, second=0):
        self.date = datetime.datetime(year, month, day, hour, minute, second)

today = Time().now
birthday = Time(1983, 3, 31).date


def day_of_week():
    return "1) Today is %s" % rules[today.weekday()]


def birthday_stats(birthday):
    age = today.year - birthday.year
    if (birthday.month == today.month) and (birthday.day <= today.day):
        pass
    elif birthday.month < today.month:
        pass
    else:
        age -= 1

    birthday_ = Time(today.year, birthday.month, birthday.day).date
    till_birthday = str(birthday_ - today).split()

    if len(till_birthday) > 1:
        days = int(till_birthday[0])
        time = till_birthday[2].split(":")
    else:
        days = 365
        time = till_birthday[0].split(":")

    hours = time[0]
    mins = time[1]
    secs = time[2][:2]

    if (days < 0) and (days != 365):
        days = 365 + days
    elif (days == 365):
        days = 0
    else:
        days = abs(days)

    print ("2) You are %s years old; %sd:%sh:%sm:%ss until your next birthday."
    % (age, days, hours, mins, secs))

print day_of_week()
birthday_stats(birthday)
# Out:
# 1) Today is Tuesday
# 2) You are 32 years old; 315d:5h:48m:19s until your next birthday.

# %% [markdown]
# ## Problem 5
#
# Implement the `Point` class and the `Rectangle` class, with following methods.
#
# 1. Write an `init` method for the Point class that takes `x` and `y` as optional parameters and assigns them to the corresponding attributes.
# 2. Write a `str` method for the Point class.
# 3. Write an `add` method for Points that works with either a Point object or a tuple:
#   * If the second operand is a Point, the method should return a new Point whose `x` coordinate is the sum of the `x` coordinates of the operands, and likewise for the `y` coordinates.
#   * If the second operand is a tuple, the method should add the first element of the tuple to the `x` coordinate and the second element to the `y` coordinate, and return a new Point with the result.
# 4. Write some codes to demonstrate the usage of methods above.

# %%
# Problem 5
class Point(object):
    ''' note '''
    def __init__(self, x, y):
       self.x = x
       self.y = y
    def __str__(self):
        return '%d, %d' %(self.x,self.y)
    def add(self,p2):
        if type(p2) == tuple:
            t1,t2 = p2
            x = self.x + t1
            y = self.y + t2
            np = Point(x,y)
        else:
            x = self.x + p2.x
            y = self.y + p2.y
            np = Point(x,y)
        return '%d, %d'    %(np.x, np.y)
        

p1 = Point(3, 4)   
p2 = Point(4, 4)

print p1           
t = (1,2)

print p1.add(t)
print p1.add(p2)
# Out:
# 3, 4
# 4, 6
# 7, 8
