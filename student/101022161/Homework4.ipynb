# %% [markdown]
# # Homework 4

# %% [markdown]
# ## Problem 1
#
# 1. Implement the `Point` class.
# 2. Implement the `Rectangle` class.
# 3. Write a function called `distance_between_points` that takes two Points as arguments and returns the distance between them.
# 4. Write a function named `move_rectangle` that takes a Rectangle and two numbers named `dx` and `dy`. It should change the location of the rectangle by adding `dx` to the `x` coordinate of corner and adding `dy` to the `y` coordinate of corner.
# 5. Write a function named `move_rectangle_new` that is similar to the `move_rectangle` but it creates and returns a new Rectangle instead of modifying the old one.
# 6. Write some codes to demonstrate the usage of functions above.

# %%
# Problem 1
import math
# 1
class Point(object):
    """Represents a point in 2-D space."""
# 2
class Rectangle(object):
    """Represents a rectangle. 
    attributes: width, height, corner.
    """
# 3
def distance_between_points(a,b):
    distance=math.sqrt(float((a.x-b.x)**2)+float(a.y-b.y)**2)
    return distance

# 4
def move_rectangle(rectangle,dx,dy):
    rectangle.corner.x=rectangle.corner.x+dx
    rectangle.corner.y=rectangle.corner.y+dy

# 5
def move_rectangle_new(rectangle,dx,dy):
    new_rect=Rectangle()
    new_rect.width=rectangle.width
    new_rect.height=rectangle.height
    new_rect.corner = Point()
    new_rect.corner.x =rectangle.corner.x+dx
    new_rect.corner.y =rectangle.corner.y+dy
    return new_rect
# 6
    #test-3
print 'test-3'
a=Point()
a.x=1
a.y=2
b=Point()
b.x=4
b.y=6
print '(1,2) and (4,6) distance=',distance_between_points(a,b)
    #test-4
print  'test-4'
rect1=Rectangle()
rect1.width=50
rect1.height=100
rect1.corner = Point()
rect1.corner.x = 0.0
rect1.corner.y = 0.0
print 'old corner1=(%g,%g) and (dx,dy)=(50,60)'%(rect1.corner.x,rect1.corner.y)
move_rectangle(rect1,50.0,60.0)
print 'new corner1=(%g,%g)'%(rect1.corner.x,rect1.corner.y)
    #test-5
print 'test-5'
rect2=Rectangle()
rect2.width=50
rect2.height=100
rect2.corner = Point()
rect2.corner.x = 10.0
rect2.corner.y = 20.0
print 'old corner2=(%g,%g) and (dx,dy)=(90,120)'%(rect2.corner.x,rect2.corner.y)
new_rect2=move_rectangle_new(rect2,90,120)
print 'new corner2=(%g,%g)'%(new_rect2.corner.x,new_rect2.corner.y)
# Out:
# test-3
# (1,2) and (4,6) distance= 5.0
# test-4
# old corner1=(0,0) and (dx,dy)=(50,60)
# new corner1=(50,60)
# test-5
# old corner2=(10,20) and (dx,dy)=(90,120)
# new corner2=(100,140)

# %% [markdown]
# ## Problem 2
#
# 1. Implement the `Time` class.
# 2. Write a function called `print_time` that takes a Time object and prints it in the form `hour:minute:second`.
#   **Hint**: the format sequence '%.2d' prints an integer using at least two digits, including a leading zero if necessary.
# 3. Write a boolean function called `is_after` that takes two Time objects, `t1` and `t2`, and returns `True` if `t1` follows `t2` chronologically and `False` otherwise. **Challenge**: don’t use an `if` statement.
# 4. Write a function called `increment_modifier` that adds a given number of seconds to a Time object. It should modify the original time object. It should not contain any loops.
# 5. Write a function called `increment_pure` that adds a given number of seconds to a Time object. It should create and return a new Time object.
# 6. Write a function called `mul_time` that takes a Time object and a number and returns a new Time object that contains the product of the original Time and the number.
# 7. Use `mul_time` to write a function that takes a Time object that represents the finishing time in a race, and a number that represents the distance, and returns a Time object that represents the average pace (time per mile).
# 8. Write some codes to demonstrate the usage of functions above.

# %%
# Problem 2

# 1
class Time(object):
    """Represents the time of day.
    attributes: hour, minute, second
    """
# 2
def print_time(a):
    print '%.2d : %.2d : %.2d'%(a.hour,a.minute,a.second)

# 3 -challenge:don't use if
def is_after(t1,t2):
    total_t1=t1.hour*3600+t1.minute*60+t1.second
    total_t2=t2.hour*3600+t2.minute*60+t2.second
    return total_t1>total_t2

# 4
def increment_modifier(t,sec):
    t.second=t.second+sec
    while t.second>=60:
        t.second=t.second-60
        t.minute=t.minute+1
    while t.minute>=60:
        t.minute=t.minute-60
        t.hour=t.hour+1 
# 5
def increment_pure(t,sec):
    x=Time()
    x.hour=t.hour
    x.minute=t.minute
    x.second=t.second+sec
    while x.second>=60:
        x.second=x.second-60
        x.minute=x.minute+1
    while x.minute>=60:
        x.minute=x.minute-60
        x.hour=x.hour+1 
    return x
# 6
def mul_time(t,n):
    x=Time()
    x.hour=t.hour*n
    x.minute=t.minute*n
    x.second=t.second*n
    while x.second>=60:
        x.second=x.second-60
        x.minute=x.minute+1
    while x.minute>=60:
        x.minute=x.minute-60
        x.hour=x.hour+1 
    return x

# 7
def average_pace(t,n):
    x=Time()
    y=3600*t.hour+60*t.minute+t.second
    x.second=float(y)/float(n)
    x.hour=0
    x.minute=0
    while x.second>=60:
        x.second=x.second-60
        x.minute=x.minute+1
    while x.minute>=60:
        x.minute=x.minute-60
        x.hour=x.hour+1 
    return x
# 8
    #test-2
print 'test-2'
time=Time()
time.hour = 9
time.minute = 35
time.second = 46
print_time(time)
#test-3
print'test-3-challenge:don\'t use if'
t1=Time()
t1.hour=9
t1.minute=27
t1.second=50
t2=Time()
t2.hour=9
t2.minute=28
t2.second=50
print 't1=',
print_time(t1)
print 't2=',
print_time(t2)
if is_after(t1,t2):
    print 'True'
else:
    print 'False'
#test-4
print 'test-4'
time_test=Time()
time_test.hour=2
time_test.minute=57
time_test.second=52
print '修改前t=',
print_time(time_test)
increment_modifier(time_test,50)
print '修改後t=',
print_time(time_test)
    #test-5
print 'test-5'
time_test2=Time()
time_test2.hour=3
time_test2.minute=56
time_test2.second=51
print '修改前t2=',
print_time(time_test2)
time_test2_new=increment_pure(time_test2,110)
print '修改後t2=',
print_time(time_test2_new)
    #test-6
print 'test-6'
time_test3=Time()   
time_test3.hour=2
time_test3.minute=40
time_test3.second=50
print '修改前t3=',
print_time(time_test3)
time_test3_new=mul_time(time_test3,2)  #乘2前：9650sec =>02:40:50 乘2後：19300sec => 05:21:40
print '修改後t3=',
print_time(time_test3_new)
    #test-7
print 'test-7'
time_test4=Time()   
time_test4.hour=2
time_test4.minute=40
time_test4.second=50
print 't4=',
print_time(time_test4)
distance=4825.0
print 'distance=%g mile'%(distance)
ave_pace=average_pace(time_test3,distance)  #總秒數:9650sec 距離:4825mile
print 'average_pace(sec/mile)=',
print_time(ave_pace)
# Out:
# test-2
# 09 : 35 : 46
# test-3-challenge:don't use if
# t1= 09 : 27 : 50
# t2= 09 : 28 : 50
# False
# test-4
# 修改前t= 02 : 57 : 52
# 修改後t= 02 : 58 : 42
# test-5
# 修改前t2= 03 : 56 : 51
# 修改後t2= 03 : 58 : 41
# test-6
# 修改前t3= 02 : 40 : 50
# 修改後t3= 05 : 21 : 40
# test-7
# t4= 02 : 40 : 50
# distance=4825 mile
# average_pace(sec/mile)= 00 : 00 : 02

# %% [markdown]
# ## Problem 3
#
# 1. Write a class definition for a Date object that has attributes `day`, `month` and `year`.
# 2. Write a function called `increment_date` that takes a Date object, `date` and an integer, `n`, and returns a new Date object that represents the day `n` days after date.
# 3. **Challenge**: does your function deal with leap years correctly? See http://en.wikipedia.org/wiki/Leap_year.

# %%
# Problem 3

#1
class Date(object):
    """Represents the date.
    attributes: year, month, day
    """
#2 先用一年=365天，不考慮閏年
def print_date(a):
    print '%d . %d . %d'%(a.year,a.month,a.day)
 
    
def month365(month):
    a=[0,31,59,90,120,151,181,212,243,273,304,334,365]
    return a[month-1]
    
def increment_date(date,n):
    x=Date()
    x.year=0
    x.month=0
    x.day=0
    t=(date.year-1)*365+month365(date.month)+date.day+n
    x.year=(t/365)+1
    y=t%365
    i=1
    while i<=12:
        if y>=month365(i)+1 and y<=month365(i+1):
            x.month=i
            x.day=y-month365(i)
        i=i+1
    if y==0:
        x.year=x.year-1
        x.month=12 
        x.day=31
    return x
date=Date()
date.year=534
date.month=12
date.day=30

new_date=Date()
new_date=increment_date(date,2)
print_date(new_date)
#3-3在下框
# Out:
# 535 . 1 . 1

# %%
# Problem 3-3-考慮閏年
class Date(object):
    """Represents the date.
    attributes: year, month, day
    """
def print_date(a):
    print '%d . %d . %d'%(a.year,a.month,a.day)

def month365(month):   #month366為閏年,month365為正常年
    a=[0,31,59,90,120,151,181,212,243,273,304,334,365]
    return a[month-1]
def month366(month):
    b=[0,31,60,91,121,152,182,213,244,274,305,335,366]
    return b[month-1]    
    
def increment_date_leap(date,n):
    # a:正常年 b:閏年 c:不一定，再判斷    
    x=Date()
    if (date.year%400==0) or (date.year%4==0 and date.year%100!=0):
        t=month366(date.month)+date.day+n    
        if t<=366:
            x=b(date,t)
        if t>366:    
            x=c(date,t)
    if (date.year%4!=0) or (date.year%100==0 and date.tear%400!=0):
        t=month365(date.month)+date.day+n
        if t<=365:    
            x=a(date,t)
        if t>365:
            x=c(date,t)
    return x
def a(date,t):
    x=Date()
    x.year=date.year
    x.month=0
    x.day=0
    i=1
    while i<=12:
        if t>=month365(i)+1 and t<=month365(i+1):
            x.month=i
            x.day=t-month365(i)
        i=i+1
    return x

def b(date,t):
    x=Date()
    x.year=date.year
    x.month=0
    x.day=0
    i=1
    while i<=12:
        if t>=month366(i)+1 and t<=month366(i+1):
            x.month=i
            x.day=t-month366(i)
        i=i+1
    return x

def c(date,t):
    x=Date()
    x.year=date.year
    x.month=date.month
    x.day=date.day    
    t2=t  #避免和t=t-366,t-365後的t衝到
    if (date.year%400==0) or (date.year%4==0 and date.year%100!=0):
        if t>366:
            t=t-366
            x.year=x.year+1
            x=c(x,t)
        if t2<=366:
            x=b(x,t)  
    if (date.year%4!=0) or (date.year%100==0 and date.tear%400!=0):
        if t>365:
            t=t-365
            x.year=x.year+1
            x=c(x,t)
        if t2<=365:
            x=a(x,t)  
    return x

date=Date()
date.year=34
date.month=12
date.day=31
new_date=Date()
new_date=increment_date_leap(date,800)
print_date(new_date)
# Out:
# 37 . 3 . 10

# %% [markdown]
# ## Problem 4
#
# The `datetime` module provides date and time objects that are similar to the Date and Time objects in this chapter, but they provide a rich set of methods and operators. Read the documentation at http://docs.python.org/2/library/datetime.html.
#
# 1. Use the `datetime` module to write a program that gets the current date and prints the day of the week.
# 2. Write a program that takes a birthday as input and prints the user’s age and the number of days, hours, minutes and seconds until their next birthday.
# 3. For two people born on different days, there is a day when one is twice as old as the other. That’s their Double Day. Write a program that takes two birthdays and computes their Double Day.
# 4. For a little more challenge, write the more general version that computes the day when one person is `n` times older than the other.

# %%
import time;

localtime = time.asctime( time.localtime(time.time()) )
print "Local current time :", localtime
# Out:
# Local current time : Tue May 19 17:38:57 2015

# %%
# Problem 4
#1
class Datetime(object):
    """Represents the date and time .
    attributes: year, month, day , hour, minute, second, microsecond, tzinfo
    """
import time
from datetime import datetime,tzinfo,timedelta

def print_current_time():
    x=Datetime()
    x=datetime.today()
    a=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
    print x,a[x.weekday()]

print_current_time()
# Out:
# 2015-05-19 17:39:49.193000 Tuesday

# %%
#4-2
class Datetime(object):
    """Represents the date and time .
    attributes: year, month, day , hour, minute, second, microsecond, tzinfo
    """
import time
from datetime import datetime,tzinfo,timedelta
def month365(month):   
    a=[0,31,59,90,120,151,181,212,243,273,304,334,365]
    return a[month-1]

def print_datetime(a):
    print '%d-%d-%d %.2d:%.2d:%.2d'%(a.year,a.month,a.day,a.hour,a.minute,a.second)

def next_birthday():
    x=Datetime()#x:生日
    x.year=1994
    x.month=10
    x.day=20
    x.hour=18
    x.minute=6
    x.second=6
    y=Datetime()
    y=datetime.today() #y:當下時間
    z=0  #z:目前年齡
    next_time=Datetime()
    
            
    birthday_day=0   #計算一年過了幾天，先忽略平閏年，today代表current，birthday代表生日
    today_day=0
    birthday_time=0 #計算當天已過時間
    today_time=0
    
    birthday_now=Datetime()  
    birthday_now.year=y.year 
    birthday_now.month=x.month #直接=x會影響下面計算年齡
    birthday_now.day=x.day
    birthday_now.hour=x.hour
    birthday_now.minute=x.minute
    birthday_now.second=x.second    
    
    birthday_day=month365(birthday_now.month)+birthday_now.day
    birthday_time=birthday_now.hour*3600+birthday_now.minute*60+birthday_now.second
    
    today_day=month365(y.month)+y.day
    today_time=y.hour*3600+y.minute*60+y.second
    #計算當時年齡
    if y.year>=x.year:  
        if today_day>birthday_day:  #已過生日 年可直接相減
            z=y.year-x.year
        if birthday_day==today_day:
            if today_time>=birthday_time:
                z=y.year-x.year
            if today_time<birthday_time:
                z=z.year-x.year-1
        if today_day<birthday_day:
            z=y.year-x.year-1    
    #計算下次生日
    if birthday_day>today_day: #當年生日還沒到
        if birthday_time>=today_time:
            next_birthday_day=birthday_day-today_day #只要天數不用年月日，故不使用Datetime
            next_birthday_time=birthday_time-today_time
            minutes,next_birthday_second=divmod(next_birthday_time,60)
            next_birthday_hour,next_birthday_minute=divmod(minutes,60)
        if birthday_time<today_time:
            next_birthday_day=birthday_day-today_day-1 #已減少一天
            next_birthday_time=birthday_time+86400-today_time   #86400=一天總秒數
            minutes,next_birthday_second=divmod(next_birthday_time,60)
            next_birthday_hour,next_birthday_minute=divmod(minutes,60)
    if birthday_day<=today_day:
        if birthday_time>=today_time:
            next_birthday_day=365+birthday_day-today_day #只要天數不用年月日，故不使用Datetime
            next_birthday_time=birthday_time-today_time
            minutes,next_birthday_second=divmod(next_birthday_time,60)
            next_birthday_hour,next_birthday_minute=divmod(minutes,60)
        if birthday_time<today_time:
            next_birthday_day=365+birthday_day-today_day-1 #當年生日已過，等364天
            next_birthday_time=birthday_time+86400-today_time   #86400=一天總秒數
            minutes,next_birthday_second=divmod(next_birthday_time,60)
            next_birthday_hour,next_birthday_minute=divmod(minutes,60)
      
    print 'Age=',z
    print '下次生日： %dDay- %dHour- %dMin- %dSec 後'%(next_birthday_day,next_birthday_hour,next_birthday_minute,next_birthday_second)
   
next_birthday()
# Out:
# Age= 20
# 下次生日： 154Day- 0Hour- 28Min- 8Sec 後

# %%
#4-3
class Datetime(object):
    """Represents the date and time .
    attributes: year, month, day , hour, minute, second, microsecond, tzinfo
    """
class Date(object):
    """Represents the date and time .
    attributes: year, month, day ,
    """
import time
from datetime import datetime,tzinfo,timedelta,date

def print_date(a):
    print '%d . %d . %d'%(a.year,a.month,a.day)
    
def month365(month):   
    a=[0,31,59,90,120,151,181,212,243,273,304,334,365]
    return a[month-1]
    
def double_day(t1,t2):
    total_t1=(t1.year-1)*365+month365(t1.month)+t1.day
    total_t2=(t2.year-1)*365+month365(t2.month)+t2.day
    # total_t1<total_t2:age1>age2  (double-t1)=2*(double-t2)  double=2t2-t1
    # total_t1>total_t2:age1<age2  (double-t2)=2*(double-t1)  double=2t1-t2
    if total_t1<total_t2:
        double=2*total_t2-total_t1
    if total_t1==total_t2:
        double='They are the same age' 
    if total_t1>total_t2:
        double=2*total_t1-total_t2
    double_day=Date()
    double_day.year=(double/365)+1
    y=double%365 #當年過的天數
    i=1
    while i<=12:
        if y>=month365(i)+1 and y<=month365(i+1):
            double_day.month=i
            double_day.day=y-month365(i)
        i=i+1
    if y==0: #剛好跑365天，一年最後一天
        double_day.year=double_day.year-1
        double_day.month=12
        double_day.day=31
    return double_day

t1=Date()
t1.year=1951
t1.month=7
t1.day=14
t2=Date()
t2.year=1951
t2.month=7
t2.day=16
print 'The doubleday of t1 and t2 is:'
print_date(double_day(t1,t2))
# Out:
# The doubleday of t1 and t2 is:
# 1951 . 7 . 18

# %%
#4-4
class Datetime(object):
    """Represents the date and time .
    attributes: year, month, day , hour, minute, second, microsecond, tzinfo
    """
class Date(object):
    """Represents the date and time .
    attributes: year, month, day ,
    """
import time
from datetime import datetime,tzinfo,timedelta,date

def print_date(a):
    if type(a)==str:
        print a
    else:    
        print '%d . %d . %d'%(a.year,a.month,a.day)
    
def month365(month):   
    a=[0,31,59,90,120,151,181,212,243,273,304,334,365]
    return a[month-1]
    
def n_day(t1,t2,n):
    total_t1=(t1.year-1)*365+month365(t1.month)+t1.day
    total_t2=(t2.year-1)*365+month365(t2.month)+t2.day
    # total_t1<total_t2:age1>age2  (n_day-t1)=n*(n_day-t2)  nday=(n*t2-t1)/(n-1)
    # total_t1>total_t2:age1<age2  (n_day-t2)=n*(n_day-t1)  nday=(n*t1-t2)/(n-1)
    if total_t1<total_t2:
        nday=float((n*total_t2-total_t1))/float((n-1))
    if total_t1==total_t2:
        nday='They are the same age' 
    if total_t1>total_t2:
        nday=float((n*total_t1-total_t2))/float((n-1))
    #若nday是分數，代表t1和t2無法找到nday
    nday_int_part=int(nday)
    if nday_int_part!=nday:
        return 'Doesn\'t exist'
    if nday_int_part==nday:
        nday=int(nday) #轉成int方便下面的找餘數和求year   
    
    n_day=Date()
    n_day.year=(nday/365)+1
    y=nday%365 #當年過的天數
    i=1
    while i<=12:
        if y>=month365(i)+1 and y<=month365(i+1):
            n_day.month=i
            n_day.day=y-month365(i)
        i=i+1
    if y==0: #剛好跑365天，一年最後一天
        n_day.year=n_day.year-1
        n_day.month=12
        n_day.day=31
    return n_day

t1=Date()
t1.year=1951
t1.month=7
t1.day=14
t2=Date()
t2.year=1951
t2.month=7
t2.day=16
print 'The n times\'s day is: '
print_date(n_day(t1,t2,3))
# Out:
# The n times's day is:
# 1951 . 7 . 17

# %% [markdown]
# ## Problem 5
#
# Implement the `Point` class and the `Rectangle` class, with following methods.
#
# 1. Write an `init` method for the Point class that takes `x` and `y` as optional parameters and assigns them to the corresponding attributes.
# 2. Write a `str` method for the Point class.
# 3. Write an `add` method for Points that works with either a Point object or a tuple:
#   * If the second operand is a Point, the method should return a new Point whose `x` coordinate is the sum of the `x` coordinates of the operands, and likewise for the `y` coordinates.
#   * If the second operand is a tuple, the method should add the first element of the tuple to the `x` coordinate and the second element to the `y` coordinate, and return a new Point with the result.
# 4. Write some codes to demonstrate the usage of methods above.

# %%
# Problem 5
import math
class Rectangle(object):
    """Represents a rectangle. 
    attributes: width, height, corner.
    """
#1
class Point(object):
    """Represents a point in 2-D space."""
    def __init__(self, x=0, y=0):
        self.x=x
        self.y=y
#2        
    def __str__(self):
        return '(%d,%d)' % (self.x, self.y)
#3 
    def __add__(self, other):
        a=Point()
        if isinstance(other, Point):
            a.x=self.x+other.x
            a.y=self.y+other.y
            return a
        if type(other)== tuple:
            a.x=self.x+other[0]
            a.y=self.y+other[1]
            return a
    def __radd__(self, other):  # #
        return self.__add__(other)
#4
point1=Point(2, 3)
point2=Point(5, 6)
point3=(5,6)
point4=point1+point2  #test __add__ and __radd__
point5=point1+point3
point6=point3+point1
print point4   #test __str__(can print) ,__add__ and __radd__ 
print point5
print point6
# Out:
# (7,9)
# (7,9)
# (7,9)
