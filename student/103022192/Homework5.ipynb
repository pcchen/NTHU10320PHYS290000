# %% [markdown]
# # Homework 5

# %% [markdown]
# ## Problem 1
#
# Consider the damped oscillation
# $$
#   m \ddot{x} + b \dot{x} + k x =0,
# $$
# which can be rewritten as
# $$
#   \ddot{x} + 2\beta\dot{x} + \omega^2_0 x =0,
# $$
# where $\beta=b/2m$ is the **damping parameter** and $\omega_0=\sqrt{k/m}$ is the characteristic angular frequency in the absence of damping.
#
# ### Underdamping
# When $\omega^2_0  > \beta^2$ the system has underdamping oscillation. Define
# $$
#   \omega_1 = \sqrt{\omega_0^2 -\beta^2}.
# $$
# The general solution can be written as
# $$
#   x(t) = A \exp(-\beta t) \cos(\omega_1 t - \delta).
# $$
#
# ### Overdsamping
# When $\omega^2_0  < \beta^2$ the system has underdamping oscillation. Define
# $$
#   \omega_2 = \sqrt{\beta^2 - \omega_0^2}.
# $$
# The general solution can be written as
# $$
#   x(t) = A \exp(-\beta t) \left[ A_1 \exp(\omega_2 t) + A_2 \exp(-\omega_2 t) \right].
# $$
#
# For a given set of $m$, $b$, $k$, and
# * $A$, $\delta$ (for underdamping)
# * $A_1$, $A_2$ (for overdamping)
#
# Do the following:
# * Plot $x(t)$.
# * Plot $E(t)= \frac{1}{2} k x^2(t) + \frac{1}{2} m \dot{x}^2(t)$.
# * Plot the $\dot{x}(t)$ v.s. $x(t)$.

# %%
# Problem 1
#for underdamping
m=3
b=2
k=2
A=100
delta=0.1
omega_0=k/m
omega_1=(omega_0**2-b**2/4/m**2)**(1/2)

#for overdamping
m_1=1
b_1=3
k_1=2
omega_i=k_1/m_1
omega_2=(b_1**2/4/m_1**2-omega_i**2)**(1/2)
A_1=0.01
A_2=0.02



# %pylab inline
def f1(t):
    return A*exp(-t*b/2/m)*cos(omega_1*t-delta)
def f2(t):
    return 1000*exp(-t*b_1/2/m_1)*(A_1*exp(omega_2*t)+A_2*exp(-omega_2*t))

t = linspace(0, 10, 100)
y1 = f1(t)
y2 = f2(t)

plot(t, y1, 'r-')
hold('on')
plot(t, y2, 'bo')
xlabel('t')
ylabel('y')
legend(['underdamping', 'overdamping'])
title('x vs. t graph')
show()

#E(t) vs t



def y5(t):
    return -b/2/m*A*exp(-t*b/2/m)*cos(omega_1*t-delta)-A*exp(-t*b/2/m)*sin(omega_1*t-delta)*omega_1

def y6(t):
    return A*A_1*(-b_1/2/m_1)*e**(-b_1/2/m_1*t)*e**(omega_2*t)+A*A_1*omega_2*e**(-b_1/2/m_1*t)*e**(omega_2*t)+A*(-b_1/2/m_1)*A_2*e**(-b_1/2/m_1*t)*e**(omega_2*t)+A*(omega_2)*A_2*e**(-b_1/2/m_1*t)*e**(omega_2*t)
def f3(t):
    return power(f1(t),2)/2*k
def f4(t):
    return power(f2(t),2)/2*k_1
t = linspace(0, 10, 100)
y3 = f3(t)+power(y5(t),2)/2*m
y4 = f4(t)+power(y6(t),2)/2*m_1

plot(y1, y3, 'r-')
hold('on')
plot(y2, y4, 'bo')
xlabel('x')
ylabel('x_differientation')
legend(['underdamping', 'overdamping'])
title('x vs. x differientation graph')
show()

#Energy vs. t
plot(t, y3, 'r-')
hold('on')
plot(t, y4, 'bo')
xlabel('x')
ylabel('y')
legend(['underdamping', 'overdamping'])
title('Energy vs. t graph')
show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Problem 2
#
# Consider the driven oscillation
# $$
#   \ddot{x} + 2\beta\dot{x} + \omega^2_0 x = A\cos(\omega t).
# $$
#
# The amplitude $D$ of the oscillation has the form
# $$
#   D = \frac{A}{\sqrt{(\omega_0^2-\omega^2)^2+4\omega^2 \beta^2}},
# $$
# and the phase angle $\delta$ has the form
# $$
#   \delta = \tan^{-1}\left( \frac{2\omega \beta }{\omega^2_0-\omega^2} \right), \;
#   0 \le \delta \le \pi.
# $$
#
# For a given set of $\beta$, $\omega_0$ and $\omega$:
# * Plot amplitude $D$ as a function of $\omega$.
# * Plot phase angle $\delta$ as a function of $\omega$.
# * Use IPython Interact to let the user changes the values of $\beta$ and $\omega_0$.

# %%
# Problem 2
# %pylab inline
#1
w0=5
B=3
w = arange(-30, 30, 0.1)
D = 1/((5**2-w**2)**2+4*(w**2)*(3**2))**0.5
plot(w,D)
# %pylab inline
w0=5
B=3
w = arange(0, 10, 0.1)
d = arctan(2*w*3/(w0**2-w**2))
plot(w,d)
from pylab import *
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab inline
#1
w0=5
B=3
w = arange(-30, 30, 0.1)
D = 1/((5**2-w**2)**2+4*(w**2)*(3**2))**0.5
plot(w,D)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['draw']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
#Problem 2
from IPython.html.widgets import interact
def draw(B,wo): 
    x = linspace(0, 10, 300)
    plot(x, A/(sqrt((wo**2-x**2)**2+4*(x**2)*(B**2))))  #D(w)
interact(draw, B=(-10.,10.), wo=(0., 10.))

# %% [markdown]
# ## Problem 3
#
# Write a definition for a class named `Kangaroo` with the following methods:
#
# * An `__init__` method that initializes an attribute named `pouch_contents` to an empty list.
# * A method named `put_in_pouch` that takes an object of any type and adds it to `pouch_contents`.
# * A `__str__` method that returns a string representation of the Kangaroo object and the contents of the pouch.
#
# Test your code by creating two Kangaroo objects, assigning them to variables named `kanga` and `roo`, and then adding `roo` to the contents of `kanga`’s pouch

# %%
# Problme 3
class Kangaroo(object):
    '''attribute : pouch_contents'''
def __init__ (d):
    d.pouch_contents=[]
def put_in_pouch(d,obj):
    d.pouch_contents.appebd(obj)
def __str__(d):
    e=Kangaroo
    e.pouch_contents=d.pouch_contents
    return '%.2d' % (e.pouch_contents)

# %% [markdown]
# ## Problem 4
#
# Write a `__cmp__` method for `Time` objects.

# %%
# Problem 4

#class Time(object):
    """Attributes: hour, minute, second"""
    

    # special methods
   # def __str__(self):
   #     return '%s of %s' % (Card.rank_names[self.rank],
                             Card.suit_names[self.suit])    
    
  #  def __init__(self, hour=0, minute=2,second=0):
   #     self.suit = suit
    #    self.rank = rank
        
    # operator overloading
    # verbose version
   # def __cmp__(self, other):
        # check the suits
   #     if self.suit > other.suit: return 1
    #    if self.suit < other.suit: return -1

        # suits are the same... check ranks
     #   if self.rank > other.rank: return 1
      #  if self.rank < other.rank: return -1

        # ranks are the same... it's a tie
       # return 0  
    
    # concise version, using tuple
    #def __cmp__(self, other):
     #   t1 = self.suit, self.rank
      #  t2 = other.suit, other.rank
       # return cmp(t1, t2)
    
#print t1 > t2
def __cmp__(t1,t2):
    
    def time_to_int(self):
        minutes = self.hour * 60 + self.minute
        seconds = minutes * 60 + self.second
        return seconds
    if time_to_int(t1)> time_to_int(t2):
        return 1
    if time_to_int(t1)< time_to_int(t2):
        return -1
    return 0

# %% [markdown]
# ## Problem 5
#
# Write a `Deck` method named `sort` that uses the list method `sort` to sort the cards in a `Deck`. `sort` uses the `__cmp__` method we defined to determine sort order.

# %%
# Problem 5
class Card(object):
    """Represents a standard playing card."""

    # class attributes
    suit_names = ['Clubs', 'Diamonds', 'Hearts', 'Spades']
    rank_names = [None, 'Ace', '2', '3', '4', '5', '6', '7', 
              '8', '9', '10', 'Jack', 'Queen', 'King']

    # special methods
    def __str__(self):
        return '%s of %s' % (Card.rank_names[self.rank],
                             Card.suit_names[self.suit])    
    
    def __init__(self, suit=0, rank=2):
        self.suit = suit
        self.rank = rank
        
    
    # concise version, using tuple
    def __cmp__(self, other):
        t1 = self.suit, self.rank
        t2 = other.suit, other.rank
        return cmp(t1, t2)
card_1= Card()
card_2=Card()
card_1.suit=0
card_1.rank=1
card_2.rank=12
card_2.suit=1

print card_1
print card_2
print cmp(card_1,card_2)

print"_____________________________________________________________________"
import random
class Card:
    """represents a playing card"""
    def __init__(self, suit=0, rank=2):
        self.suit = suit
        self.rank = rank
    suit_names = ['Clubs', 'Diamonds', 'Hearts', 'Spades']
    rank_names = [None, 'Ace','2', '3', '4', '5', '6', '7', 
        '8', '9', '10', 'Jack', 'Queen', 'King']
    def __str__(self):
        return '%s of %s' % (Card.rank_names[self.rank], Card.suit_names[self.suit])
    def __cmp__(self, other):
        t1 = self.suit, self.rank
        t2 = other.suit, other.rank
        return cmp(t1, t2)
class Deck:
    """represents a deck of cards"""
    def __init__(self):
        self.cards = []
        for suit in range(4):
            for rank in range(1, 14):
                card = Card(suit, rank)
                self.cards.append(card)
    def __str__(self):
        res = [str(card) for card in self.cards]
        return '\n'.join(res)
    def shuffle(self):
        random.shuffle(self.cards)
    def pop_card(self):
        return self.cards.pop()
    def add_card(self, card):
        self.cards.append(card)
    def move_cards(self, hand, num):
        for i in range(num):
            hand.add_card(self.pop_card())
        
class Hand(Deck):
    """represents a hand of cards"""
    def __init__(self, label=''):
        self.cards= []
        self.label = label
    def show_hand(Hand):
        """Displays hand"""
        print Hand
hand = Hand()
deck = Deck()
hand1 = Hand('Hand One') 
hand2 = Hand('Hand Two')
Deck.shuffle(deck)
Deck.move_cards(deck, hand1, 26)
Deck.move_cards(deck, hand2, 26)
print 'Hand 1: ', hand1
print 'Hand 2: ', hand2
# Out:
# Ace of Clubs
# Queen of Diamonds
# -1
# _____________________________________________________________________
# Hand 1:  Jack of Diamonds
# Ace of Hearts
# 2 of Diamonds
# 3 of Hearts
# 8 of Spades
# Jack of Clubs
# 4 of Clubs
# 4 of Spades
# 6 of Clubs
# 6 of Diamonds
# 10 of Diamonds
# 4 of Hearts
# 2 of Spades
# Queen of Clubs
# 10 of Spades
# 2 of Clubs
# 8 of Clubs
# Ace of Clubs
# King of Spades
# 7 of Diamonds
# 3 of Diamonds
# 10 of Clubs
# 8 of Diamonds
# King of Hearts
# 5 of Clubs
# Jack of Hearts
# Hand 2:  5 of Hearts
# 5 of Diamonds
# 4 of Diamonds
# 7 of Spades
# 9 of Hearts
# Ace of Diamonds
# Jack of Spades
# 3 of Spades
# King of Clubs
# 6 of Spades
# 3 of Clubs
# 9 of Spades
# King of Diamonds
# Queen of Hearts
# 5 of Spades
# 7 of Hearts
# 10 of Hearts
# 6 of Hearts
# 8 of Hearts
# 7 of Clubs
# 9 of Diamonds
# 9 of Clubs
# Queen of Diamonds
# Queen of Spades
# Ace of Spades
# 2 of Hearts

# %% [markdown]
# ## Problem 6
#
# The following are the possible hands in poker, in increasing order of value (and decreasing order of probability):
#
# **pair:**
# two cards with the same rank
#
# **two pair:**
# two pairs of cards with the same rank
#
# **three of a kind:**
# three cards with the same rank
#
# **straight:**
# five cards with ranks in sequence (aces can be high or low, so Ace-2-3-4-5 is a straight and so is 10-Jack-Queen-King-Ace, but Queen-King-Ace-2-3 is not.)
#
# **flush:**
# five cards with the same suit
#
# **full house:**
# three cards with one rank, two cards with another
#
# **four of a kind:**
# four cards with the same rank
#
# **straight flush:**
# five cards in sequence (as defined above) and with the same suit
#
# **Modify** the following codes.
#
# Add methods to `PokerHand` class named `has_pair`, `has_twopair`, etc. that return `True` or `False` according to whether or not the hand meets the relevant criteria. Your code should work correctly for “hands” that contain any number of cards (although 5 and 7 are the most common sizes)

# %%
# Problem 6
import random
class Card(object):
    """Represents a standard playing card.
    
    Attributes:
      suit: integer 0-3
      rank: integer 1-13
    """
    suit_names = ["Clubs", "Diamonds", "Hearts", "Spades"]
    rank_names = [None, "Ace", "2", "3", "4", "5", "6", "7", 
              "8", "9", "10", "Jack", "Queen", "King"]
    def __init__(self, suit=0, rank=2):
        self.suit = suit
        self.rank = rank
    def __str__(self):
        """Returns a human-readable string representation."""
        return '%s of %s' % (Card.rank_names[self.rank],
                             Card.suit_names[self.suit])
    def __cmp__(self, other):
        """Compares this card to other, first by suit, then rank.
        Returns a positive number if this > other; negative if other > this;
        and 0 if they are equivalent.
        """
        t1 = self.suit, self.rank
        t2 = other.suit, other.rank
        return cmp(t1, t2)
class Deck(object):
    """Represents a deck of cards.
    Attributes:
      cards: list of Card objects.
    """
    
    def __init__(self):
        self.cards = []
        for suit in range(4):
            for rank in range(1, 14):
                card = Card(suit, rank)
                self.cards.append(card)
    def __str__(self):
        res = []
        for card in self.cards:
            res.append(str(card))
        return '\n'.join(res)
    def add_card(self, card):
        """Adds a card to the deck."""
        self.cards.append(card)
    def remove_card(self, card):
        """Removes a card from the deck."""
        self.cards.remove(card)
    def pop_card(self, i=-1):
        """Removes and returns a card from the deck.
        i: index of the card to pop; by default, pops the last card.
        """
        return self.cards.pop(i)
    def shuffle(self):
        """Shuffles the cards in this deck."""
        random.shuffle(self.cards)
    def sort(self):
        """Sorts the cards in ascending order."""
        self.cards.sort()
    def move_cards(self, hand, num):
        """Moves the given number of cards from the deck into the Hand.
        hand: destination Hand object
        num: integer number of cards to move
        """
        for i in range(num):
            hand.add_card(self.pop_card())
class Hand(Deck):
    """Represents a hand of playing cards."""
    
    def __init__(self, label=''):
        self.cards = []
        self.label = label
        
class PokerHand(Hand):
    def suit_hist(self):
        """Builds a histogram of the suits that appear in the hand.
        Stores the result in attribute suits.
        """
        self.suits = {}
        for card in self.cards:
            self.suits[card.suit] = self.suits.get(card.suit, 0) + 1
    def has_flush(self):
        """Returns True if the hand has a flush, False otherwise.
      
        Note that this works correctly for hands with more than 5 cards.
        """
        self.suit_hist()
        for val in self.suits.values():
            if val >= 5:
                return True
        return False
    def rank_hist(self) :
        """Builds a histogram of the ranks that appear in the hand.
        Stores the result in attribute ranks.
        """
        self.ranks = {}
        for card in self.cards:
            self.ranks[card.rank] = self.ranks.get(card.rank, 0) + 1
    def has_pair(self):
        """pair:  two cards with the same rank"""
        for val in self.ranks.values() :
            if val >= 2 :
                return True
        return False
    def has_two_pairs(self) :
        """ two pair: two pairs of cards with the same rank"""
        pair_ctr=0
        for val in self.ranks.values() :
            if val >= 2 :
                pair_ctr += 1
                if pair_ctr >= 2 :
                    return True
        return False
    def has_three_of_a_kind(self) :
        """three of a kind: three cards with the same rank"""
        for val in self.ranks.values() :
            if val >= 3 :
                return True
        return False
    def has_four_of_a_kind(self) :
        """three of a kind: four cards with the same rank"""
        for val in self.ranks.values() :
            if val >= 4 :
                return True
        return False
    def has_fullhouse(self) :
        """ two pair: two pairs of cards with the same rank"""
        pair_ctr=0
        for val in self.ranks.values() :
            if val >= 3 :
                pair_ctr += 1
                if pair_ctr >= 3 :
                    return True
if __name__ == '__main__':
    # make a deck
    deck = Deck()
    deck.shuffle()
    while True:
        print "*"*20
        try :
            hand = PokerHand()
        except IndexError:
            print "New Deck"
            deck = Deck()
            deck.shuffle()
        deck.move_cards(hand, 7)
        hand.sort()
        hand.suit_hist()
        hand.rank_hist()
        print hand
        print "Has flush:",  hand.has_flush()
        print "Has pair:", hand.has_pair()
        print "Has two pairs:", hand.has_two_pairs()
        t = hand.has_three_of_a_kind()
        print "Has three of a kind:", t
        print "Has four of a kind:", t
        print "Has fullhouse:", t
        if t:
            break
# Out:
# ********************
# 10 of Clubs
# Jack of Clubs
# 5 of Diamonds
# Jack of Hearts
# Queen of Hearts
# King of Hearts
# 8 of Spades
# Has flush: False
# Has pair: True
# Has two pairs: False
# Has three of a kind: False
# Has four of a kind: False
# Has fullhouse: False
# ********************
# 2 of Clubs
# 7 of Diamonds
# Jack of Diamonds
# King of Diamonds
# 9 of Hearts
# 10 of Spades
# Queen of Spades
# Has flush: False
# Has pair: False
# Has two pairs: False
# Has three of a kind: False
# Has four of a kind: False
# Has fullhouse: False
# ********************
# 4 of Clubs
# 7 of Clubs
# 8 of Clubs
# 9 of Diamonds
# 8 of Hearts
# 2 of Spades
# 5 of Spades
# Has flush: False
# Has pair: True
# Has two pairs: False
# Has three of a kind: False
# Has four of a kind: False
# Has fullhouse: False
# ********************
# Queen of Clubs
# Ace of Diamonds
# 5 of Hearts
# 6 of Hearts
# Ace of Spades
# 7 of Spades
# 9 of Spades
# Has flush: False
# Has pair: True
# Has two pairs: False
# Has three of a kind: False
# Has four of a kind: False
# Has fullhouse: False
# ********************
# Ace of Clubs
# King of Clubs
# 3 of Diamonds
# 10 of Diamonds
# 3 of Hearts
# 10 of Hearts
# King of Spades
# Has flush: False
# Has pair: True
# Has two pairs: True
# Has three of a kind: False
# Has four of a kind: False
# Has fullhouse: False
# ********************
# 3 of Clubs
# 6 of Clubs
# 6 of Diamonds
# Ace of Hearts
# 4 of Hearts
# 7 of Hearts
# 3 of Spades
# Has flush: False
# Has pair: True
# Has two pairs: True
# Has three of a kind: False
# Has four of a kind: False
# Has fullhouse: False
# ********************
# 5 of Clubs
# 9 of Clubs
# 2 of Diamonds
# 4 of Diamonds
# 8 of Diamonds
# Queen of Diamonds
# 6 of Spades
# Has flush: False
# Has pair: False
# Has two pairs: False
# Has three of a kind: False
# Has four of a kind: False
# Has fullhouse: False
# ********************
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-0d2069c24158> in <module>()
#     146             deck = Deck()
#     147             deck.shuffle()
# --> 148         deck.move_cards(hand, 7)
#     149         hand.sort()
#     150         hand.suit_hist()
#
# <ipython-input-39-0d2069c24158> in move_cards(self, hand, num)
#      66         """
#      67         for i in range(num):
# ---> 68             hand.add_card(self.pop_card())
#      69 class Hand(Deck):
#      70     """Represents a hand of playing cards."""
#
# <ipython-input-39-0d2069c24158> in pop_card(self, i)
#      53         i: index of the card to pop; by default, pops the last card.
#      54         """
# ---> 55         return self.cards.pop(i)
#      56     def shuffle(self):
#      57         """Shuffles the cards in this deck."""
#
# IndexError: pop from empty list
