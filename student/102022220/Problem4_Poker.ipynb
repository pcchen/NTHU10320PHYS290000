# %% [markdown]
# # Problem 4:
# # Poker Games

# %% [markdown]
# Following are the implementations of the class
# * Card
# * Deck
# * Hand
# * PokerHand
#
# See the example codes below the class definition to see how to use these classes.

# %%
import random

class Card(object):
    """Represents a standard playing card.
    
    Attributes:
      suit: integer 0-3
      rank: integer 1-13
    """

    suit_names = ["Clubs", "Diamonds", "Hearts", "Spades"]
    rank_names = [None, "Ace", "2", "3", "4", "5", "6", "7", 
              "8", "9", "10", "Jack", "Queen", "King"]

    def __init__(self, suit=0, rank=2):
        self.suit = suit
        self.rank = rank

    def __str__(self):
        """Returns a human-readable string representation."""
        return '%s of %s' % (Card.rank_names[self.rank],
                             Card.suit_names[self.suit])

    def __cmp__(self, other):
        """Compares this card to other, first by suit, then rank.

        Returns a positive number if this > other; negative if other > this;
        and 0 if they are equivalent.
        """
        t1 = self.suit, self.rank
        t2 = other.suit, other.rank
        return cmp(t1, t2)


class Deck(object):
    """Represents a deck of cards.

    Attributes:
      cards: list of Card objects.
    """
    
    def __init__(self):
        self.cards = []
        for suit in range(4):
            for rank in range(1, 14):
                card = Card(suit, rank)
                self.cards.append(card)

    def __str__(self):
        res = []
        for card in self.cards:
            res.append(str(card))
        return '\n'.join(res)

    def add_card(self, card):
        """Adds a card to the deck."""
        self.cards.append(card)

    def remove_card(self, card):
        """Removes a card from the deck."""
        self.cards.remove(card)

    def pop_card(self, i=-1):
        """Removes and returns a card from the deck.

        i: index of the card to pop; by default, pops the last card.
        """
        return self.cards.pop(i)

    def shuffle(self):
        """Shuffles the cards in this deck."""
        random.shuffle(self.cards)

    def sort(self):
        """Sorts the cards in ascending order."""
        self.cards.sort()

    def move_cards(self, hand, num):
        """Moves the given number of cards from the deck into the Hand.

        hand: destination Hand object
        num: integer number of cards to move
        """
        for i in range(num):
            hand.add_card(self.pop_card())


class Hand(Deck):
    """Represents a hand of playing cards."""
    
    def __init__(self, label=''):
        self.cards = []
        self.label = label
        
class PokerHand(Hand):

    def make_histograms(self):
        """Builds a histogram of the suits that appear in the hand.

        Stores the result in attribute suits.
        """
        self.suits = {}
        self.ranks = {}
        for card in self.cards:
            self.suits[card.suit] = self.suits.get(card.suit, 0) + 1
            self.ranks[card.rank] = self.ranks.get(card.rank, 0) + 1
        
        self.sets = self.ranks.values()
        self.sets.sort(reverse=True)
        
    def has_pair(self):
        """Checks whether this hand has a pair."""
        self.make_histograms()
        for i in range(len(self.sets)):
            if self.sets[i] == 2:
                return True
        return False

    def has_twopair(self):
        """Checks whether this hand has two pair."""
        self.make_histograms()
        for i in range(len(self.sets)-1):
            if self.sets[i] == 2 and self.sets[i+1] == 2:
                return True
        return False

    def has_threekind(self):
        """Checks whether this hand has three of a kind."""
        self.make_histograms()
        for i in range(len(self.sets)):
            if self.sets[i] == 3:
                return True
        return False

        
    def has_fourkind(self):
        """Checks whether this hand has four of a kind."""
        self.make_histograms()
        for i in range(len(self.sets)):
            if self.sets[i] == 4:
                return True
        return False
    
    def has_fullhouse(self):
        """Checks whether this hand has a full house."""
        self.make_histograms()
        for i in range(len(self.sets)-1):
            if self.sets[i] == 3 and self.sets[i+1] == 2:
                return True
        return False

    def has_straight(self):
        """Checks whether this hand has a straight."""        
        self.make_histograms()
        
        myranks = self.ranks.keys()
        myranks.sort()
        if 1 in myranks:
            myranks.append(14)
        
        for ini in range(len(myranks)-5+1):
            straight = True
            for i in range(4):
                if myranks[ini+i]+1 != myranks[ini+i+1]:
                    straight = False
                    break
            if straight != False:
                return True
        return False

    
    def has_straightflush(self):
        """Checks whether this hand has a straight flush.

        Better algorithm (in the sense of being more demonstrably
        correct).
        """
        # partition the hand by suit and check each
        # sub-hand for a straight
        d = {}
        d[0] = PokerHand()
        d[1] = PokerHand()
        d[2] = PokerHand()
        d[3] = PokerHand()
        
        for c in self.cards:
            d[c.suit].add_card(c)

        # see if any of the partitioned hands has a straight
        for hand in d.values():
            if len(hand.cards) < 5:
                continue            
            hand.make_histograms()
            if hand.has_straight():
                return True
        return False
    
    def has_flush(self):
        """Returns True if the hand has a flush, False otherwise.
      
        Note that this works correctly for hands with more than 5 cards.
        """
        self.make_histograms()
        for val in self.suits.values():
            if val >= 5:
                return True
        return False

# %% [markdown]
# If you want to
# * Create a new Deck and shuffle it.
# * Create a PokerHand called hand and deal 5 cards from the deck to the hand.
# * Sort the hand and print it.
# * Test if the had has two_pair.
#
# You can use the following code:

# %%
# make a deck

deck = Deck()
deck.shuffle()

# deal the cards and classify the hands
hand = PokerHand()
deck.move_cards(hand, 35)
hand.sort()
print hand
print hand.has_twopair()
# Out:
# 3 of Clubs
# 6 of Clubs
# 9 of Clubs
# Queen of Clubs
# King of Clubs
# Ace of Diamonds
# 2 of Diamonds
# 3 of Diamonds
# 4 of Diamonds
# 6 of Diamonds
# 7 of Diamonds
# 8 of Diamonds
# 10 of Diamonds
# Jack of Diamonds
# Queen of Diamonds
# Ace of Hearts
# 3 of Hearts
# 5 of Hearts
# 6 of Hearts
# 7 of Hearts
# 8 of Hearts
# 9 of Hearts
# 10 of Hearts
# Queen of Hearts
# King of Hearts
# Ace of Spades
# 2 of Spades
# 4 of Spades
# 5 of Spades
# 6 of Spades
# 8 of Spades
# 9 of Spades
# Jack of Spades
# Queen of Spades
# King of Spades
# True

# %%
# make a deck

deck = Deck()
deck.shuffle()

# deal the cards and classify the hands
hand = PokerHand()
hand2= PokerHand()
hand3= PokerHand()
hand4 = PokerHand()
hand5 = PokerHand()
hand6 = PokerHand()
hand7 = PokerHand()
deck.move_cards(hand, 5)
deck.move_cards(hand2, 5)
deck.move_cards(hand3, 5)
deck.move_cards(hand4, 5)
deck.move_cards(hand5, 5)
deck.move_cards(hand6, 5)
deck.move_cards(hand7, 5)
print hand
print hand2
print hand2.has_twopair()
# Out:
# King of Clubs
# 3 of Hearts
# 10 of Hearts
# 9 of Spades
# King of Spades
# False
# 6 of Spades
# 9 of Diamonds
# King of Diamonds
# Jack of Diamonds
# 6 of Clubs
# False

# %% [markdown]
# Write some codes to do the following:
#
# * Create a Deck and suffle it.
# * Deal 7 hands, each hand should have 5 cards.
#
# Repeat the proceduer above for 10000 times and estimate the probability of
# * twopair
# * threekind
# * flush

# %%
# estimate the probabillity
n = 10000
number_twopair=0
number_threekind=0
number_flush=0

for i in range(n):
    hand = PokerHand()
    hand2= PokerHand()
    hand3= PokerHand()
    hand4 = PokerHand()
    hand5 = PokerHand()
    hand6 = PokerHand()
    hand7 = PokerHand()
    deck.move_cards(hand, 5)
    deck.move_cards(hand2, 5)
    deck.move_cards(hand3, 5)
    deck.move_cards(hand4, 5)
    deck.move_cards(hand5, 5)
    deck.move_cards(hand6, 5)
    deck.move_cards(hand7, 5)
    if hand.has_twopair()==True:
        number_twopair=+1
    if hand2.has_twopair()==True:
        number_twopair=+1
    if hand3.has_twopair()==True:
        number_twopair=+1    
    if hand4.has_twopair()==True:
        number_twopair=+1
    if hand5.has_twopair()==True:
        number_twopair=+1
    if hand6.has_twopair()==True:
        number_twopair=+1
    if hand7.has_twopair()==True:
        number_twopair=+1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-43fd4eed91e8> in <module>()
#      13     hand6 = PokerHand()
#      14     hand7 = PokerHand()
# ---> 15     deck.move_cards(hand, 5)
#      16     deck.move_cards(hand2, 5)
#      17     deck.move_cards(hand3, 5)
#
# <ipython-input-3-72e4b29eab9e> in move_cards(self, hand, num)
#      83         """
#      84         for i in range(num):
# ---> 85             hand.add_card(self.pop_card())
#      86
#      87
#
# <ipython-input-3-72e4b29eab9e> in pop_card(self, i)
#      66         i: index of the card to pop; by default, pops the last card.
#      67         """
# ---> 68         return self.cards.pop(i)
#      69
#      70     def shuffle(self):
#
# IndexError: pop from empty list

# %%
# estimate the probabillity
n = 10000
number_twopair=0
number_threekind=0
number_flush=0

for hh in range(n):
    hand = PokerHand()
    deck.move_cards(hand, 5)
    if hand.has_twopair()==True:
        number_twopair=+1
    hh=hh+1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-ac109a1224d5> in <module>()
#       7 for hh in range(n):
#       8     hand = PokerHand()
# ----> 9     deck.move_cards(hand, 5)
#      10     if hand.has_twopair()==True:
#      11         number_twopair=+1
#
# <ipython-input-3-72e4b29eab9e> in move_cards(self, hand, num)
#      83         """
#      84         for i in range(num):
# ---> 85             hand.add_card(self.pop_card())
#      86
#      87
#
# <ipython-input-3-72e4b29eab9e> in pop_card(self, i)
#      66         i: index of the card to pop; by default, pops the last card.
#      67         """
# ---> 68         return self.cards.pop(i)
#      69
#      70     def shuffle(self):
#
# IndexError: pop from empty list
