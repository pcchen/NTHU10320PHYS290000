# %% [markdown]
# # Homework 5

# %% [markdown]
# ## Problem 1
#
# Consider the damped oscillation
# $$
#   m \ddot{x} + b \dot{x} + k x =0,
# $$
# which can be rewritten as
# $$
#   \ddot{x} + 2\beta\dot{x} + \omega^2_0 x =0,
# $$
# where $\beta=b/2m$ is the **damping parameter** and $\omega_0=\sqrt{k/m}$ is the characteristic angular frequency in the absence of damping.
#
# ### Underdamping
# When $\omega^2_0  > \beta^2$ the system has underdamping oscillation. Define
# $$
#   \omega_1 = \sqrt{\omega_0^2 -\beta^2}.
# $$
# The general solution can be written as
# $$
#   x(t) = A \exp(-\beta t) \cos(\omega_1 t - \delta).
# $$
#
# ### Overdsamping
# When $\omega^2_0  < \beta^2$ the system has underdamping oscillation. Define
# $$
#   \omega_2 = \sqrt{\beta^2 - \omega_0^2}.
# $$
# The general solution can be written as
# $$
#   x(t) = A \exp(-\beta t) \left[ A_1 \exp(\omega_2 t) + A_2 \exp(-\omega_2 t) \right].
# $$
#
# For a given set of $m$, $b$, $k$, and
# * $A$, $\delta$ (for underdamping)
# * $A_1$, $A_2$ (for overdamping)
#
# Do the following:
# * Plot $x(t)$.
# * Plot $E(t)= \frac{1}{2} k x^2(t) + \frac{1}{2} m \dot{x}^2(t)$.
# * Plot the $\dot{x}(t)$ v.s. $x(t)$.

# %%
# Problem 1-1-(x(t)-t)-Underdamping
# %pylab inline
import numpy as np
import math
def solution(B,ww,x0,v0): #BB:beta ww:omgea0^2 x0:x(0) v0:dx/dt]t=0
    float(B)
    float(ww)
    float(x0)
    float(v0)
    if B*B>ww:
        k=math.sqrt(B*B-ww)
        m1=0-B+k  #m1,m2:特徵方程式的兩個根
        m2=0-B-k  #x=Aexp(m1t)+Bbexp(m2t) A=(v0-m2*x0)/(m1-m2) Bb=(m1*x0-v0)/(m1-m2) 
                  #Bb是一個常數，+b只是要與B:beta區隔
        A=(v0-m2*x0)/(m1-m2)
        Bb=(m1*x0-v0)/(m1-m2) #後面再想回傳方式  方程式要自己解或者用python解?
        s1=[m1,m2,A,Bb]
        return s1
    if B*B==ww: #m1=m2=m x=Cexp(mt)+Dtexp(mt) C=x0 D=v0+B*x0
        m=0-B #k=0
        C=x0 
        D=v0+B*x0
        s2=[B,C,D]
        return s2
    if B*B<ww: 
        k=math.sqrt(ww-B*B) #x=exp(-Bt)*(Esinkt+Fcoskt) F=x0 E=(v0+B*x0)/k
        E=(v0+B*x0)/k
        F=x0
        s3=[B,k,E,F]
        return s3
    
a=np.arange(0, 10, 0.001)
n=[]
    
def plot_x1(i,s): #x1:B*B>ww
    for t in i:
        x=s[2]*math.exp(s[0]*t)+s[3]*math.exp(s[1]*t)
        n.append([t,x])
    
def plot_x2(i,s): #x2:B*B=ww
    for t in i:
        x=s[1]*math.exp(0-s[0]*t)+s[2]*t*math.exp(0-s[0]*t)
        n.append([t,x])  
    
def plot_x3(i,s): #x2:B*B<ww
    for t in i:
        x=math.exp(0-s[0]*t)*(s[2]*math.sin(s[1]*t)+s[3]*math.cos(s[1]*t))
        n.append([t,x])    

B=2
w=15
ww=w*w
x0=0
v0=10
solution(B,ww,x0,v0)

if B*B>ww:
    s1=solution(B,ww,x0,v0)
    plot_x1(a,s1)
if B*B==ww:
    s2=solution(B,ww,x0,v0)
    plot_x2(a,s2)
if B*B<ww:
    s3=solution(B,ww,x0,v0)
    plot_x3(a,s3)
    
n=np.array(n)

x1=n[:,0]
y1=n[:,1]

figure(figsize(10,10))
plot(x1,y1)
show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Problem 1-2-Overdamping
# %pylab inline
import numpy as np
import math
def solution(B,ww,x0,v0): #BB:beta ww:omgea0^2 x0:x(0) v0:dx/dt]t=0
    float(B)
    float(ww)
    float(x0)
    float(v0)
    if B*B>ww:
        k=math.sqrt(B*B-ww)
        m1=0-B+k  #m1,m2:特徵方程式的兩個根
        m2=0-B-k  #x=Aexp(m1t)+Bbexp(m2t) A=(v0-m2*x0)/(m1-m2) Bb=(m1*x0-v0)/(m1-m2) 
                  #Bb是一個常數，+b只是要與B:beta區隔
        A=(v0-m2*x0)/(m1-m2)
        Bb=(m1*x0-v0)/(m1-m2) #後面再想回傳方式  方程式要自己解或者用python解?
        s1=[m1,m2,A,Bb]
        return s1
    if B*B==ww: #m1=m2=m x=Cexp(mt)+Dtexp(mt) C=x0 D=v0+B*x0
        m=0-B #k=0
        C=x0 
        D=v0+B*x0
        s2=[B,C,D]
        return s2
    if B*B<ww: 
        k=math.sqrt(ww-B*B) #x=exp(-Bt)*(Esinkt+Fcoskt) F=x0 E=(v0+B*x0)/k
        E=(v0+B*x0)/k
        F=x0
        s3=[B,k,E,F]
        return s3
    
a=np.arange(0, 10, 0.001)
n=[]
    
def plot_x1(i,s): #x1:B*B>ww
    for t in i:
        x=s[2]*math.exp(s[0]*t)+s[3]*math.exp(s[1]*t)
        n.append([t,x])
    
def plot_x2(i,s): #x2:B*B=ww
    for t in i:
        x=s[1]*math.exp(0-s[0]*t)+s[2]*t*math.exp(0-s[0]*t)
        n.append([t,x])  
    
def plot_x3(i,s): #x2:B*B<ww
    for t in i:
        x=math.exp(0-s[0]*t)*(s[2]*math.sin(s[1]*t)+s[3]*math.cos(s[1]*t))
        n.append([t,x])    

B=16
w=5
ww=w*w
x0=0
v0=10
solution(B,ww,x0,v0)

if B*B>ww:
    s1=solution(B,ww,x0,v0)
    plot_x1(a,s1)
if B*B==ww:
    s2=solution(B,ww,x0,v0)
    plot_x2(a,s2)
if B*B<ww:
    s3=solution(B,ww,x0,v0)
    plot_x3(a,s3)
    
n=np.array(n)

x1=n[:,0]
y1=n[:,1]

figure(figsize(10,10))
plot(x1,y1)
show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Problem 1-3-(x-xdot圖)-Underdamping 令質量m=1
# %pylab inline
import numpy as np
import math
def solution(B,ww,x0,v0): #B:beta ww:omgea0^2 x0:x(0) v0:dx/dt]t=0
    float(B)
    float(ww)
    float(x0)
    float(v0)
    if B*B>ww:
        k=math.sqrt(B*B-ww)
        m1=0-B+k  #m1,m2:特徵方程式的兩個根
        m2=0-B-k  #x=Aexp(m1t)+Bbexp(m2t) A=(v0-m2*x0)/(m1-m2) Bb=(m1*x0-v0)/(m1-m2)
        A=(v0-m2*x0)/(m1-m2)
        Bb=(m1*x0-v0)/(m1-m2) 
        s1=[m1,m2,A,Bb]
        return s1
    if B*B==ww: #m1=m2=m x=Cexp(mt)+Dtexp(mt) C=x0 D=v0+B*x0
        m=0-B #k=0
        C=x0 
        D=v0+B*x0
        s2=[B,C,D]
        return s2
    if B*B<ww: 
        k=math.sqrt(ww-B*B) #x=exp(-Bt)*(Esinkt+Fcoskt) F=x0 E=(v0+B*x0)/k
        E=(v0+B*x0)/k
        F=x0
        s3=[B,k,E,F]
        return s3
    
a=np.arange(0, 10, 0.001)
n=[]
def plot_x1(i,s): #x1:B*B>ww x=Aexp(m1t)+Bbexp(m2t) v=Am1exp(m1t)+Bbm2exp(m2t)
    for t in i:
        x=s[2]*math.exp(s[0]*t)+s[3]*math.exp(s[1]*t)
        v=s[2]*s[0]*math.exp(s[0]*t)+s[3]*s[1]*math.exp(s[1]*t)
        n.append([v,x])
    
def plot_x2(i,s): #x2:B*B=ww x=Cexp(mt)+Dtexp(mt) v=(D-BC)exp(mt)-DBtexp(mt)
    for t in i:
        x=s[1]*math.exp(0-s[0]*t)+s[2]*t*math.exp(0-s[0]*t)
        v=(s[2]-s[0]*s[1])*exp(0-s[0]*t)-s[2]*s[0]*t*exp(0-s[0]*t)
        n.append([v,x])  
    
def plot_x3(i,s): #x2:B*B<ww x=exp(-Bt)*(Esinkt+Fcoskt) 
    #v=-Bexp(-Bt)*(Esinkt+Fcoskt)+exp(-Bt)*(Ecoskt-Fsinkt)
    for t in i:
        B=s[0]
        E=s[2]
        F=s[3]
        sinkt=math.sin(s[1]*t)
        coskt=math.cos(s[1]*t)
        exp_minusBt=math.exp(0-s[0]*t)
        x=exp_minusBt*(E*sinkt+F*coskt)
        v=0-B*exp_minusBt*(E*sinkt+F*coskt)+exp_minusBt*(E*coskt-F*sinkt)
        n.append([v,x])    

B=2
w=10
ww=w*w
x0=0
v0=10
solution(B,ww,x0,v0)

if B*B>ww:
    s1=solution(B,ww,x0,v0)
    plot_x1(a,s1)
if B*B==ww:
    s2=solution(B,ww,x0,v0)
    plot_x2(a,s2)
if B*B<ww:
    s3=solution(B,ww,x0,v0)
    plot_x3(a,s3)
    
n=np.array(n)

x1=n[:,0]
y1=n[:,1]

figure(figsize(10,10))
plot(x1,y1)
show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Problem 1-4-(x-xdot圖)-Overdamping(只留畫overdamping的plot_x1) 令質量m=1
# %pylab inline
import numpy as np
import math
def solution(B,ww,x0,v0): #B:beta ww:omgea0^2 x0:x(0) v0:dx/dt]t=0
    float(B)
    float(ww)
    float(x0)
    float(v0)
    if B*B>ww:
        k=math.sqrt(B*B-ww)
        m1=0-B+k  #m1,m2:特徵方程式的兩個根
        m2=0-B-k  #x=Aexp(m1t)+Bbexp(m2t) A=(v0-m2*x0)/(m1-m2) Bb=(m1*x0-v0)/(m1-m2)
        A=(v0-m2*x0)/(m1-m2)
        Bb=(m1*x0-v0)/(m1-m2) 
        s1=[m1,m2,A,Bb]
        return s1
    if B*B==ww: #m1=m2=m x=Cexp(mt)+Dtexp(mt) C=x0 D=v0+B*x0
        m=0-B #k=0
        C=x0 
        D=v0+B*x0
        s2=[B,C,D]
        return s2
    if B*B<ww: 
        k=math.sqrt(ww-B*B) #x=exp(-Bt)*(Esinkt+Fcoskt) F=x0 E=(v0+B*x0)/k
        E=(v0+B*x0)/k
        F=x0
        s3=[B,k,E,F]
        return s3
    
a=np.arange(0, 10, 0.001)
n=[]
def plot_x1(i,s): #x1:B*B>ww x=Aexp(m1t)+Bbexp(m2t) v=Am1exp(m1t)+Bbm2exp(m2t)
    for t in i:
        x=s[2]*math.exp(s[0]*t)+s[3]*math.exp(s[1]*t)
        v=s[2]*s[0]*math.exp(s[0]*t)+s[3]*s[1]*math.exp(s[1]*t)
        n.append([v,x])
    

B=10
w=5
ww=w*w
x0=0
v0=10
solution(B,ww,x0,v0)

if B*B>ww:
    s1=solution(B,ww,x0,v0)
    plot_x1(a,s1)
if B*B==ww:
    s2=solution(B,ww,x0,v0)
    plot_x2(a,s2)
if B*B<ww:
    s3=solution(B,ww,x0,v0)
    plot_x3(a,s3)
    
n=np.array(n)

x1=n[:,0]
y1=n[:,1]

figure(figsize(10,10))
plot(x1,y1)
show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Problem 2
#
# Consider the driven oscillation
# $$
#   \ddot{x} + 2\beta\dot{x} + \omega^2_0 x = A\cos(\omega t).
# $$
#
# The amplitude $D$ of the oscillation has the form
# $$
#   D = \frac{A}{\sqrt{(\omega_0^2-\omega^2)^2+4\omega^2 \beta^2}},
# $$
# and the phase angle $\delta$ has the form
# $$
#   \delta = \tan^{-1}\left( \frac{2\omega \beta }{\omega^2_0-\omega^2} \right), \;
#   0 \le \delta \le \pi.
# $$
#
# For a given set of $\beta$, $\omega_0$ and $\omega$:
# * Plot amplitude $D$ as a function of $\omega$.
# * Plot phase angle $\delta$ as a function of $\omega$.
# * Use IPython Interact to let the user changes the values of $\beta$ and $\omega_0$.

# %%
# Problem 2-1-(D-ω)
# %pylab inline
import numpy as np
import math
    
a=np.arange(0, 10, 0.001)
n=[]
def plot_x(i,B,A,w0): 
    for w in i:
        D=A/(math.sqrt((w0*w0-w*w)**2+4*w*w*B*B))
        n.append([w,D])
    
B=0.2
w0=3
A=2
plot_x(a,B,A,w0)
    
n=np.array(n)

x1=n[:,0]
y1=n[:,1]

figure(figsize(10,10))
plot(x1,y1)
show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Problem 2-2-(δ-ω)   Q=ω0/2 穩態-用arctan值域在-pi/2~pi/2
# δ=arctan(2βω/(ω0^2-ω^2))
# %pylab inline
import numpy as np
import math
    
a=np.arange(-5, 5, 0.001)
n=[]
def plot_x(i,B,w0): 
    for w in i:
        delta=math.atan(2*B*w/(w0*w0-w*w))
        n.append([w,delta])
    
B=2
w0=5
plot_x(a,B,w0)
    
n=np.array(n)

x1=n[:,0]
y1=n[:,1]

figure(figsize(10,10))
plot(x1,y1)
show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Problem 2-2-(δ-ω)   Q=ω0/2 穩態-用arctan值域在-pi/2~pi/2
# δ=arctan(2βω/(ω0^2-ω^2))
# %pylab inline
import numpy as np
import math
    
a=np.arange(0, 20, 0.001)
n=[]
def plot_x(i,B,w0): 
    for w in i:
        if w<=w0:
            delta=np.arctan2(2*B*w/(w0*w0-w*w),1)
            n.append([w,delta])
        if w>w0:
            delta=np.arctan2(-2*B*w/(w0*w0-w*w),-1)
            n.append([w,delta])
    
B=2
w0=5
plot_x(a,B,w0)
    
n=np.array(n)

x1=n[:,0]
y1=n[:,1]

figure(figsize(10,10))
plot(x1,y1)
show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Problem 2-3-1(D-ω)-IPython Interact
from IPython.html.widgets import interact
# %pylab inline
import numpy as np
import math
    

def plot_x(B,w0,A):
    n=[]
    a=np.arange(0, 10, 0.001)
    for w in a:
        D=A/math.sqrt((w0*w0-w*w)**2+4*w*w*B*B)
        n.append([w,D])
    n=np.array(n)
    
    x1=n[:,0]
    y1=n[:,1]

    figure(figsize(10,10))
    plot(x1,y1)
    show()   

interact(plot_x, B=(0.,20.), w0=(0., 20.),A=(0.,10.))

# %%
# Problem 2-3-2(δ-ω)-IPython Interact-用arctan值域在-pi/2~pi/2
from IPython.html.widgets import interact
# %pylab inline
import numpy as np
import math
    

def plot_x(B,w0):
    n=[]
    a=np.arange(-5, 5, 0.001)
    for w in a:
        delta=math.atan(2*B*w/(w0*w0-w*w))
        n.append([w,delta])
    n=np.array(n)
    
    x1=n[:,0]
    y1=n[:,1]

    figure(figsize(10,10))
    plot(x1,y1)
    show()   

interact(plot_x, B=(0.,20.), w0=(0., 20.))

# %%
# Problem 2-3-2(δ-ω)-IPython Interact-用arctan值域在0~pi
from IPython.html.widgets import interact
# %pylab inline
import numpy as np
import math
    

def plot_x(B,w0):
    n=[]
    a=np.arange(0, 10, 0.001)
    for w in a:
        if w<=w0:
            delta=np.arctan2(2*B*w/(w0*w0-w*w),1)
            n.append([w,delta])
        if w>w0:
            delta=np.arctan2(-2*B*w/(w0*w0-w*w),-1)
            n.append([w,delta])
    n=np.array(n)
    
    x1=n[:,0]
    y1=n[:,1]

    figure(figsize(10,10))
    plot(x1,y1)
    show()   

interact(plot_x, B=(0.,20.), w0=(0., 20.))

# %% [markdown]
# ## Problem 3
#
# Write a definition for a class named `Kangaroo` with the following methods:
#
# * An `__init__` method that initializes an attribute named `pouch_contents` to an empty list.
# * A method named `put_in_pouch` that takes an object of any type and adds it to `pouch_contents`.
# * A `__str__` method that returns a string representation of the Kangaroo object and the contents of the pouch.
#
# Test your code by creating two Kangaroo objects, assigning them to variables named `kanga` and `roo`, and then adding `roo` to the contents of `kanga`’s pouch

# %%
# Problme 3
class Kangaroo(object):
    """Represents Kangaroo's pounch's contents
    """
    def __init__(self, pouch_contents=0):
        self.pouch_contents = pouch_contents
    def __str__(self):
        return self.pouch_contents
    
    def put_in_pouch(self,other):
        x=Kangaroo()
        x.pouch_contents=self.pouch_contents+other.pouch_contents
        return x

kanga='kanga'
kanga=Kangaroo(kanga)
print kanga
roo='roo'
roo=Kangaroo(roo)
print roo
z=kanga.put_in_pouch(roo)
print z
# Out:
# kanga
# roo
# kangaroo

# %% [markdown]
# ## Problem 4
#
# Write a `__cmp__` method for `Time` objects.

# %%
# Problem 4
class Time(object):
    """Represents the time of day.
    attributes: hour, minute, second
    """
    def __init__(self, hour=0, minute=0, second=0):
        self.hour = hour
        self.minute = minute
        self.second = second

    def __str__(self):
        return '%.2d:%.2d:%.2d' % (self.hour, self.minute, self.second)

    def print_time(time):
        print '%.2d:%.2d:%.2d' % (time.hour, time.minute, time.second)    
        
    def time_to_int(self):
        minutes = self.hour * 60 + self.minute
        seconds = minutes * 60 + self.second
        return seconds
    def __cmp__(self, other):
        if self.time_to_int()>other.time_to_int(): return 1
        if self.time_to_int()>other.time_to_int(): return -1
        return 0
    
t1=Time(9,10,50)
t2=Time(8,11,51)
print t1>t2
# Out:
# True

# %% [markdown]
# ## Problem 5
#
# Write a `Deck` method named `sort` that uses the list method `sort` to sort the cards in a `Deck`. `sort` uses the `__cmp__` method we defined to determine sort order.

# %%
# Problem 5-為了方便操作程式裡包含Card和Deck，sort功能在Deck裡面
import random
class Card(object):
    """Represents a standard playing card."""

    suit_names = ["Clubs", "Diamonds", "Hearts", "Spades"]
    rank_names = [None, "Ace", "2", "3", "4", "5", "6", "7","8", "9", "10", "Jack", "Queen", "King"]

    def __init__(self, suit=0, rank=2):
        self.suit = suit
        self.rank = rank

    def __str__(self):
        return '%s of %s' % (Card.rank_names[self.rank],Card.suit_names[self.suit])

    def __cmp__(self, other):
        t1 = self.suit, self.rank
        t2 = other.suit, other.rank
        return cmp(t1, t2)


class Deck(object):
    """Represents a deck of cards.
    Attributes:
      cards: list of Card objects.
    """
    
    def __init__(self):
        self.cards = []
        for suit in range(4):
            for rank in range(1, 14):
                card = Card(suit, rank)
                self.cards.append(card)

    def __str__(self):
        res = []
        for card in self.cards:
            res.append(str(card))
        return '\n'.join(res)

    def add_card(self, card):
        self.cards.append(card)
        
    def pop_card(self):
        return self.cards.pop()

    def shuffle(self):
        random.shuffle(self.cards)

    def sort(self): #This problem- method sort to sort the cards in a Deck. sort
        self.cards.sort()

deck = Deck()
deck.shuffle()
print '---Shuffle the deck---'
print deck
print '---Sorted the deck----'
deck.sort()
print deck
# Out:
# ---Shuffle the deck---
# 6 of Diamonds
# Ace of Diamonds
# 8 of Hearts
# 5 of Clubs
# 8 of Spades
# 3 of Hearts
# Ace of Hearts
# 10 of Clubs
# 3 of Diamonds
# Ace of Clubs
# 9 of Clubs
# 7 of Diamonds
# 4 of Spades
# 6 of Spades
# Jack of Hearts
# Jack of Clubs
# 6 of Hearts
# Queen of Hearts
# King of Hearts
# 4 of Clubs
# 4 of Diamonds
# 2 of Clubs
# 7 of Spades
# 8 of Diamonds
# 10 of Spades
# Jack of Spades
# 10 of Diamonds
# 7 of Hearts
# 5 of Diamonds
# 10 of Hearts
# 3 of Clubs
# 2 of Spades
# King of Diamonds
# Jack of Diamonds
# 3 of Spades
# Ace of Spades
# 9 of Hearts
# 4 of Hearts
# Queen of Clubs
# 2 of Diamonds
# 8 of Clubs
# 2 of Hearts
# King of Clubs
# Queen of Diamonds
# 5 of Hearts
# 9 of Diamonds
# 9 of Spades
# King of Spades
# 6 of Clubs
# 5 of Spades
# Queen of Spades
# 7 of Clubs
# ---Sorted the deck----
# Ace of Clubs
# 2 of Clubs
# 3 of Clubs
# 4 of Clubs
# 5 of Clubs
# 6 of Clubs
# 7 of Clubs
# 8 of Clubs
# 9 of Clubs
# 10 of Clubs
# Jack of Clubs
# ...

# %% [markdown]
# ## Problem 6
#
# The following are the possible hands in poker, in increasing order of value (and decreasing order of probability):
#
# **pair:**
# two cards with the same rank
#
# **two pair:**
# two pairs of cards with the same rank
#
# **three of a kind:**
# three cards with the same rank
#
# **straight:**
# five cards with ranks in sequence (aces can be high or low, so Ace-2-3-4-5 is a straight and so is 10-Jack-Queen-King-Ace, but Queen-King-Ace-2-3 is not.)
#
# **flush:**
# five cards with the same suit
#
# **full house:**
# three cards with one rank, two cards with another
#
# **four of a kind:**
# four cards with the same rank
#
# **straight flush:**
# five cards in sequence (as defined above) and with the same suit
#
# **Modify** the following codes.
#
# Add methods to `PokerHand` class named `has_pair`, `has_twopair`, etc. that return `True` or `False` according to whether or not the hand meets the relevant criteria. Your code should work correctly for “hands” that contain any number of cards (although 5 and 7 are the most common sizes)

# %%
import random
class Card(object):
    """Represents a standard playing card.
    
    Attributes:
      suit: integer 0-3
      rank: integer 1-13
    """

    suit_names = ["Clubs", "Diamonds", "Hearts", "Spades"]
    rank_names = [None, "Ace", "2", "3", "4", "5", "6", "7", 
              "8", "9", "10", "Jack", "Queen", "King"]

    def __init__(self, suit=0, rank=2):
        self.suit = suit
        self.rank = rank

    def __str__(self):
        """Returns a human-readable string representation."""
        return '%s of %s' % (Card.rank_names[self.rank],
                             Card.suit_names[self.suit])

    def __cmp__(self, other):
        """Compares this card to other, first by suit, then rank.

        Returns a positive number if this > other; negative if other > this;
        and 0 if they are equivalent.
        """
        t1 = self.suit, self.rank
        t2 = other.suit, other.rank
        return cmp(t1, t2)


class Deck(object):
    """Represents a deck of cards.

    Attributes:
      cards: list of Card objects.
    """
    
    def __init__(self):
        self.cards = []
        for suit in range(4):
            for rank in range(1, 14):
                card = Card(suit, rank)
                self.cards.append(card)

    def __str__(self):
        res = []
        for card in self.cards:
            res.append(str(card))
        return '\n'.join(res)

    def add_card(self, card):
        """Adds a card to the deck."""
        self.cards.append(card)

    def remove_card(self, card):
        """Removes a card from the deck."""
        self.cards.remove(card)

    def pop_card(self, i=-1):
        """Removes and returns a card from the deck.

        i: index of the card to pop; by default, pops the last card.
        """
        return self.cards.pop(i)

    def shuffle(self):
        """Shuffles the cards in this deck."""
        random.shuffle(self.cards)

    def sort(self):
        """Sorts the cards in ascending order."""
        self.cards.sort()

    def move_cards(self, hand, num):
        """Moves the given number of cards from the deck into the Hand.

        hand: destination Hand object
        num: integer number of cards to move
        """
        for i in range(num):
            hand.add_card(self.pop_card())


class Hand(Deck):
    """Represents a hand of playing cards."""
    
    def __init__(self, label=''):
        self.cards = []
        self.label = label
# 此處的class PokerHand(Hand): 移到下面和Problem6框放在一起方便編寫

# %%
# Problem 6
class Hand(Deck):
    """Represents a hand of playing cards."""
    
    def __init__(self, label=''):
        self.cards = []
        self.label = label
class PokerHand(Hand):

    def suit_hist(self):
        """Builds a histogram of the suits that appear in the hand.
        Stores the result in attribute suits.
        """
        self.suits = {}
        for card in self.cards:
            self.suits[card.suit] = self.suits.get(card.suit, 0) + 1

    def rank_hist(self) :
        """Builds a histogram of the ranks that appear in the hand.
        Stores the result in attribute ranks.
        """
        self.ranks = {}
        for card in self.cards:
            self.ranks[card.rank] = self.ranks.get(card.rank, 0) + 1

    def has_pair(self): #同樣rank的牌至少一種>=2
        for i in self.ranks.values() :
            if i >= 2 :
                return True
        return False

    def has_two_pairs(self) : #同樣rank的牌至少兩張，且至少兩組(number)以上
        number=0
        for i in self.ranks.values() :
            if i >= 2 :
                number += 1
                if number >= 2 :
                    return True
        return False

    def has_three_of_a_kind(self) : #照題目給下來，此處同rank牌要>=3
        for i in self.ranks.values() :
            if i >= 3 :
                return True
        return False
    
    def has_straight(self):
        self.cards.sort() #先將五張牌按order排
        x=0
        for i in range(4):
            if self.cards[i].rank+1==self.cards[i+1].rank:
                x += 1 #i從0跑到3，若x==4，為straight
        if x==4:
            return True
        #10.J.Q.K.A也ok
        y=[1,10,11,12,13]
        z=0
        for i in range(5):
            if self.cards[i].rank==y[i]:
                z=z+1
        if z==5:
            return True
        return False
    
    def has_flush(self):
        for i in self.suits.values():
            if i >= 5:
                return True
        return False
    
    def has_full_house(self):
        two_number=0
        three_number=0
        for i in self.ranks.values() :
            if i >= 3:
                three_number += 1 
            elif i==2:
                two_number+=1
        if (three_number>=2)or(three_number==1 and two_number>=1):
            return True
        return False
    
    def has_three_of_a_kind(self) : #照題目給下來，此處同rank牌要>=3
        for i in self.ranks.values() :
            if i >= 4 :
                return True
        return False
    
    def has_straight_flush(self):
        self.cards.sort() #先排序
        for i in self.suits.values():
            if i < 5: # 五張牌suits並沒有完全一樣
                return False
            elif i>=5:
                pass
        #判斷完suits，仿照straight判斷rank
        x=0
        for i in range(4):
            if self.cards[i].rank+1==self.cards[i+1].rank:
                x += 1 #i從0跑到3，若x==4，為straight
        if x==4:
            return True
        #10.J.Q.K.A也ok
        y=[1,10,11,12,13]
        z=0
        for i in range(5):
            if self.cards[i].rank==y[i]:
                z=z+1
        if z==5:
            return True
        return False
d=Deck()
h= PokerHand()
d.move_cards(h,5)
print 'Cards are:'
print h
h.suit_hist() #要先執行h.suit_hist()、h.rank_hist()才能跑底下的function,會用到suits和ranks
h.rank_hist()
print '----------'
print 'Has straight flush?'
print h.has_straight_flush()
print '----------'
print 'Has three of a kind?'
print h.has_three_of_a_kind()
print '----------'
print 'Has flush?'
print h.has_flush()
# Out:
# Cards are:
# King of Spades
# Queen of Spades
# Jack of Spades
# 10 of Spades
# 9 of Spades
# ----------
# Has straight flush?
# True
# ----------
# Has three of a kind?
# False
# ----------
# Has flush?
# True
