# %% [markdown]
# # Problem 2:
# # Sorting a List
#
# In this problem you should
# * Implement the **selection sort** algorithm.
# * Implement the **insertion sort** algorithm.
# * Create a list of N-elements where each element is a random integer between 0, 1, 2, ..., N-1.
# * Use your implementation of the selection sort and insertion sort to sort the the random list above.
# * Use built-in function `sorted()` that builds a new sorted list to show that your implementation is correct.
#
# ## Selection sort
#
# Following is the algorithm of the **selection sort**:
#
# * Divide the input list into two sub-lists:
#  * Sorted sub-list (Start with an empty list).
#  * Un-Sorted sub-list.
# * Find the smallest element in the unsorted list.
# * Swap with the leftmost unsorted element.
# * Move the sub-list boundaries.
#
# Following is an example of selection sort:
# <img src="SelectionSort.png" width="800">
#
# ## Insertion sort
#
# Following is the algorithm of the **insertion sort**:
#
# * Divide the input list into two sub-lists:
#  * Sorted sub-list (Start with the leftmost element).
#  * Un-Sorted sub-list.
# * Insert the leftmost element of the unsorted sub-list into the proper position of the sorted sub-list.
# * Move the sub-list boundaries
#
# Following is an example of selection sort:
# <img src="InsertionSort.png" width="800">

# %% [markdown]
# Please write your code based on the sketch below and use the test code below to show that your function works properly.

# %%
from random import *

# create a random list with N elements
n=10
ilist=[]
while len(ilist) < n:
    r=randint(0,n)
    if r not in ilist:
        ilist.append(r)
#print ilist

# list done

def random_list(n):
    ilist=[]
    while len(ilist) < n:
        r=randint(0,n)
        if r not in ilist:
            ilist.append(r)

# selection sort
def selection_sort(ilist):
    sort=[]
    unsort=ilist
    while len(unsort) != 0:

        sort.append(min(unsort))
        unsort.pop(unsort.index(min(unsort)))
    return sort
#done


    
# insertion sort
def insertion_sort(ilist):
    sort=[]
    unsort=ilist
    while len(unsort) >1 :
        temp=[]
        new=[]
        for j in range(len(unsort)):
            for i in range(len(sort)):
                if unsort[j]>sort[i] and unsort[j]<sort[i+1]:
                    temp.append(unsort[j])

                    new=sort[:i]+temp+sort[i+1:]
                    sort=new
                    unsort.pop(j)
                elif unsort[j]>sort[i]:
                    sort.append(unsort[j])
                    unsort.pop(j)
    return sort
                
'''
    for i in unsort:
        for j in sort:
            if i > j :
                sort.append(i)
                unsort.pop(unsort.index(i))
    return sort
        
'''
#--------------test------
n=[1,2,99,3,7,5,56]
n2=[44]
n3=[66,77]
#print n+n2+n3
#insertion_sort(n)

# %%
# test the implementation of selection sort
N = 10
L = random_list(N)
L_sorted = sorted(L)
selection_sort(L)

for i in range(len(L)):
    if L[i] != L_sorted[i]:
        print 'oops!'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-41ec1e8a86f6> in <module>()
#       2 N = 10
#       3 L = random_list(N)
# ----> 4 L_sorted = sorted(L)
#       5 selection_sort(L)
#       6
#
# TypeError: 'NoneType' object is not iterable

# %%
# test the implementation of insertion sort
N = 10
L = random_list(N)
L_sorted = sorted(L)
insertion_sort(L)

for i in range(len(L)):
    if L[i] != L_sorted[i]:
        print 'oops!'
