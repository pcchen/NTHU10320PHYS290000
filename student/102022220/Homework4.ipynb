# %% [markdown]
# # Homework 4

# %% [markdown]
# ## Problem 1
#
# 1. Implement the `Point` class.
# 2. Implement the `Rectangle` class.
# 3. Write a function called `distance_between_points` that takes two Points as arguments and returns the distance between them.
# 4. Write a function named `move_rectangle` that takes a Rectangle and two numbers named `dx` and `dy`. It should change the location of the rectangle by adding `dx` to the `x` coordinate of corner and adding `dy` to the `y` coordinate of corner.
# 5. Write a function named `move_rectangle_new` that is similar to the `move_rectangle` but it creates and returns a new Rectangle instead of modifying the old one.
# 6. Write some codes to demonstrate the usage of functions above.

# %%
# Problem 1

# 1
class Point(object):
    def __init__(self,x=0.0,y=0.0):
        self.x=x
        self.y=y
    def __str__(self):
        return '(%g,%g)' % (self.x,self.y)
#分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線
# 2
class Rectangle(object):
    def __init__(self,x=0.0,y=0.0,xlength=0.0,ylength=0.0):
        self.x=x
        self.y=y
        self.xlength=xlength
        self.ylength=ylength
    def __str__(self):
        return '(%g,%g,%g,%g)' % (self.x,self.y,self.xlength,self.ylength)
#分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線
# 3
def distance_between_points(point_1,point_2):
    return ((point_1.x-point_2.x)**2+(point_1.y-point_2.y)**2)**0.5
    
#分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線
# 4
def move_rectangle(rect,dx,dy):
    rect.x=rect.x+dx
    rect.y=rect.y+dy
    return '(%g,%g,%g,%g)' % (rect.x,rect.y,rect.xlength,rect.ylength)
# 5
def move_rectangle_new(rect,dx,dy):
    rect_new=Rectangle(0,0,0,0)
    rect_new.xlength=rect.xlength
    rect_new.ylength=rect.ylength
    rect_new.x=rect.x+dx
    rect_new.y=rect.y+dy
    return '(%g,%g,%g,%g)' % (rect_new.x,rect_new.y,rect_new.xlength,rect_new.ylength)


#分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線
#6此為測試區
aaa=Point(2,2)
bbb=Point(6,5)
ccc=Rectangle(5,5,10,20)
print distance_between_points(aaa,bbb)
print move_rectangle(ccc,10,0)
print ccc
print move_rectangle_new(ccc,10,0)
# Out:
# 5.0
# (15,5,10,20)
# (15,5,10,20)
# (25,5,10,20)

# %% [markdown]
# ## Problem 2
#
# 1. Implement the `Time` class.
# 2. Write a function called `print_time` that takes a Time object and prints it in the form `hour:minute:second`.
#   **Hint**: the format sequence '%.2d' prints an integer using at least two digits, including a leading zero if necessary.
# 3. Write a boolean function called `is_after` that takes two Time objects, `t1` and `t2`, and returns `True` if `t1` follows `t2` chronologically and `False` otherwise. **Challenge**: don’t use an `if` statement.
# 4. Write a function called `increment_modifier` that adds a given number of seconds to a Time object. It should modify the original time object. It should not contain any loops.
# 5. Write a function called `increment_pure` that adds a given number of seconds to a Time object. It should create and return a new Time object.
# 6. Write a function called `mul_time` that takes a Time object and a number and returns a new Time object that contains the product of the original Time and the number.
# 7. Use `mul_time` to write a function that takes a Time object that represents the finishing time in a race, and a number that represents the distance, and returns a Time object that represents the average pace (time per mile).
# 8. Write some codes to demonstrate the usage of functions above.

# %%
# Problem 2

# 1
class Time(object):
    def __init__(self,hour=0,minute=0,second=0):
        self.second=second%60
        self.minute=minute%60+second/60
        self.hour=hour+minute/60
        self.hour=self.hour+self.minute/60
        self.minute=self.minute%60
    def time_to_int(self):
        minute=self.hour*60+self.minute
        second=minute*60+self.second
        return second
    def __str__(self):
        return '%.2d:%.2d:%.2d' % (self.hour, self.minute, self.second)
#分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線
# 2
def print_time(dat):
    print '%.2d:%.2d:%.2d' % (dat.hour,dat.minute,dat.second)
#分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線
# 3
def is_after(t1,t2):
    return t1.time_to_int()<t2.time_to_int()
#分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線
# 4
def increment_modifier(time,sec):
    time=Time(time.hour,time.minute,time.second+sec)
    return time
#分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線
# 5
def increment_pure(time,sec):
    time_new=Time(time.hour,time.minute,time.second+sec)
    return time_new
#分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線
# 6
def mul_time(time,multi):
    time_new=Time(time.hour*multi,time.minute*multi,time.second*multi)
    return time_new
#分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線
# 7

#分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線
#此為測試區
# 8

dddd=Time(2,59,60)
eeee=Time(3,0,0)
ffff=Time(3,0,1)
print_time(dddd)
print is_after(dddd,eeee)
print is_after(dddd,ffff)
print increment_modifier(dddd,100)
print increment_pure(dddd,100)
print mul_time(dddd,2)
# Out:
# 03:00:00
# False
# True
# 03:01:40
# 03:01:40
# 06:00:00

# %% [markdown]
# ## Problem 3
#
# 1. Write a class definition for a Date object that has attributes `day`, `month` and `year`.
# 2. Write a function called `increment_date` that takes a Date object, `date` and an integer, `n`, and returns a new Date object that represents the day `n` days after date.
# 3. **Challenge**: does your function deal with leap years correctly? See http://en.wikipedia.org/wiki/Leap_year.

# %%
# Problem 3

#1
class Date(object):
	def __init__(self,year=0,month=0,day=0):
		self.year=year
		self.month=month
		self.day=day
		while self.month>12:
			self.month=self.month-12
			self.year=self.year+1
		while self.day>31:
			if self.month==1 or self.month==3 or self.month==5 or self.month==7 or self.month==8 or self.month==10 or self.month==12:
				self.day=self.day-31
				self.month=self.month+1
			elif  self.month==4 or self.month==6 or self.month==9 or self.month==11:
				self.day=self.day-30
				self.month=self.month+1
			else:
				if self.year%4==0:
					self.day=self.day-29
					self.month=self.month+1
				else:
					self.day=self.day-28
					self.month=self.month+1
			while self.month>12:
				self.month=self.month-12
				self.year=self.year+1
		if self.month==2 and self.day>28:
			if self.year%4==0 and self.day>29:
				self.day=self.day-29
				self.month=self.month+1
			elif self.year%4==0 and self.day<=29:
				pass
			else:
				self.day=self.day-28
				self.month=self.month+1
		else:
			pass
	def __str__(self):
		return '%2d/%2d/%2d' % (self.year,self.month,self.day)

#2
def increment_date(date,n):
	date_new=Date(date.year,date.month,date.day+n)
	return date_new
#3測試區

print Date(2000,200,200)#測試正確顯示
print ''


cca=Date(2000,2,28)
ccb=Date(2001,2,28)
print cca
print increment_date(cca,1)
print ccb
print increment_date(ccb,1)
# Out:
# 2017/ 2/16
#
# 2000/ 2/28
# 2000/ 2/29
# 2001/ 2/28
# 2001/ 3/ 1

# %% [markdown]
# ## Problem 4
#
# The `datetime` module provides date and time objects that are similar to the Date and Time objects in this chapter, but they provide a rich set of methods and operators. Read the documentation at http://docs.python.org/2/library/datetime.html.
#
# 1. Use the `datetime` module to write a program that gets the current date and prints the day of the week.
# 2. Write a program that takes a birthday as input and prints the user’s age and the number of days, hours, minutes and seconds until their next birthday.
# 3. For two people born on different days, there is a day when one is twice as old as the other. That’s their Double Day. Write a program that takes two birthdays and computes their Double Day.
# 4. For a little more challenge, write the more general version that computes the day when one person is `n` times older than the other.

# %%
# Problem 4
import datetime
#1
def now():
    print Date(datetime.date.today().year,datetime.date.today().month,datetime.date.today().day)
    return datetime.date.today().weekday()
#分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線
#2
def next_birthday(birthday):
    i=0
    today=Date(datetime.date.today().year,datetime.date.today().month,datetime.date.today().day)
    while today.day<datetime.date.today().day:
        while today.month<datetime.date.today().month:
            i=i+1
            today=Date(today.year,today.month,today.day+1)
    print i
    print 'Your age is'
#3
#分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線


#4由於衍生自第三題，已經乾脆附加於第三題內

#試驗區

print now()
print ''
birthday=Date(2000,9,9)
next_birthday(birthday)
# Out:
# 2015/ 5/19
# 1
#
# 0
# Your age is

# %%
# Problem 4
import datetime
#1
def now():
    print Date(datetime.date.today().year,datetime.date.today().month,datetime.date.today().day)
    return datetime.date.today().weekday()
#分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線
#2
def next_birthday(birthday):
    i=0
    today=Date(datetime.date.today().year,datetime.date.today().month,datetime.date.today().day)
    while 1+1==2:
        if today.day!=datetime.date.today().day:
            if today.month!=datetime.date.today().month:
                break
            else:
                i=i+1
                today=Date(today.year,today.month,today.day+1)
        else:
            i=i+1
            today=Date(today.year,today.month,today.day+1)
    print i
    print 'Your age is'
#3
#分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線


#4由於衍生自第三題，已經乾脆附加於第三題內

#試驗區

print now()
print ''
birthday=Date(2000,9,9)
next_birthday(birthday)

# %% [markdown]
# ## Problem 5
#
# Implement the `Point` class and the `Rectangle` class, with following methods.
#
# 1. Write an `init` method for the Point class that takes `x` and `y` as optional parameters and assigns them to the corresponding attributes.
# 2. Write a `str` method for the Point class.
# 3. Write an `add` method for Points that works with either a Point object or a tuple:
#   * If the second operand is a Point, the method should return a new Point whose `x` coordinate is the sum of the `x` coordinates of the operands, and likewise for the `y` coordinates.
#   * If the second operand is a tuple, the method should add the first element of the tuple to the `x` coordinate and the second element to the `y` coordinate, and return a new Point with the result.
# 4. Write some codes to demonstrate the usage of methods above.

# %%
# Problem 5

#1 and 2 and 3
class Point(object):
    def __init__(self,x=0.0,y=0.0):
        self.x=x
        self.y=y
    def __str__(self):
        return '(%g,%g)' % (self.x,self.y)
    def __add__(self, other):
        if isinstance(other,Point):
            new_point=Point(self.x+other.x,self.y+other.y)
            return new_point
        elif isinstance(other,tuple):
            new_point=Point(self.x+other[0],self.y+other[1])
            return new_point
        else:
            print 'not fit'
#分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線分隔線

#4
point01=Point(5,5)
point02=Point(6,7)
print point01
print point01+Point(6,7)
print point01+(6,7)
print point01+6
# Out:
# (5,5)
# (11,12)
# (11,12)
# not fit
# None
