# %% [markdown]
# # Homework 6

# %% [markdown]
# ## Problem 1
#
# Use **ivisual** module to plot the projectile motion with following equations of motion:
#
# $$
# \begin{eqnarray*}
#   m\ddot{x} &=& 0, \\
#   m\ddot{y} &=& -mg, \\
#   m\ddot{z} &=& 0,
# \end{eqnarray*}
# $$
# and initial conditions
#
# $$
#   \vec{r}(0) = (0, 0, 0), \\
#   \vec{v}(0) = (v_{x0}, v_{y0}, 0),
# $$
# You can assign $v_{x0}$ and $v_{y0}$ in the code or ask user to input it.
#
# You should
# * Use a box to represent the ground.
# * Use three arrows to represent the three axes.
# * Use a sphere to represent the ball of the projectile motion.
# * Leave a trail.
# * Stop the simulation when the ball hit the ground.
#
# You should use to ways to calculate the trajectory of the motion.
# 1. Use exact solution: $x(t)=x(0)+v_x t$, etc.
# 2. Use numerical solution:
#  * $v(t+dt) = v(t) + a * dt$.
#  * $x(t+dt) = x(t) + v(t) * dt$.
#
# You should use a small enough $dt$ to ensure the numerical solution is accurate enough.

# %%
# Problem 1
from ivisual import *

scene = canvas()

scene.width = 800
scene.height = 600

scene.autoscale = 0
scene.range = (10,10,20)
scene.center = (10,0,0)

ball = sphere(pos=(0,0,0), radius=0.5, color=color.cyan)
ground = box(pos = (10, -0.1, 0), size = (30, 0.2, 20), color = color.green)
x_axis = arrow(pos = (0, 0, 0), axis = (10, 0, 0), shaftwidth=0.2)
y_axis = arrow(pos = (0, 0, 0), axis = (0, 10, 0), shaftwidth=0.2)
z_axis = arrow(pos = (0, 0, 0), axis = (0, 0, 10), shaftwidth=0.2)
ball.velocity = vector(9,10,0)
vscale = 0.2
varr = arrow(pos=ball.pos, axis=vscale*ball.velocity, color=color.yellow)

ball.trail = curve(color=ball.color)
deltat = 0.01
g = -9.8
ball.velocity.y += g*deltat
t = 0

while t < 10:
    rate(50)
    if ball.pos.y < ground.pos.y:
        break
        
    ball.pos = ball.pos + ball.velocity*deltat
    ball.trail.append(pos=ball.pos)
    ball.velocity.y += g*deltat
    varr.pos = ball.pos
    varr.axis = vscale*ball.velocity
    t = t + deltat
# Out:
# <div id="scene13"><div id="glowscript" class="glowscript"></div></div>
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0
# commsend len(baseObj.cmds) > 0

# %% [markdown]
# ## Problem 2
#
# Now introduce the air resistence so the equations of motion become:
#
# $$
# \begin{eqnarray*}
#   m\ddot{x} &=& -km\dot{x}, \\
#   m\ddot{y} &=& -km\dot{y}-mg, \\
#   m\ddot{z} &=& 0,
# \end{eqnarray*}
# $$
# and initial conditions
#
# $$
#   \vec{r}(0) = (0, 0, 0), \\
#   \vec{v}(0) = (v_{x0}, v_{y0}, 0),
# $$
# You can assign $v_{x0}$ and $v_{y0}$ in the code or ask user to input it.
#
# You should
# * Use a box to represent the ground.
# * Use three arrows to represent the three axes.
# * Use a sphere to represent the ball of the projectile motion.
# * Leave a trail.
# * Stop the simulation when the ball hit the ground.
#
#
# You should use to ways to calculate the trajectory of the motion.
# 1. Use exact solution: (Check for example Marion's book).
# 2. Use numerical solution:
#  * $v(t+dt) = v(t) + a * dt$.
#  * $x(t+dt) = x(t) + v(t) * dt$.
#
# You should use a small enough $dt$ to ensure the numerical solution is accurate enough.

# %%
# Problem 2
from ivisual import *
#objects
scene = canvas(title = "ball movement")

scene.width = 800
scene.height = 600
scene.autoscale = 0
scene.range = (100,100,100)
scene.center = (0,0,0)

ground = box(pos=(0,-5,0),     axis=(1,0,0), length=150,
    height=10, width=150)

xaxis = arrow(pos=(0,0,0),  axis=(1,0,0),    color=(1,0,0), length=200,  shaftwidth=5)

yaxis = arrow(pos=(0,0,0),  axis=(0,1,0),    color=(0,1,0), length=200,  shaftwidth=5)

zaxis = arrow(pos=(0,0,0),  axis=(0,0,1),    color=(0,0,1), length=200,  shaftwidth=5)

ball = sphere(pos=(0,0,0), radius=5, color=(1,1,0))

vx=10
vy=60


deltat = 0.02
t=0
g=9.8
k=0.3
ball.trail = curve(color=ball.color)
ball.velocity=vector(vx,vy,0)


while ball.pos.y >= 0 and t<10:
    rate(10)
    t += deltat
    ball.pos.x=ball.pos.x+ball.velocity.x*deltat
    ball.pos.y=ball.pos.y+ball.velocity.y*deltat
    ball.velocity.x=ball.velocity.x-k*deltat*ball.velocity.x
    ball.velocity.y=ball.velocity.y-k*deltat*ball.velocity.y-g*deltat
    ball.pos=ball.pos
    ball.trail.append(pos=ball.pos)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-135dbf37cfbc> in <module>()
#       1 # Problem 2
# ----> 2 from ivisual import *
#       3 #objects
#       4 scene = canvas(title = "ball movement")
#       5
#
# ImportError: No module named ivisual

# %% [markdown]
# ## Problem 3
#
# Use **ivisual** module to plot the trajectory of a coupled spring-mass system that has two masses, three springs, two walls.
#
# Something like Wall-spring1-mass1-spring2-mass2-spring3-Wall.
#
# You should
# * Use a box to represent the ground.
# * Use two boxes to represent the walls.
# * Use two **cubic** boxes to represent the two masses.
# * Use helix to represent the two srpings.

# %%
from ivisual import *

# %%
# Problem 3
from math import *

scene = canvas(title = "Spring Mass")

weight = box(pos=(-0.5,0,0),size=(.3,.3,.3),color=color.yellow)
weight2 = box(pos=(0.4,0,0),size=(.3,.3,.3),color=color.yellow)
frictionlessSurface = box(size=(3,.02,.5),pos=(.0,-.16,0))
wall = box(size=(.04,.5,.3),pos=(-1.27,.1,0),color=color.red)
wall2 = box(size=(.04,.5,.3),pos=(1.17,.1,0),color=color.red)

relaxedlength = vector(0.6,0,0) # length of spring when it isn't stretched or compressed .60
spring = helix(pos=(-1.25,0,0),axis=relaxedlength, radius=.1,coils=8,thickness=.01,color=color.green)
spring2 = helix(pos=(weight.pos.x+.15,0,0),axis=relaxedlength, radius=.1,coils=8,thickness=.01,color=color.green)
spring3 = helix(pos=(weight2.pos.x+0.15,0,0),axis=relaxedlength, radius=.1,coils=8,thickness=.01,color=color.green)

# 
g=9.8 # m/s**2
spring.constant = 2 # k
spring2.constant = 2 # k
spring3.constant = 2 # k

weight.mass = 10 # kg
weight2.mass = 10 # kg

mu = 0.00 # friction

# initial position
xpos=-0.15 
xpos2=0.75
weight.pos=vector(xpos,0,0)
weight2.pos=vector(xpos2,0,0)

spring.displacement=weight.pos+vector(0.5,0,0)
spring.axis=relaxedlength+spring.displacement
spring2.displacement=weight2.pos-vector(0.4,0,0)-spring.displacement
spring2.axis=relaxedlength+spring2.displacement
spring3.displacement=vector(0.4,0,0)-weight2.pos
spring3.axis=relaxedlength+spring3.displacement

weight.velocity = vector(0,0,0)
weight.acceleration = vector(0,0,0)
weight.force = vector(0,0,0)
weight2.velocity = vector(0,0,0)
weight2.acceleration = vector(0,0,0)
weight2.force = vector(0,0,0)


def ani2():
    dt = .01    # seconds
    seconds = 0 # total time
    steps=5000 #integration steps: final time= dt*steps

    while seconds < dt*steps:
        rate(100)
        seconds = seconds + dt

        F_fr=vector(0,0,0)
        if weight.velocity.x>0:
            F_fr=vector(-mu*weight.mass*g,0,0)
        if weight.velocity.x<0:
            F_fr=vector(mu*weight.mass*g,0,0)
        if weight2.velocity.x>0:
            F_fr2=vector(-mu*weight.mass*g,0,0)
        if weight2.velocity.x<0:
            F_fr2=vector(mu*weight.mass*g,0,0)

        # Calculate the spring force using Hooke's Law
        SpringForce = -spring.constant * spring.displacement
        SpringForce2 = -spring2.constant * spring.displacement
        SpringForce3 = -spring3.constant * spring.displacement


        # The spring force acts on the weight
        weight.force = SpringForce-SpringForce2
        weight2.force = SpringForce2-SpringForce3

        # move the weight from weight.pos using 
        # the momentum principle
        #weight.acceleration = weight.force/weight.mass
        weight.velocity += dt*weight.force/weight.mass # F*dt=dp
        weight2.velocity += weight2.force/weight2.mass
        weight.pos += weight.velocity*dt #+O(dt^2) -> + .5 * weight.acceleration * dt**2
        weight2.pos += weight2.velocity*dt
        spring2.pos = weight.pos+vector(.15,0,0)
        spring3.pos = weight2.pos+vector(.15,0,0)
        # calculate the new spring displacement
        spring.displacement=weight.pos+vector(0.5,0,0)
        spring2.displacement=weight2.pos-vector(0.4,0,0)-spring.displacement
        spring3.displacement=vector(0.4,0,0)-weight2.pos

        # update the length of the spring
        spring.axis = relaxedlength + spring.displacement
        spring2.axis=relaxedlength+spring2.displacement
        spring3.axis = relaxedlength+spring3.displacement
# Out:
# <div id="scene17"><div id="glowscript" class="glowscript"></div></div>

# %%
ani2()

# %% [markdown]
# # Problem 4
#
# Use **ivisual** module to plot the trajectories of 20 particles in a rectangle box.
#
# * The rectangle box has the dimension $L_x$, $L_y$, $L_z$.
# * Use boxes to represent the walls. Keep one wall **invisible**.
# * The 20 particles should have **random** initial velocity.
# * The 20 particles should leave a trail.
# * Make each particle has random RGB color.

# %%
# Problem 4

from ivisual import *

scene = canvas()

scene.width = 800
scene.height = 600

scene.autoscale = 0
scene.range = (10,10,10)
scene.center = (0,0,0)
#bondary 666
wallR = box(pos=(+6,0,0), size=(0.2,12,12), color=color.green)
wallL = box(pos=(-6,0,0), size=(0.2,12,12), color=color.green)
wallU = box(pos=(0,+6,0), size=(12,0.2,12), color=color.blue)
wallD = box(pos=(0,-6,0), size=(12,0.2,12), color=color.blue)
wallB = box(pos=(0,0,-6), size=(12,12,0.2), color=color.red)

ball = []

def rc():
    c = (random.randint(0,255),random.randint(0,255),random.randint(0,255))
    #print c
    return c
def randp():
    return random.uniform(-6,6)
for i in range(20):
    position = vector(randp(),randp(),randp())
    ball.append(sphere(pos=position, radius=0.5, color=rc()))
    v = vector(randp(),randp(),randp())
    ball[i].velocity = v
    ball[i].trail = curve(color=ball[i].color)


vscale = 0.1



deltat = 0.005
t=0

while t < 5:
    rate(50)
    for i in range(20):
        if ball[i].pos.x > wallR.pos.x:
             ball[i].velocity.x = -ball[i].velocity.x
        if ball[i].pos.x < wallL.pos.x:
             ball[i].velocity.x = -ball[i].velocity.x
        if ball[i].pos.y > wallU.pos.y:
             ball[i].velocity.y = -ball[i].velocity.y
        if ball[i].pos.y < wallD.pos.y:
             ball[i].velocity.y = -ball[i].velocity.y
        if ball[i].pos.z < wallB.pos.z:
             ball[i].velocity.z = -ball[i].velocity.z
        if ball[i].pos.z > +6:
             ball[i].velocity.z = -ball[i].velocity.z
    
        ball[i].pos = ball[i].pos + ball[i].velocity*deltat
        ball[i].trail.append(pos=ball[i].pos)
    
    t = t + deltat
# Out:
# <div id="scene18"><div id="glowscript" class="glowscript"></div></div>
