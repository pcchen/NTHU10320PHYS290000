# %% [markdown]
# # Homework 4

# %% [markdown]
# ## Problem 1
#
# 1. Implement the `Point` class.
# 2. Implement the `Rectangle` class.
# 3. Write a function called `distance_between_points` that takes two Points as arguments and returns the distance between them.
# 4. Write a function named `move_rectangle` that takes a Rectangle and two numbers named `dx` and `dy`. It should change the location of the rectangle by adding `dx` to the `x` coordinate of corner and adding `dy` to the `y` coordinate of corner.
# 5. Write a function named `move_rectangle_new` that is similar to the `move_rectangle` but it creates and returns a new Rectangle instead of modifying the old one.
# 6. Write some codes to demonstrate the usage of functions above.

# %%
# Problem 1

import math

# 1

class Point(object):
    """Represents a point in 2-D space."""
print Point

# 2

class Rectangle(object):
    """Represents a rectangle. 

    attributes: width, height, corner.
    """
print Rectangle
    
# 3 (and #6)

def distance_between_points(p1,p2):
    dist = math.sqrt((p2.x-p1.x)**2 + (p2.y-p1.y)**2)
    print dist

p1 = Point()
p1.x = 0
p1.y = 0
p2 = Point()
p2.x = 1
p2.y = 1

print "Demo #3 Points:"
print (p1.x,p1.y),(p2.x,p2.y)
print "Demo #3 Distance between points:"
print distance_between_points(p1,p2)

# 4 (and #6)

def move_rectangle(r,dx,dy):
    r.corner.x = r.corner.x + dx
    r.corner.y = r.corner.y + dy
    return (r.corner.x,r.corner.y)

r = Rectangle()
r.corner = Point()
r.w = 2
r.h = 2 
r.corner.x = 1
r.corner.y = 1

print "Demo #4 Initial value"
print (r.corner.x,r.corner.y)
print "Demo #4 After moving dx=3,dy=4"
move_rectangle(r,3,4)

# 5 (and #6)

def move_rectangle_new(r,dx,dy):
    new_r = Rectangle()
    new_r.corner = Point()
    new_r.corner.x = r.corner.x + dx
    new_r.corner.y = r.corner.y + dy
    new_r.w = 2
    new_r.h = 2 
    new_r.corner.x = 1
    new_r.corner.y = 1

print "Demo #5 Initial value"
print (new_r.corner.x,new_r.corner.y)
print "Demo #5 New dx=3,dy=4"
move_rectangle_new(r,3,4)
# Out:
# <class '__main__.Point'>
# <class '__main__.Rectangle'>
# Demo #3 Points:
# (0, 0) (1, 1)
# Demo #3 Distance between points:
# 1.41421356237
# None
# Demo #4 Initial value
# (1, 1)
# Demo #4 After moving dx=3,dy=4
# Demo #5 Initial value
# (7, 9)
# Demo #5 New dx=3,dy=4

# %% [markdown]
# ## Problem 2
#
# 1. Implement the `Time` class.
# 2. Write a function called `print_time` that takes a Time object and prints it in the form `hour:minute:second`.
#   **Hint**: the format sequence '%.2d' prints an integer using at least two digits, including a leading zero if necessary.
# 3. Write a boolean function called `is_after` that takes two Time objects, `t1` and `t2`, and returns `True` if `t1` follows `t2` chronologically and `False` otherwise. **Challenge**: don’t use an `if` statement.
# 4. Write a function called `increment_modifier` that adds a given number of seconds to a Time object. It should modify the original time object. It should not contain any loops.
# 5. Write a function called `increment_pure` that adds a given number of seconds to a Time object. It should create and return a new Time object.
# 6. Write a function called `mul_time` that takes a Time object and a number and returns a new Time object that contains the product of the original Time and the number.
# 7. Use `mul_time` to write a function that takes a Time object that represents the finishing time in a race, and a number that represents the distance, and returns a Time object that represents the average pace (time per mile).
# 8. Write some codes to demonstrate the usage of functions above.

# %%
# Problem 2

# 1

class Time(object):
    """represents the time of day.
        attributes: hour, minute, second"""

# 2 (and #8)

t = Time()
def print_time(t):
    print '%.2d:%.2d:%.2d' % (t.hour,t.minute,t.second)

print "#2 Demo"
t.hour = 1
t.minute = 10
t.second = 10
print_time(time)
    
# 3 (and #8)

print "#3 Demo"
def is_after(t1,t2):
    t1.minute = t1.hour * 60 + t1.minute
    t1.second = t1.minute * 60 + t1.second
    t2.minute = t2.hour * 60 + t2.minute
    t2.second = t2.minute * 60 + t2.second
    if t1.second < t2.second:
        print True
    else:
        print False

t1=Time()
t2=Time()
t1.hour = 1
t1.minute = 10
t1.second = 10
t2.hour = 1
t2.minute = 10
t2.second = 11

is_after(t1,t2)


# 4 (and #8)

t = Time()
def increment_modifier(time,s):
    t.second = t.second + s
    if t.second >= 60:
        t.minute = t.minute + t.second/60
        t.second = t.second%60
    if t.minute >= 60:
        t.hour = t.hour + t.minute/60
        t.minute = t.minute%60
    return time

t.hour = 1
t.minute = 10
t.second = 10

print "#4 Demo"
increment_modifier(time,1000)
print_time(t)

# 5 (and #8)

def increment_pure(time,s):
    
    n_t = Time()
    n_t.second = t.second + s
    n_t.minute = t.minute
    n_t.hour = t.hour
    
    if n_t.second >= 60:
        n_t.minute = n_t.minute + n_t.second /60
        n_t.second = n_t.second %60
    if n_t.minute >= 60:
        n_t.hour = n_t.hour + n_t.minute /60
        n_t.minute = n_t.minute %60
    return n_t

t.hour = 1
t.minute = 10
t.second = 10

print "#5 Demo"
print_time(increment_pure(time,1000))

# 6 (and #8)

def mul_time(t,x):
    
    n_t = Time()
    n_t.hour = t.hour * x
    n_t.minute = t.minute * x
    n_t.second = t.second * x
    
    if n_t.second >= 60:
        n_t.minute = n_t.minute + n_t.second/60
        n_t.second = n_t.second%60
    if n_t.minute >= 60:
        n_t.hour = n_t.hour + n_t.minute/60
        n_t.minute = n_t.minute%60
    return n_t

t.hour = 1
t.minute = 10
t.second = 10

print "#6 Demo"
print_time(mul_time(t,6))

# 7 (and #8)

print "#7 Demo"
def avg_pace(t,x):
    return mul_time(tt,1/x)

t.hour = 1
t.minute = 10
t.second = 10

print_time(pace(t,0.5))
# Out:
# #2 Demo
# 01:10:10
# #3 Demo
# True
# #4 Demo
# 01:26:50
# #5 Demo
# 01:26:50
# #6 Demo
# 07:01:00
# #7 Demo
# 02:20:20

# %% [markdown]
# ## Problem 3
#
# 1. Write a class definition for a Date object that has attributes `day`, `month` and `year`.
# 2. Write a function called `increment_date` that takes a Date object, `date` and an integer, `n`, and returns a new Date object that represents the day `n` days after date.
# 3. **Challenge**: does your function deal with leap years correctly? See http://en.wikipedia.org/wiki/Leap_year.

# %%
# Problem 3 (FAILED)

#1
class Date(object):
    """represents a date.
    attributes: day, month, year"""
 
    
#2 & #3

d = Date()
def increment_date(d,n):
    n_d = Date()
    n_d.day = d.day + n
    n_d.month = d.month
    n_d.year = d.year
    
    if year %4!=0: #leapyear
        if month !=2:
            if n_d.day >29:
                n_d.day = n_d.day-28
                n_d.month = n_d.month+1
                print "{}/{}/{}".format(n_d.year,n_d.month,n_d.day)
                
        if (month <=7 & month %2 ==1) or (month >=8 & month %2 ==0) :
            if n_d.day > 31:
                n_d.day = n_d.day -30
                n_d.month = n_d.month +1
                print "{}/{}/{}".format(n_d.year,n_d.month,n_d.day)
                
        if (month <=7 & month %2 ==0) or (month >=8 & month %2 ==1) :
            if n_d.day > 30:
                n_d.day = n_d.day -29
                n_d.month = n_d.month +1
                print "{}/{}/{}".format(n_d.year,n_d.month,n_d.day)
                
        if month >= 13:
            n_d.month = n_d.month -12
            n_d.year = n_d.year + 1
            return year
            
    else: #non leap years
        if month !=2:
            if n_d.day >28:
                n_d.day = n_d.day-27
                n_d.month = n_d.month+1
                print "{}/{}/{}".format(n_d.year,n_d.month,n_d.day)
                
        if (month <=7 & month %2 ==1) or (month >=8 & month %2 ==0) :
            if n_d.day > 31:
                n_d.day = n_d.day -30
                n_d.month = n_d.month +1
                print "{}/{}/{}".format(n_d.year,n_d.month,n_d.day)
                
        if (month <=7 & month %2 ==0) or (month >=8 & month %2 ==1) :
            if n_d.day > 30:
                n_d.day = n_d.day -29
                n_d.month = n_d.month +1
                print "{}/{}/{}".format(n_d.year,n_d.month,n_d.day)
                
        if month >=13:
            n_d.month = n_d.month -12
            n_d.year = n_d.year + 1
            return year

def print_date(d):
    print "{}/{}/{}".format(d.year,d.month,d.day)         

d.year = 2015 
d.month = 5
d.day= 13

print_date(d)
increment_date(d,3)
# Out:
# 2015/5/13
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-135397df4ba9> in <module>()
#      72
#      73 print_date(d)
# ---> 74 increment_date(d,3)
#
# <ipython-input-11-135397df4ba9> in increment_date(d, n)
#      16     n_d.year = d.year
#      17
# ---> 18     if year %4!=0:
#      19         if month !=2:
#      20             if n_d.day >29:
#
# NameError: global name 'year' is not defined

# %%
# Problem 3 (SUCCESSFUL)

#1
class Date(object):
    """ Represent the date
    attributes: year, month, day.
    """
#2,3
d = Date()
d1 = Date()

def print_date(d):
    print "{}/{}/{}".format(d.month,d.day,d.year)    

def leapyear(year):
    if year%4 == 0:
        if year%100 == 0:
            if year%400 == 0:
                return True
            return False
        return True
    return False

def month_list(year):
    if leapyear(year):
        return [31,29,31,30,31,30,31,31,30,31,30,31]
    return [31,28,31,30,31,30,31,31,30,31,30,31]

def day_year(year):
    if leapyear(year):
        return 366
    return 365

def date_to_int(d):
    year_to_day = 0
    month_to_day = 0
    for year in range(1,d.year):
        year_to_day += day_year(year)

    month_day = month_list(d.year)
    for month in range(1,d.month):
        month_to_day += month_day[month - 1] 
    return month_to_day + year_to_day + d.day - 1

def int_to_date(day):
    d1 = copy.deepcopy(d)
    d1.year = 1
    remain_day = 365
    month_day = month_list(d1.year)
    while day >= remain_day:
        d1.year += 1
        day -= remain_day
        remain_day = day_year(d1.year)
    
    d1.month = 1
    remain_day = 31    
    while day >= remain_day:
        d1.month += 1
        day -= remain_day
        remain_day = month_day[d1.month-1]
    
    d1.day = day+1
    return print_date(d1)
import copy
def increment_date(d,n):
    new_d = copy.deepcopy(d)
    return int_to_date(date_to_int(new_d)+n)


d.year = 2015 
d.month = 5
d.day= 20
n=1000

print "Printed date"
print_date(d)
print "Adding increment"
increment_date(d,n)
# Out:
# Printed date
# 5/20/2015
# Adding increment
# 2/13/2018

# %% [markdown]
# ## Problem 4
#
# The `datetime` module provides date and time objects that are similar to the Date and Time objects in this chapter, but they provide a rich set of methods and operators. Read the documentation at http://docs.python.org/2/library/datetime.html.
#
# 1. Use the `datetime` module to write a program that gets the current date and prints the day of the week.
# 2. Write a program that takes a birthday as input and prints the user’s age and the number of days, hours, minutes and seconds until their next birthday.
# 3. For two people born on different days, there is a day when one is twice as old as the other. That’s their Double Day. Write a program that takes two birthdays and computes their Double Day.
# 4. For a little more challenge, write the more general version that computes the day when one person is `n` times older than the other.

# %%
# Problem 4
#1
from datetime import datetime,date,time
i = datetime.now()
print i.strftime('%Y/%m/%d %H:%M:%S %A')
# Out:
# 2015/05/20 23:00:21 Wednesday

# %% [markdown]
# ## Problem 5
#
# Implement the `Point` class and the `Rectangle` class, with following methods.
#
# 1. Write an `init` method for the Point class that takes `x` and `y` as optional parameters and assigns them to the corresponding attributes.
# 2. Write a `str` method for the Point class.
# 3. Write an `add` method for Points that works with either a Point object or a tuple:
#   * If the second operand is a Point, the method should return a new Point whose `x` coordinate is the sum of the `x` coordinates of the operands, and likewise for the `y` coordinates.
#   * If the second operand is a tuple, the method should add the first element of the tuple to the `x` coordinate and the second element to the `y` coordinate, and return a new Point with the result.
# 4. Write some codes to demonstrate the usage of methods above.

# %%
# Problem 5

#1 (and #4)

class Point(object):
    """Represents a point in 2-D space."""
    
    def __init__(self, x=0, y=0):
        self.x = x
        self.y = y
    def print_point(point):
        print '(%.d,%.d)' % (p.x,p.y) 

print '#1 Demo'
p = Point(1,1)
p.print_point()

#2 (and #4)

class Point(object):
    """Represents a point in 2-D space."""
    def __init__(self, x=0, y=0):
        self.x = x
        self.y = y      
    def __str__(self):
        return '(%.d,%.d)' % (self.x, self.y)
    
print '#2 Demo'    
p = Point(1,1)
print p

#3 (and #4)

class Point(object):
    """Represents a point in 2-D space."""
    def __init__(self, x=0, y=0):
        self.x = x
        self.y = y
    
    def __add__(self, other):
        if isinstance(other, Point):
            return self.add(other)
        else:
            return self.tuple(other)
        
    def add(self,other):
        x = self.x + other.x
        y = self.y + other.y
        return '(%.d,%.d)' % (x, y)
    
    def tuple(self,other):
        x = self.x + other[0]
        y = self.y + other[1]
        return '(%.d,%.d)' % (x, y)

print '#3 Demo'
p1 = Point(1,2)
p2 = Point(1,3)
p3 = (1,4)
print p1 + p2
print p1 + p3
print p2 + p3
# Out:
# #1 Demo
# (1,1)
# #2 Demo
# (1,1)
# #3 Demo
# (2,5)
# (2,6)
# (2,7)
